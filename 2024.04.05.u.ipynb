# %%
import pandas as pd
import pickle
with open("./kbo_detail.pkl", "rb") as f:
    kbo_df=pickle.load(f)

# %%
#loc iloc
kbo_df.loc[2,"경력"]
# Out:
# ' 가동초-휘문중-배명고-동국대'

# %%
kbo_df.loc[2:,"경력"]
# Out:
# 2                       가동초-휘문중-배명고-동국대
# 3                           사당초-언북중-장충고
# 4                    본리초-대구중-경북고-SK-SSG
# 5                           양정초-개성중-경남고
# 6                 동수원초(수원영통구리틀)-매향중-공주고
#                      ...
# 839                       동일중앙초-경남중-경남고
# 840           사능초(남양주리틀)-청원중-포항제철고-성균관대
# 841                 수원신곡초-매송중-유신고-KT-상무
# 842                     칠성초-경복중-경북고-수성대
# 843     사당초-서울이수중-경기고-현대-히어로즈-롯데-샌프란시스코
# Name: 경력, Length: 842, dtype: object

# %%
kbo_df.set_index("선수명")
#선수명을 인덱스로하기
# Out:
#          등번호            생년월일         포지션         신장/체중  \
# 선수명
# 강재민      No.   1997년 04월 03일    투수(우언우타)    180cm/89kg
# 권광민    No.17   1997년 12월 12일   외야수(좌투좌타)   189cm/102kg
# 권동욱    No.02   2001년 01월 08일   외야수(우투우타)    173cm/85kg
# 권현    No.111   2005년 02월 23일   외야수(우투우타)    182cm/88kg
# 김강민     No.9   1982년 09월 13일   외야수(우투우타)    182cm/87kg
# ..       ...             ...         ...           ...
# 한민우    No.96   1999년 04월 27일    투수(좌투좌타)    177cm/82kg
# 한차현    No.59   1998년 11월 30일    투수(우투우타)    180cm/80kg
# 홍현빈    No.31   1997년 08월 29일   외야수(우투좌타)    174cm/70kg
# 황의준   No.103   2002년 04월 06일   외야수(우투좌타)    185cm/95kg
# 황재균    No.10   1987년 07월 28일   내야수(우투우타)    183cm/96kg
#
#                                    경력    입단 계약금         연봉  \
# 선수명
# 강재민                   양덕초-마산중-용마고-단국대    8000만원    14500만원
# 권광민                     서울청구초-홍은중-장충고               3300만원
# 권동욱                   가동초-휘문중-배명고-동국대               3000만원
# ...

# %%
kbo_df.set_index("선수명").loc[' 권동욱','신장/체중']
# 모든 index가 0으로 시작하는건아니다.
#loc의 왼쪽이 로우
# Out:
# ' 173cm/85kg'

# %%
#강화학습 벨만방정식
# 지도학습 정답이 있는 데이터를 가지고 대상 가르침
# 비지도학습 
# ai hub 데이터에 정답이 있어야하는데

# %%
kbo_df["선수명"]
# Out:
# 0       강재민
# 1       권광민
# 2       권동욱
# 3        권현
# 4       김강민
#        ...
# 839     한민우
# 840     한차현
# 841     홍현빈
# 842     황의준
# 843     황재균
# Name: 선수명, Length: 844, dtype: object

# %%
def tmp(x):
    return x.strip()

# %%
kbo_df.선수명.apply(tmp)
# 크몽
# Out:
# 0      강재민
# 1      권광민
# 2      권동욱
# 3       권현
# 4      김강민
#       ...
# 839    한민우
# 840    한차현
# 841    홍현빈
# 842    황의준
# 843    황재균
# Name: 선수명, Length: 844, dtype: object

# %%
kbo_df.선수명=kbo_df.선수명.apply(lambda x:x.strip())

# %%
# kbo_df.set_index("선수명").loc['권동욱','신장/체중']
# 데이터 전처리
kbo_df.set_index("선수명").iloc[1,2] #loc는 이름 iloc는 index로
# Out:
# ' 외야수(좌투좌타)'

# %%
sum(kbo_df.연봉.str.find("달러")>-1)   #만약에 true면 달러가들어간거
# Out:
# 30

# %%
mask=kbo_df.연봉.str.find("달러")>-1

# %%
kbo_df[mask] #true값만나옴 원하는 data뽑으려고할때
# Out:
#        선수명     등번호            생년월일         포지션         신장/체중  \
# 33     산체스   No.34   1997년 04월 11일    투수(좌투좌타)    178cm/99kg
# 84      페냐   No.20   1990년 01월 25일    투수(우투우타)    188cm/99kg
# 85     페라자   No.30   1998년 11월 10일   외야수(우투양타)    175cm/88kg
# 124     네일   No.40   1993년 02월 08일    투수(우투우타)    193cm/83kg
# 134  소크라테스   No.30   1992년 09월 06일   외야수(좌투좌타)    188cm/93kg
# 170    크로우   No.12   1994년 09월 09일    투수(우투우타)   185cm/108kg
# 194     더거   No.33   1995년 07월 03일    투수(우투우타)    183cm/83kg
# 218   에레디아   No.27   1991년 01월 31일   외야수(좌투우타)    178cm/88kg
# 219   엘리아스   No.55   1988년 08월 01일    투수(좌투좌타)    185cm/92kg
# 283   데이비슨   No.24   1991년 03월 26일   내야수(우투우타)   190cm/104kg
# 340   카스타노   No.20   1994년 09월 17일    투수(좌투좌타)   190cm/104kg
# 342     하트   No.30   1992년 11월 23일    투수(좌투좌타)    196cm/90kg
# 388     엔스   No.34   1991년 05월 16일    투수(좌투좌타)    185cm/95kg
# 389    오스틴   No.23   1993년 10월 14일   내야수(우투우타)    183cm/97kg
# ...

# %%
a=pd.DataFrame({"col1" : [1,2,3,4],"col2" : [2,3,4,5]})
a
# Out:
#    col1  col2
# 0     1     2
# 1     2     3
# 2     3     4
# 3     4     5

# %%
b=a

# %%
b.loc[1,'col2']=100

# %%
b.iloc[1,1]
# Out:
# 100

# %%
a #할당연산자는 이름만 다르게할뿐 주소는 같다
# Out:
#    col1  col2
# 0     1     2
# 1     2   100
# 2     3     4
# 3     4     5

# %%
tmp_df=kbo_df[mask].copy() #copy함수를 써서 새로운 저장메모리 만들기
tmp_df['gggg']=1000

# %%
kbo_df
# 함수내장시키기 환율은 쭉스므로 
# 삼성의 gpt이야기
# Out:
#      선수명      등번호            생년월일         포지션         신장/체중  \
# 0    강재민      No.   1997년 04월 03일    투수(우언우타)    180cm/89kg
# 1    권광민    No.17   1997년 12월 12일   외야수(좌투좌타)   189cm/102kg
# 2    권동욱    No.02   2001년 01월 08일   외야수(우투우타)    173cm/85kg
# 3     권현   No.111   2005년 02월 23일   외야수(우투우타)    182cm/88kg
# 4    김강민     No.9   1982년 09월 13일   외야수(우투우타)    182cm/87kg
# ..   ...      ...             ...         ...           ...
# 839  한민우    No.96   1999년 04월 27일    투수(좌투좌타)    177cm/82kg
# 840  한차현    No.59   1998년 11월 30일    투수(우투우타)    180cm/80kg
# 841  홍현빈    No.31   1997년 08월 29일   외야수(우투좌타)    174cm/70kg
# 842  황의준   No.103   2002년 04월 06일   외야수(우투좌타)    185cm/95kg
# 843  황재균    No.10   1987년 07월 28일   내야수(우투우타)    183cm/96kg
#
#                                    경력    입단 계약금         연봉  \
# 0                     양덕초-마산중-용마고-단국대    8000만원    14500만원
# 1                       서울청구초-홍은중-장충고               3300만원
# 2                     가동초-휘문중-배명고-동국대               3000만원
# ...

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# error발생시 
# pip install lxml
# tag가 table일때 오직 table일때
import requests 

payload = {"ajax": "true",
"curCd": "",
"tmpInqStrDt": "2024-04-03",
"pbldDvCd": "0",
"pbldSqn": "",
"hid_key_data": "",
"inqStrDt": "20240403",
"inqKindCd": "1",
"hid_enc_data": "",
"requestTarget": "searchContentDiv",}

url = "https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do"

r = requests.post(url, data=payload)

hana = pd.read_html(r.text)[0]

# error는 미래에 사용이못할수도있다
# Out:
# C:\Users\Playdata2\AppData\Local\Temp\ipykernel_14900\3788413160.py:21: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   hana = pd.read_html(r.text)[0]

# %%
hana
# Out:
#                  통화       현찰                              송금          T/C 사실때  \
#                  통화     사실 때            파실 때            보낼 때     받을 때 T/C 사실때
#                  통화       환율 Spread       환율 Spread     보낼 때     받을 때 T/C 사실때
# 0            미국 USD  1371.59   1.75  1324.41   1.75  1361.20  1334.80     0.0
# 1      일본 JPY (100)   904.18   1.75   873.08   1.75   897.33   879.93     0.0
# 2            유로 EUR  1489.69   1.99  1431.57   1.99  1475.23  1446.03     0.0
# 3            중국 CNY   195.26   5.00   176.68   5.00   187.82   184.12     0.0
# 4            홍콩 HKD   175.58   1.97   168.80   1.97   173.91   170.47     0.0
# 5            태국 THB    38.66   5.00    34.62   6.00    37.18    36.46     0.0
# 6            대만 TWD    47.60  13.10    37.89  10.00     0.00     0.00     0.0
# 7           필리핀 PHP    26.29  10.00    21.95   8.20    24.13    23.67     0.0
# 8          싱가포르 SGD  1019.78   1.99   980.00   1.99  1009.88   989.90     0.0
# ...

# %%
kbo_df.columns #1차원은 series 2차원은 dataframe
kbo_df.columns.values #numpy
# Out:
# array(['선수명', '등번호', '생년월일', '포지션', '신장/체중', '경력', '입단 계약금', '연봉', '지명순위',
#        '입단년도', 'team'], dtype=object)

# %%
hana.columns #multiindex
# Out:
# MultiIndex([(       '통화',        '통화',        '통화'),
#             (       '현찰',      '사실 때',        '환율'),
#             (       '현찰',      '사실 때',    'Spread'),
#             (       '현찰',      '파실 때',        '환율'),
#             (       '현찰',      '파실 때',    'Spread'),
#             (       '송금',      '보낼 때',      '보낼 때'),
#             (       '송금',      '받을 때',      '받을 때'),
#             (  'T/C 사실때',   'T/C 사실때',   'T/C 사실때'),
#             ('외화 수표 파실때', '외화 수표 파실때', '외화 수표 파실때'),
#             (   '매매 기준율',    '매매 기준율',    '매매 기준율'),
#             (    '환가 료율',     '환가 료율',     '환가 료율'),
#             (   '미화 환산율',    '미화 환산율',    '미화 환산율')],
#            )

# %%
for x in hana.columns:
    print(x[0]+"_"+x[1])
# Out:
# 통화_통화
# 현찰_사실 때
# 현찰_사실 때
# 현찰_파실 때
# 현찰_파실 때
# 송금_보낼 때
# 송금_받을 때
# T/C 사실때_T/C 사실때
# 외화 수표 파실때_외화 수표 파실때
# 매매 기준율_매매 기준율
# 환가 료율_환가 료율
# 미화 환산율_미화 환산율

# %%
"_".join(x) #합쳐서 string으로 return
"_".join(x[:2]) #합쳐서 string으로 return
# Out:
# '미화 환산율_미화 환산율'

# %%
"와".join(['서찬웅','권시은','기석광'])
# Out:
# '서찬웅와권시은와기석광'

# %%
[x[0]+"_"+x[1] for x in hana.columns]
# Out:
# ['통화_통화',
#  '현찰_사실 때',
#  '현찰_사실 때',
#  '현찰_파실 때',
#  '현찰_파실 때',
#  '송금_보낼 때',
#  '송금_받을 때',
#  'T/C 사실때_T/C 사실때',
#  '외화 수표 파실때_외화 수표 파실때',
#  '매매 기준율_매매 기준율',
#  '환가 료율_환가 료율',
#  '미화 환산율_미화 환산율']

# %%
# DataFrame.coluns ->컬럶이름 series 형태로 출력
# DataFrame.colums=[] ->개수일치하기
hana.columns=["_".join(x[:2]) for x in hana.columns] #colums과 list개수 일치하기 길면힘들기에 rename이라는것이 있다 일괄적으로

# %%
hana.columns
# Out:
# Index(['통화_통화', '현찰_사실 때', '현찰_사실 때', '현찰_파실 때', '현찰_파실 때', '송금_보낼 때',
#        '송금_받을 때', 'T/C 사실때_T/C 사실때', '외화 수표 파실때_외화 수표 파실때', '매매 기준율_매매 기준율',
#        '환가 료율_환가 료율', '미화 환산율_미화 환산율'],
#       dtype='object')

# %%
# 순서 교체할떄
hana2=hana[['미화 환산율_미화 환산율','통화_통화', '현찰_사실 때', '현찰_사실 때', '현찰_파실 때', '현찰_파실 때', '송금_보낼 때',
       '송금_받을 때', 'T/C 사실때_T/C 사실때', '외화 수표 파실때_외화 수표 파실때', '매매 기준율_매매 기준율',
       '환가 료율_환가 료율']]

# %%
hana['통화_통화'] #data type series
# Out:
# 0              미국 USD
# 1        일본 JPY (100)
# 2              유로 EUR
# 3              중국 CNY
# 4              홍콩 HKD
# 5              태국 THB
# 6              대만 TWD
# 7             필리핀 PHP
# 8            싱가포르 SGD
# 9              호주 AUD
# 10      베트남 VND (100)
# 11             영국 GBP
# 12            캐나다 CAD
# 13          말레이시아 MYR
# 14            러시아 RUB
# 15          남아공화국 ZAR
# 16           노르웨이 NOK
# 17           뉴질랜드 NZD
# 18            덴마크 DKK
# 19            멕시코 MXN
# 20             몽골 MNT
# 21            바레인 BHD
# 22          방글라데시 BDT
# 23            브라질 BRL
# 24           브루나이 BND
# 25        사우디아라비아 SAR
# 26           스리랑카 LKR
# 27            스웨덴 SEK
# 28            스위스 CHF
# 29      아랍에미리트공화국 AED
# 30            알제리 DZD
# 31             오만 OMR
# 32            요르단 JOD
# 33           이스라엘 ILS
# 34            이집트 EGP
# 35             인도 INR
# 36    인도네시아 IDR (100)
# 37             체코 CZK
# 38             칠레 CLP
# 39          카자흐스탄 KZT
# 40            카타르 QAR
# ...

# %%
hana[['통화_통화']] #data type dataframe list로 주기에
# Out:
#               통화_통화
# 0            미국 USD
# 1      일본 JPY (100)
# 2            유로 EUR
# 3            중국 CNY
# 4            홍콩 HKD
# 5            태국 THB
# 6            대만 TWD
# 7           필리핀 PHP
# 8          싱가포르 SGD
# 9            호주 AUD
# 10    베트남 VND (100)
# 11           영국 GBP
# 12          캐나다 CAD
# 13        말레이시아 MYR
# 14          러시아 RUB
# 15        남아공화국 ZAR
# 16         노르웨이 NOK
# 17         뉴질랜드 NZD
# 18          덴마크 DKK
# 19          멕시코 MXN
# 20           몽골 MNT
# 21          바레인 BHD
# 22        방글라데시 BDT
# 23          브라질 BRL
# 24         브루나이 BND
# 25      사우디아라비아 SAR
# 26         스리랑카 LKR
# 27          스웨덴 SEK
# 28          스위스 CHF
# 29    아랍에미리트공화국 AED
# 30          알제리 DZD
# 31           오만 OMR
# 32          요르단 JOD
# 33         이스라엘 ILS
# 34          이집트 EGP
# 35           인도 INR
# 36  인도네시아 IDR (100)
# 37           체코 CZK
# 38           칠레 CLP
# 39        카자흐스탄 KZT
# 40          카타르 QAR
# 41           케냐 KES
# 42         콜롬비아 COP
# 43         쿠웨이트 KWD
# ...

# %%
hana
# Out:
#               통화_통화  현찰_사실 때  현찰_사실 때  현찰_파실 때  현찰_파실 때  송금_보낼 때  송금_받을 때  \
# 0            미국 USD  1371.59     1.75  1324.41     1.75  1361.20  1334.80
# 1      일본 JPY (100)   904.18     1.75   873.08     1.75   897.33   879.93
# 2            유로 EUR  1489.69     1.99  1431.57     1.99  1475.23  1446.03
# 3            중국 CNY   195.26     5.00   176.68     5.00   187.82   184.12
# 4            홍콩 HKD   175.58     1.97   168.80     1.97   173.91   170.47
# 5            태국 THB    38.66     5.00    34.62     6.00    37.18    36.46
# 6            대만 TWD    47.60    13.10    37.89    10.00     0.00     0.00
# 7           필리핀 PHP    26.29    10.00    21.95     8.20    24.13    23.67
# 8          싱가포르 SGD  1019.78     1.99   980.00     1.99  1009.88   989.90
# 9            호주 AUD   902.26     1.97   867.40     1.97   893.67   875.99
# 10    베트남 VND (100)     6.02    11.80     4.76    11.80     5.44     5.34
# 11           영국 GBP  1739.15     1.97  1671.97     1.97  1722.61  1688.51
# ...

# %%
def get_exchange(code_="USD", date_=None):
    return hana.loc[hana['통화_통화'].str.find(f"{code_.upper()}") >-1,'현찰_파실 때'].iloc[0,0]

# %%
get_exchange("jpy")
#스케일 업 스케일 아웃 하둡이 대표적인 스케일아웃 병렬처리
# 코드가 느리면 컴퓨터병렬
# Out:
# 873.08

# %%
#tmpInqStrDt inqStrDt
payload = {"ajax": "true",
"curCd": "",
"tmpInqStrDt": "2024-01-02",
"pbldDvCd": "0",
"pbldSqn": "",
"hid_key_data": "",
"inqStrDt": "20240102",
"inqKindCd": "1",
"hid_enc_data": "",
"requestTarget": "searchContentDiv",}

url = "https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do"

r = requests.post(url, data=payload)

exchange = pd.read_html(r.text)[0]
# Out:
# C:\Users\Playdata2\AppData\Local\Temp\ipykernel_14900\1998136866.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(r.text)[0]

# %%
exchange
# Out:
#                  통화       현찰                              송금          T/C 사실때  \
#                  통화     사실 때            파실 때            보낼 때     받을 때 T/C 사실때
#                  통화       환율 Spread       환율 Spread     보낼 때     받을 때 T/C 사실때
# 0            미국 USD  1334.96   1.75  1289.04   1.75  1324.80  1299.20     0.0
# 1      일본 JPY (100)   941.20   1.75   908.84   1.75   934.08   915.96     0.0
# 2            유로 EUR  1464.83   1.99  1407.67   1.99  1450.61  1421.89     0.0
# 3            중국 CNY   192.65   5.00   174.31   5.00   185.31   181.65     0.0
# 4            홍콩 HKD   171.17   1.97   164.57   1.97   169.54   166.20     0.0
# 5            태국 THB    40.17   5.00    35.97   6.00    38.64    37.88     0.0
# 6            대만 TWD    47.92  13.10    38.14  10.00     0.00     0.00     0.0
# 7           필리핀 PHP    25.96  10.00    21.67   8.20    23.83    23.37     0.0
# 8          싱가포르 SGD  1008.40   1.99   969.06   1.99   998.61   978.85     0.0
# ...

# %%
payload['tmpInqStrDt']
# Out:
# '2024-01-02'

# %%
# def get_exchange(code_="USD", date_=None):
#     """
#         code_ =통화코드
#             ex) USD
#         date- = ex) '2024-01-02'
#         #tmpInqStrDt inqStrDt
#     """
#     payload = {"ajax": "true",
#         "curCd": "",
#         "pbldDvCd": "0",
#         "pbldSqn": "",
#         "hid_key_data": "",
#         "inqKindCd": "1",
#         "hid_enc_data": "",
#         "requestTarget": "searchContentDiv",}
#     payload['tmpInqStrDt'] = date_
#     payload['inqStrDt'] = date_.replace("-","")
#     url = "https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do"
#     r = requests.post(url, data=payload)
#     exchange = pd.read_html(r.text)[0]
#     exchange.columns=["_".join(x[:2]) for x in exchange.columns]
#     return exchange.loc[exchange['통화_통화'].str.find(f"{code_.upper()}") >-1,'현찰_파실 때'].iloc[0,0]
# 왜 1324이 뜨는거지

# %%
from datetime import date,datetime
import requests
import pandas as pd
def get_exchange(code_="USD", date_=None):
    """
     code_ = 통화코드 
         예) USD 
     date_ = 예) '2024-01-02'
    """
    payload = {"ajax": "true",
            "curCd": "",
            "pbldDvCd": "0",
            "pbldSqn": "",
            "hid_key_data": "",
            "inqKindCd": "1",
            "hid_enc_data": "",
            "requestTarget": "searchContentDiv",}
    #날짜 형식 검사
    try:
        datetime.strptime(date_,"%Y-%m-%d")
    except:
        print("값 확인해!!") #return -1 값이 없으므로
        # return -1
        date_=str(date.today())  #오늘날짜가져오기
    
    
    
    payload['tmpInqStrDt'] = date_
    payload['inqStrDt'] = date_.replace("-", "")
    url = "https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do"
    r = requests.post(url, data=payload)
    exchange = pd.read_html(r.text)[0]
    exchange.columns = ["_".join(x[:2]) for x in exchange.columns]
    return exchange.loc[exchange['통화_통화'].str.find(f"{code_.upper()}") > -1, '현찰_파실 때'].iloc[0,0]
# 웹으로하면 restapi 
# 이제 이거 내장함수로 변환
# Out:
#   Cell In[226], line 3
#     iport pandas as pd
#           ^
# SyntaxError: invalid syntax

# %%
get_exchange("USD")
# Out:
# 값 확인해!!
# C:\Users\Playdata2\AppData\Local\Temp\ipykernel_14900\681949652.py:29: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(r.text)[0]
# 1329.43

# %%
from datetime import date,datetime

# %%
datetime.strptime("2024-04-02","%Y-%m-%d")]
#dir로 확인
# C:\Users\Playdata2>wsl
# jotaesik@Playdata:/mnt/c/Users$ cd ~
# jotaesik@Playdata:~$ python3
# >>> import hana
# >>> hana.get_exchange("usd","2024-04-03")
# error 발생시 exit() 입력하
# jotaesik@Playdata:~$ pip install lxml
# 다시실행하면잘된다
# 리눅스 \\wsl.localhost\Ubuntu-22.04\home\jotaesik\.local\lib\python3.10\site-packages 
# 내pc에 있는 hana.py
# Out:
# datetime.datetime(2024, 4, 2, 0, 0)

# %%
# unpacking
# _ dummy data
a1, *a2= "A B C D".split()
a2
# Out:
# ['B', 'C', 'D']

# %%
import os
# os.walk generator 값 3개를 변화해서 출
f = open("./file.txt", "w", encoding="utf-8")
for roots, dirs, files in os.walk("c:/windows"):
    
    for file in files:
        f.write(f"{roots}/{file}\n")
f.close()
#파일생성오류 왜 빈폴더지?

# %%
os.listdir("./") #타겟폴어듸 파일만보
# Out:
# ['.bash_history',
#  '.conda',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.ssh',
#  '.vscode',
#  '.wdm',
#  '2024.04.04_se.ipynb',
#  '2024.04.05.u.ipynb',
#  '20240404_final.ipynb',
#  '20240404_selenium.ipynb',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'file.txt',
#  'hana.py',
#  'IntelGraphicsProfiles',
#  'kbo.pkl',
#  'kbo_detail.pkl',
#  'Links',
#  'Local Settings',
#  'miniconda3',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{395ff14c-47f6-11ee-8582-84aabd131caf}.TM.blf',
#  'NTUSER.DAT{395ff14c-47f6-11ee-8582-84aabd131caf}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{395ff14c-47f6-11ee-8582-84aabd131caf}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
# ...

# %%
code_master={x1.split()[0] : x1.split()[1] for x1 in hana['통화_통화']}

# %%
code_master
# Out:
# 'BDT'

# %%
kbo2 = kbo_df[kbo_df.연봉.str.find("달러")>-1 ].copy()

# %%
"{:,}".format(get_exchange('usd','2024-01-02')*500000)
# Out:
# C:\Users\Playdata2\AppData\Local\Temp\ipykernel_14900\681949652.py:29: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(r.text)[0]
# '644,520,000.0'

# %%
kbo2.head(3)
# Out:
#     선수명     등번호            생년월일         포지션        신장/체중  \
# 33  산체스   No.34   1997년 04월 11일    투수(좌투좌타)   178cm/99kg
# 84   페냐   No.20   1990년 01월 25일    투수(우투우타)   188cm/99kg
# 85  페라자   No.30   1998년 11월 10일   외야수(우투양타)   175cm/88kg
#
#                                경력     입단 계약금         연봉         지명순위   입단년도  \
# 33      베네수엘라 Fernando Ramirez(고)              500000달러   23 한화 자유선발   23한화
# 84      도미니카 Crecimiento Credy(고)   100000달러   650000달러   22 한화 자유선발   22한화
# 85   베네수엘라 San Isidro Labrador(고)   200000달러   600000달러   24 한화 자유선발   24한화
#
#       team
# 33  한화 이글스
# 84  한화 이글스
# 85  한화 이글스

# %%
kbo3 = kbo_df[~kbo_df.연봉.str.find("달러")>-1 ].copy()

# %%
# kbo2 
# warning 숨기기 
import warnings
warnings.filterwarnings(action='ignore')

from hana import get_exchange
# 환율을 2024-01-02 원화로 바꿔주기 만원단위 컬럼: 원화(만원) 연봉
kbo2 = kbo_df[kbo_df.연봉.str.find("달러")>-1 ].copy()
kbo3 = kbo_df[~kbo_df.연봉.str.find("달러")>-1 ].copy()
# kbo2.shape
# kbo3.shape
exchange = get_exchange("usd","2024-01-02")
kbo2['연봉']=kbo2.연봉.apply(lambda x : int(x[:-2])*exchange)/10000
kbo2['연봉']= [str(int(x2.split("달러")[0])*get_exchange('usd','2024-01-02')/10000)+"만원" for x2 in tqdm(kbo2.연봉)]
kbo2
# 에러끼는법 정당한 에러
# Out:
#        선수명     등번호            생년월일         포지션         신장/체중  \
# 33     산체스   No.34   1997년 04월 11일    투수(좌투좌타)    178cm/99kg
# 84      페냐   No.20   1990년 01월 25일    투수(우투우타)    188cm/99kg
# 85     페라자   No.30   1998년 11월 10일   외야수(우투양타)    175cm/88kg
# 124     네일   No.40   1993년 02월 08일    투수(우투우타)    193cm/83kg
# 134  소크라테스   No.30   1992년 09월 06일   외야수(좌투좌타)    188cm/93kg
# 170    크로우   No.12   1994년 09월 09일    투수(우투우타)   185cm/108kg
# 194     더거   No.33   1995년 07월 03일    투수(우투우타)    183cm/83kg
# 218   에레디아   No.27   1991년 01월 31일   외야수(좌투우타)    178cm/88kg
# 219   엘리아스   No.55   1988년 08월 01일    투수(좌투좌타)    185cm/92kg
# 283   데이비슨   No.24   1991년 03월 26일   내야수(우투우타)   190cm/104kg
# 340   카스타노   No.20   1994년 09월 17일    투수(좌투좌타)   190cm/104kg
# 342     하트   No.30   1992년 11월 23일    투수(좌투좌타)    196cm/90kg
# 388     엔스   No.34   1991년 05월 16일    투수(좌투좌타)    185cm/95kg
# 389    오스틴   No.23   1993년 10월 14일   내야수(우투우타)    183cm/97kg
# ...

# %%
#bit 연산자 and-> % or->| not->~
kbo3.isnull().sum() #결측치확인
# Out:
# 선수명       0
# 등번호       0
# 생년월일      0
# 포지션       0
# 신장/체중     0
# 경력        0
# 입단 계약금    0
# 연봉        0
# 지명순위      0
# 입단년도      0
# team      0
# dtype: int64

# %%
# Out:
#      선수명      등번호            생년월일         포지션         신장/체중  \
# 0    강재민      No.   1997년 04월 03일    투수(우언우타)    180cm/89kg
# 1    권광민    No.17   1997년 12월 12일   외야수(좌투좌타)   189cm/102kg
# 2    권동욱    No.02   2001년 01월 08일   외야수(우투우타)    173cm/85kg
# 3     권현   No.111   2005년 02월 23일   외야수(우투우타)    182cm/88kg
# 4    김강민     No.9   1982년 09월 13일   외야수(우투우타)    182cm/87kg
# ..   ...      ...             ...         ...           ...
# 839  한민우    No.96   1999년 04월 27일    투수(좌투좌타)    177cm/82kg
# 840  한차현    No.59   1998년 11월 30일    투수(우투우타)    180cm/80kg
# 841  홍현빈    No.31   1997년 08월 29일   외야수(우투좌타)    174cm/70kg
# 842  황의준   No.103   2002년 04월 06일   외야수(우투좌타)    185cm/95kg
# 843  황재균    No.10   1987년 07월 28일   내야수(우투우타)    183cm/96kg
#
#                                    경력    입단 계약금         연봉  \
# 0                     양덕초-마산중-용마고-단국대    8000만원    14500만원
# 1                       서울청구초-홍은중-장충고               3300만원
# 2                     가동초-휘문중-배명고-동국대               3000만원
# ...

# %%
kbo3[kbo3.연봉.apply(lambda x : len(x)<3)].loc[37,'연봉']  #스펭스키도 데이터 있는걸로암
# Out:
# ' '

# %%
kbo4 = kbo3[~kbo3.연봉.apply(lambda x : len(x)<3)]
kbo4.연봉 = kbo4.연봉.apply(lambda x : int(x[:-2]))

# %%
pd.concat([kbo2,kbo4]).shape #colum명이 똑같해야함
final = pd.concat([kbo2,kbo4])
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 837 entries, 33 to 843
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   선수명     837 non-null    object
#  1   등번호     837 non-null    object
#  2   생년월일    837 non-null    object
#  3   포지션     837 non-null    object
#  4   신장/체중   837 non-null    object
#  5   경력      837 non-null    object
#  6   입단 계약금  837 non-null    object
#  7   연봉      837 non-null    float64
#  8   지명순위    837 non-null    object
#  9   입단년도    837 non-null    object
#  10  team    837 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 78.5+ KB

# %%
final.groupby(['team'])[['연봉']].mean().sort_values(by=['연봉'], ascending=False)
final.groupby(['team'])[['연봉']].mean().sort_values(by=['연봉'], ascending=False).to_csv("./result.csv",encoding='utf-8-sig')

# %%
# #ftp 파일즐라 깔기

# C:\Users\Playdata2>wsl
# jotaesik@Playdata:~$ cd workspace
# jotaesik@Playdata:~$ sudo service ssh status
# jotaesik@Playdata:~$ sudo service ssh stop
# jotaesik@Playdata:~$ sudo service ssh restart
# jotaesik@Playdata:~/workspace$ sudo service ssh start
#  * Starting OpenBSD Secure Shell server sshd                                                                     [ OK ]
# jotaesik@Playdata:~/workspace$ ifconfig
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 172.27.155.113  netmask 255.255.240.0  broadcast 172.27.159.255
#         inet6 fe80::215:5dff:fefe:8f84  prefixlen 64  scopeid 0x20<link>
#         ether 00:15:5d:fe:8f:84  txqueuelen 1000  (Ethernet)
#         RX packets 24  bytes 4708 (4.7 KB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 11  bytes 866 (866.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 0  bytes 0 (0.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 0  bytes 0 (0.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

# jotaesik@Playdata:~/workspace$

# %%
# putty접속
# login as: jotaesik
# jotaesik@172.27.155.113's password:
# Welcome to Ubuntu 22.04.3 LTS (GNU/Linux 5.10.16.3-microsoft-standard-WSL2 x86_64)

#  * Documentation:  https://help.ubuntu.com
#  * Management:     https://landscape.canonical.com
#  * Support:        https://ubuntu.com/advantage

# Last login: Thu Apr  4 22:13:33 2024 from 172.27.146.75
# jotaesik@Playdata:~$

# %%
# 공개키 개인키
# wsl로 들어가면 ubuntu에서 리눅수
# 미니콘다 conda는 윈도우
 # ssh-keygen -t rsa

# %%
# jotaesik@Playdata:~/workspace$ cd ~/.ssh
# jotaesik@Playdata:~/.ssh$ ll
# total 32
# drwx------  2 jotaesik jotaesik  4096 Apr  5 15:33 ./
# drwxr-x--- 12 jotaesik jotaesik 12288 Apr  5 12:23 ../
# -rw-------  1 jotaesik jotaesik  2602 Apr  5 15:33 id_rsa
# -rw-r--r--  1 jotaesik jotaesik   571 Apr  5 15:33 id_rsa.pub
# -rw-------  1 jotaesik jotaesik   978 Apr  4 22:07 known_hosts
# -rw-r--r--  1 jotaesik jotaesik   142 Apr  4 22:07 known_hosts.old
# vim autokeys
# chmod 600
# 클러스터때무에 비밀번홀 없이 들어가려고

# %%
# 파일질라들어가서 새 사이트만들기 ->SFTP 호스트입력 사용자입력 비밀번호 입력 26PORT
# 이름생년월일 파일옮기기 오른쪽이서버
# jotaesik@Playdata:~$ sudo apt install unzip
# unzip ./이름_생년_성별_10000.zip -d ./data

# %%
# 파일 분리하여 저장 
# 남성 -> 남성 폴더에 저장 
# 여성 -> 여성 폴더에 저장 

# 남성, 여성 컬럼으로 DataFrame으로 
# .to_csv("./report.csv", index=False, 
# dataframe단어붙이기 excel에서 열거면 -sig
# '1', '3' 
# '2', '4' 
 # putty로 리눅스들어가기 jupyter notebook

# %%
import shutil

# %%
# 파일 복사 
import shutil
shutil.move("./result.csv", "/home/jotaesik")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\miniconda3\envs\encore_py39\lib\shutil.py:825, in move(src, dst, copy_function)
#     824 try:
# --> 825     os.rename(src, real_dst)
#     826 except OSError:
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: './result.csv' -> '/home/jotaesik'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[434], line 3
#       1 # 파일 복사
#       2 import shutil
# ----> 3 shutil.move("./result.csv", "/home/jotaesik")
#
# File ~\miniconda3\envs\encore_py39\lib\shutil.py:845, in move(src, dst, copy_function)
#     843         rmtree(src)
#     844     else:
# --> 845         copy_function(src, real_dst)
#     846         os.unlink(src)
#     847 return real_dst
#
# ...

# %%
#팀별 평균 중앙값 분산 연봉 계산

final.groupby(['team'])[['연봉']].agg(['mean','median','var'])
# Out:
#                     연봉
#                   mean  median           var
# team
# KIA 타이거즈  12398.912195  3900.0  3.993841e+08
# KT 위즈     14893.903448  3500.0  9.362636e+08
# LG 트윈스    16643.091892  3600.0  1.276533e+09
# NC 다이노스   10992.902472  3200.0  3.680201e+08
# SSG 랜더스   15763.145679  3100.0  8.756286e+08
# 고양 히어로즈    2956.521739  3000.0  2.716601e+05
# 두산 베어스    13040.944578  3300.0  6.093241e+08
# 롯데 자이언츠   14764.155294  3900.0  7.617914e+08
# 삼성 라이온즈   13852.809412  4100.0  7.941813e+08
# 키움 히어로즈   15447.871186  4500.0  7.191543e+08
# 한화 이글스    13584.067416  3500.0  9.880097e+08

# %%
 # kbo4 = kbo3[~kbo3.연봉.apply(lambda x : len(x)<3)] #파이썬은 나누기는 뭄조건 실

# %%
kbo3['연봉']=kbo2.연봉.apply(lambda x : int(x[:-2])*exchange)/10000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[414], line 1
# ----> 1 kbo3['연봉']=kbo2.연봉.apply(lambda x : int(x[:-2])*exchange)/10000
#
# File ~\miniconda3\envs\encore_py39\lib\site-packages\pandas\core\series.py:4908, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
# -> 4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
#    4915     ).apply()
#
# ...

# %%
kbo2.sort_values(by=['연봉'], ascending=False)
# Out:
#        선수명     등번호            생년월일         포지션         신장/체중  \
# 502    후라도   No.75   1996년 01월 30일    투수(우투우타)   187cm/109kg
# 218   에레디아   No.27   1991년 01월 31일   외야수(좌투우타)    178cm/88kg
# 837   쿠에바스   No.32   1990년 10월 14일    투수(우투양타)    188cm/98kg
# 705    맥키넌   No.24   1994년 12월 15일   내야수(우투우타)   188cm/101kg
# 793    벤자민   No.43   1993년 07월 26일    투수(좌투좌타)    188cm/95kg
# 617     반즈   No.28   1995년 10월 01일    투수(좌투좌타)    189cm/91kg
# 750     코너   No.52   1996년 01월 24일    투수(우투우타)    188cm/95kg
# 389    오스틴   No.23   1993년 10월 14일   내야수(우투우타)    183cm/97kg
# 413     켈리    No.3   1989년 10월 04일    투수(우투우타)    191cm/98kg
# 546   알칸타라   No.43   1992년 12월 04일    투수(우투우타)   193cm/100kg
# 542    브랜든   No.48   1994년 06월 03일    투수(좌투좌타)    190cm/81kg
# 219   엘리아스   No.55   1988년 08월 01일    투수(좌투좌타)    185cm/92kg
# 84      페냐   No.20   1990년 01월 25일    투수(우투우타)    188cm/99kg
# 194     더거   No.33   1995년 07월 03일    투수(우투우타)    183cm/83kg
# ...

# %%
# kbo2 
# 환율을 2024-01-02 원화로 바꿔주기 만원단위 컬럼: 원화(만원) 연봉
from hana import get_exchange
from tqdm import tqdm
# a = [str(int(x2.split("달러")[0])*get_exchange('usd','2024-01-02')/10000)+"만원" for x2 in tqdm(kbo2.연봉)]
kbo2['연봉']= [str(int(x2.split("달러")[0])*get_exchange('usd','2024-01-02')/10000)+"만원" for x2 in tqdm(kbo2.연봉)]
    #print(int(x2.split("달러")[0])*get_exchange('usd','2024-01-02')/10000)
    # break
    # break
    # x2=str(get_exchange('usd','2024-01-02')*int(x2[:len(x2)-2])/10000)+"만원"
    # remake_money.append(x2)
    # break
kbo2
# Out:
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]C:\Users\Playdata2\hana.py:32: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(r.text)[0]
#
#
#
#   3%|██▊                                                                                | 1/30 [00:00<00:22,  1.29it/s]C:\Users\Playdata2\hana.py:32: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(r.text)[0]
#
#
#
# ...

# %%
# kbo2['연봉']=a

# %%
kbo2
# Out:
#        선수명     등번호            생년월일         포지션         신장/체중  \
# 33     산체스   No.34   1997년 04월 11일    투수(좌투좌타)    178cm/99kg
# 84      페냐   No.20   1990년 01월 25일    투수(우투우타)    188cm/99kg
# 85     페라자   No.30   1998년 11월 10일   외야수(우투양타)    175cm/88kg
# 124     네일   No.40   1993년 02월 08일    투수(우투우타)    193cm/83kg
# 134  소크라테스   No.30   1992년 09월 06일   외야수(좌투좌타)    188cm/93kg
# 170    크로우   No.12   1994년 09월 09일    투수(우투우타)   185cm/108kg
# 194     더거   No.33   1995년 07월 03일    투수(우투우타)    183cm/83kg
# 218   에레디아   No.27   1991년 01월 31일   외야수(좌투우타)    178cm/88kg
# 219   엘리아스   No.55   1988년 08월 01일    투수(좌투좌타)    185cm/92kg
# 283   데이비슨   No.24   1991년 03월 26일   내야수(우투우타)   190cm/104kg
# 340   카스타노   No.20   1994년 09월 17일    투수(좌투좌타)   190cm/104kg
# 342     하트   No.30   1992년 11월 23일    투수(좌투좌타)    196cm/90kg
# 388     엔스   No.34   1991년 05월 16일    투수(좌투좌타)    185cm/95kg
# 389    오스틴   No.23   1993년 10월 14일   내야수(우투우타)    183cm/97kg
# ...

# %%
# kbo2 
# 환율을 2024-01-02 원화로 바꿔주기 만원단위 컬럼: 원화(만원) 연봉
kbo2 = kbo_df[kbo_df.연봉.str.find("달러")>-1 ].copy()
from hana import get_exchange
from tqdm import tqdm
remake_money=[]
for x2 in tqdm(kbo2['연봉']):
    # kbo2['연봉']=get_exchange('usd','2024-01-02')*(kbo2.연봉.split("달")[0])/10000    
    # print(str(kbo2.연봉)[:len(str(kbo2.연봉))-5])
    #달러숫자만 추출
    # x2.iloc[x2,7].strip()
        # print(x2)
        # print(type(x2))
        # print(x2[:len(x2)-2])
        # print(get_exchange('usd','2024-01-02'))
        # print(type(get_exchange('usd','2024-01-02')))
    #print(get_exchange('usd','2024-01-02')*int(x2[:len(x2)-2])/10000)
    x2=str(get_exchange('usd','2024-01-02')*int(x2[:len(x2)-2])/10000)+"만원"
    remake_money.append(x2)
    # break
# Out:
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]C:\Users\Playdata2\hana.py:32: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(r.text)[0]
#   3%|██▊                                                                                | 1/30 [00:00<00:20,  1.42it/s]C:\Users\Playdata2\hana.py:32: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(r.text)[0]
# ...

# %%
kbo2['연봉']=remake_money

# %%
kbo2.head(3)
# Out:
#     선수명     등번호            생년월일         포지션        신장/체중  \
# 33  산체스   No.34   1997년 04월 11일    투수(좌투좌타)   178cm/99kg
# 84   페냐   No.20   1990년 01월 25일    투수(우투우타)   188cm/99kg
# 85  페라자   No.30   1998년 11월 10일   외야수(우투양타)   175cm/88kg
#
#                                경력     입단 계약금         연봉         지명순위   입단년도  \
# 33      베네수엘라 Fernando Ramirez(고)             64452.0만원   23 한화 자유선발   23한화
# 84      도미니카 Crecimiento Credy(고)   100000달러  83787.6만원   22 한화 자유선발   22한화
# 85   베네수엘라 San Isidro Labrador(고)   200000달러  77342.4만원   24 한화 자유선발   24한화
#
#       team
# 33  한화 이글스
# 84  한화 이글스
# 85  한화 이글스
