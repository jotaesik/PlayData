# %% [markdown]
# #서울역승차하자
# #역이름도 통합하고 서울역(150) 뒤에 코드명
# #할인이라는 컬럼이 없을수도있으니 없는건 제거하고
# #국토지리정보원-히트맵
# #openai 일론머스크 azure ms
# 프롬프트튜닝
# 할루시네이션-헛소리-rag방식 rag llm
# 20240402_teacher 파일참고

# %%
# 내가한거
# import requests
# import pandas as pd
# url = "https://www.starbucks.co.kr/store/getStore.do?r=I2X7AGFWCX"
# payload = {"in_biz_cds":"0",
# "in_scodes":"0",
# "ins_lat":"37.4923734",
# "ins_lng":"127.0272751",
# "search_text":"",
# "p_sido_cd":"01",
# "p_gugun_cd":"",
# "isError":"true",
# "in_distance":"0",
# "in_biz_cd":"",
# "iend":"1000",
# "searchType":"C",
# "set_date":"",
# "rndCod":"7KDFYXRUIU",
# "all_store":"0",
# "T03":"0",
# "T01":"0",
# "T27":"0",
# "T12":"0",
# "T09":"0",
# "T30":"0",
# "T05":"0",
# "T22":"0",
# "T21":"0",
# "T10":"0",
# "T36":"0",
# "T43":"0",
# "T48":"0",
# "Z9999":"0",
# "P02":"0",
# "P10":"0",
# "P50":"0",
# "P20":"0",
# "P60":"0",
# "P30":"0",
# "P70":"0",
# "P40":"0",
# "P80":"0",
# "whcroad_yn":"0",
# "P90":"0",
# "P01":"0",
# "new_bool":"0",}
# r = requests.post(url, data=payload)
# data = r.json()
# name_list = []
# lat_list=[]
# lot_list=[]
# adr_list=[]
# len(data['list'])
# df = pd.DataFrame({"s_name" : name_list , "addr" : adr_list ,"lat" : lat_list , "lot" : lot_list})
# for x in data['list']:
#     name_list.append(x['s_name'])
#     adr_list.append(x["addr"])
#     lat_list.append(x['lat'])
#     lot_list.append(x['lot'])
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# # import seaborn as sns
# plt.pcolor(df)

# %%
import requests
import pandas as pd
url = "https://www.starbucks.co.kr/store/getStore.do?r=U1GAWL"
payload = {"in_biz_cds": "0","in_scodes": "0","ins_lat": "37.4909","ins_lng": "127.0231","search_text": "","p_sido_cd": "01","p_gugun_cd": "","in_distance": "0","isError": "true","in_biz_cd": "","iend": "1000","searchType": "C","set_date": "","rndCod": "1EMUI1PR4R","all_store": "0","T03": "0","T01": "0","T27": "0","T12": "0","T09": "0","T30": "0","T05": "0","T22": "0","T21": "0","T10": "0","T36": "0","T43": "0","T48": "0","Z9999": "0","P02": "0","P10": "0","P50": "0","P20": "0","P60": "0","P30": "0","P70": "0","P40": "0","P80": "0","whcroad_yn": "0","P90": "0","P01": "0","new_bool": "0",}
df = pd.DataFrame(requests.post(url, data=payload).json()['list'])
# pd.set_option('display.max_columns', None)
star_df = df[['addr', 's_name', 'tel', 'fax', 'gugun_name', 'defaultimage', 'lat', 'lot']].copy()

# %%
star_df
# Out:
#                                                   addr   s_name        tel  \
# 0                           서울특별시 강남구 역삼동 721-13 아레나빌딩  역삼아레나빌딩  1522-3232
# 1                             서울특별시 강남구 논현동 142-2 정일빌딩   논현역사거리  1522-3232
# 2                              서울특별시 강남구 논현동 18-4 성일빌딩  신사역성일빌딩  1522-3232
# 3                            서울특별시 강남구 역삼동 648-22 동찬빌딩   국기원사거리  1522-3232
# 4                               서울특별시 강남구 대치동 599 대원빌딩   대치재경빌딩  1522-3232
# ..                                                 ...      ...        ...
# 607                                서울특별시 중랑구 면목동 617-2     사가정역  1522-3232
# 608                          서울특별시 중랑구 상봉동 100-2,3,4번지      상봉역  1522-3232
# 609                  서울특별시 중랑구 묵동 169-12 로프트원 태릉입구역 1층       묵동  1522-3232
# 610  서울특별시 중랑구 망우동 618 B1~1층일부 B101,B102,101,102  4개호실      양원역  1522-3232
# 611                 서울특별시 중랑구 중화동 306-68 중화동 HS빌딩 1,2층      중화역  1522-3232
#
#               fax gugun_name  \
# 0     02-568-3763        강남구
# ...

# %%
star_df.value_counts(["gugun_name"])
# Out:
# gugun_name
# 강남구           91
# 중구            53
# 서초구           48
# 영등포구          41
# 종로구           40
# 마포구           36
# 송파구           36
# 강서구           27
# 용산구           24
# 서대문구          22
# 광진구           19
# 양천구           17
# 강동구           17
# 성북구           15
# 구로구           14
# 은평구           14
# 노원구           14
# 성동구           14
# 동대문구          13
# 금천구           13
# 관악구           12
# 동작구           11
# 중랑구            8
# 도봉구            7
# 강북구            6
# Name: count, dtype: int64

# %%
star_df.value_counts(["gugun_name"]).count()
# Out:
# 25

# %%
pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="cartodb positron")

# %%
# del map map 지우기

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# ?folium.Map
# Out:
# Init signature:
# folium.Map(
#     location: Optional[Sequence[float]] = None,
#     width: Union[str, float] = '100%',
#     height: Union[str, float] = '100%',
#     left: Union[str, float] = '0%',
#     top: Union[str, float] = '0%',
#     position: str = 'relative',
#     tiles: Union[str, folium.raster_layers.TileLayer, NoneType] = 'OpenStreetMap',
#     attr: Optional[str] = None,
#     min_zoom: int = 0,
#     max_zoom: int = 18,
#     zoom_start: int = 10,
#     min_lat: int = -90,
#     max_lat: int = 90,
#     min_lon: int = -180,
#     max_lon: int = 180,
#     max_bounds: bool = False,
#     crs: str = 'EPSG3857',
#     control_scale: bool = False,
#     prefer_canvas: bool = False,
#     no_touch: bool = False,
#     disable_3d: bool = False,
#     png_enabled: bool = False,
#     zoom_control: bool = True,
#     font_size: str = '1rem',
#     **kwargs: Union[str, float, bool, Sequence, dict, NoneType],
# )
# Docstring:
# Create a Map with Folium and Leaflet.js
#
# ...

# %%
import json
# geo_str= json.load( open("./skorea_municipalities_geo_simple.json", 'r', encoding='utf-8')) #구로 되어있음-전국데이터

# %%
# geo_str

# %%
geo_str = requests.get("https://t1.daumcdn.net/cfile/tistory/272C224C58B4BD540B").json()

# %%
# geo_str
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '강동구',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.11519584981606, 37.557533180704915],
#       [127.16683184366129, 37.57672487388627],
#       [127.18408792330152, 37.55814280369575],
#       [127.16530984307447, 37.54221851258693],
#       [127.14672806823502, 37.51415680680291],
#       [127.12123165719615, 37.52528270089],
#       [127.1116764203608, 37.540669955324965],
#       [127.11519584981606, 37.557533180704915]]]}},
#   {'type': 'Feature',
#    'id': '송파구',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0690698130372, 37.522279423505026],
#       [127.10087519791962, 37.524841220167055],
# ...

# %%
# dir(map)

# %%
data = star_df.value_counts("gugun_name")

# %%
data
# Out:
# gugun_name
# 강남구     91
# 중구      53
# 서초구     48
# 영등포구    41
# 종로구     40
# 마포구     36
# 송파구     36
# 강서구     27
# 용산구     24
# 서대문구    22
# 광진구     19
# 양천구     17
# 강동구     17
# 성북구     15
# 구로구     14
# 은평구     14
# 노원구     14
# 성동구     14
# 동대문구    13
# 금천구     13
# 관악구     12
# 동작구     11
# 중랑구      8
# 도봉구      7
# 강북구      6
# Name: count, dtype: int64

# %%
data.values
# Out:
# array([91, 53, 48, 41, 40, 36, 36, 27, 24, 22, 19, 17, 17, 15, 14, 14, 14,
#        14, 13, 13, 12, 11,  8,  7,  6])

# %%
data.index
# Out:
# Index(['강남구', '중구', '서초구', '영등포구', '종로구', '마포구', '송파구', '강서구', '용산구', '서대문구',
#        '광진구', '양천구', '강동구', '성북구', '구로구', '은평구', '노원구', '성동구', '동대문구', '금천구',
#        '관악구', '동작구', '중랑구', '도봉구', '강북구'],
#       dtype='object', name='gugun_name')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#             count
# gugun_name
# 강남구            91
# 중구             53
# 서초구            48
# 영등포구           41
# 종로구            40
# 마포구            36
# 송파구            36
# 강서구            27
# 용산구            24
# 서대문구           22
# 광진구            19
# 양천구            17
# 강동구            17
# 성북구            15
# 구로구            14
# 은평구            14
# 노원구            14
# 성동구            14
# 동대문구           13
# 금천구            13
# 관악구            12
# 동작구            11
# 중랑구             8
# 도봉구             7
# 강북구             6

# %%
df.index
# Out:
# Index(['강남구', '중구', '서초구', '영등포구', '종로구', '마포구', '송파구', '강서구', '용산구', '서대문구',
#        '광진구', '양천구', '강동구', '성북구', '구로구', '은평구', '노원구', '성동구', '동대문구', '금천구',
#        '관악구', '동작구', '중랑구', '도봉구', '강북구'],
#       dtype='object', name='gugun_name')

# %%
df['count'].head()
# Out:
# gugun_name
# 강남구     91
# 중구      53
# 서초구     48
# 영등포구    41
# 종로구     40
# Name: count, dtype: int64

# %%
df
#index 올리는법
df.reset_index(inplace=True)

# %%
df
# Out:
#    gugun_name  count
# 0         강남구     91
# 1          중구     53
# 2         서초구     48
# 3        영등포구     41
# 4         종로구     40
# 5         마포구     36
# 6         송파구     36
# 7         강서구     27
# 8         용산구     24
# 9        서대문구     22
# 10        광진구     19
# 11        양천구     17
# 12        강동구     17
# 13        성북구     15
# 14        구로구     14
# 15        은평구     14
# 16        노원구     14
# 17        성동구     14
# 18       동대문구     13
# 19        금천구     13
# 20        관악구     12
# 21        동작구     11
# 22        중랑구      8
# 23        도봉구      7
# 24        강북구      6

# %%
df.columns
# Out:
# Index(['gugun_name', 'count'], dtype='object')

# %%
df.rename(columns={"count" :"value"},inplace=True)

# %%
df
# Out:
#    gugun_name  value
# 0         강남구     91
# 1          중구     53
# 2         서초구     48
# 3        영등포구     41
# 4         종로구     40
# 5         마포구     36
# 6         송파구     36
# 7         강서구     27
# 8         용산구     24
# 9        서대문구     22
# 10        광진구     19
# 11        양천구     17
# 12        강동구     17
# 13        성북구     15
# 14        구로구     14
# 15        은평구     14
# 16        노원구     14
# 17        성동구     14
# 18       동대문구     13
# 19        금천구     13
# 20        관악구     12
# 21        동작구     11
# 22        중랑구      8
# 23        도봉구      7
# 24        강북구      6

# %%
geo_str
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '강동구',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.11519584981606, 37.557533180704915],
#       [127.16683184366129, 37.57672487388627],
#       [127.18408792330152, 37.55814280369575],
#       [127.16530984307447, 37.54221851258693],
#       [127.14672806823502, 37.51415680680291],
#       [127.12123165719615, 37.52528270089],
#       [127.1116764203608, 37.540669955324965],
#       [127.11519584981606, 37.557533180704915]]]}},
#   {'type': 'Feature',
#    'id': '송파구',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0690698130372, 37.522279423505026],
#       [127.10087519791962, 37.524841220167055],
# ...

# %%
m = folium.Choropleth(geo_str, 
                  data = data,
                  columns=['gugun_name', 'value'],
                  fill_color="PuRd",
                  key_on="feature.id").add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df
# Out:
#    gugun_name  value
# 0         강남구     91
# 1          중구     53
# 2         서초구     48
# 3        영등포구     41
# 4         종로구     40
# 5         마포구     36
# 6         송파구     36
# 7         강서구     27
# 8         용산구     24
# 9        서대문구     22
# 10        광진구     19
# 11        양천구     17
# 12        강동구     17
# 13        성북구     15
# 14        구로구     14
# 15        은평구     14
# 16        노원구     14
# 17        성동구     14
# 18       동대문구     13
# 19        금천구     13
# 20        관악구     12
# 21        동작구     11
# 22        중랑구      8
# 23        도봉구      7
# 24        강북구      6

# %%
# ?folium.Choropleth

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for idx, row in star_df[["s_name","lat","lot"]].iterrows(): #series형태로들어감
    # break
    folium.Marker([row.lat,row.lot],popup=row.s_name).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
row['s_name'] # row.s_name
# Out:
# '중화역'

# %%
map.save("./starbuck_loaction.html")
