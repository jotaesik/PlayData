# %%
import requests
import zipfile #zipfile c말고도 java로 된 파이썬 json
import os
import pandas as pd
import shutil 
import pickle
from bs4 import BeautifulSoup as BS
from tqdm import tqdm
dosi_url="https://cu.bgfretail.com/store/list.do?category=store"
r=requests.get(dosi_url)
bs = BS(r.text)
cu_dosi=[]
for x in bs.findAll("option"):
    # print(x.text)
    if x.text!="선택":
        cu_dosi.append(x.text)
gogun_url="https://cu.bgfretail.com/store/GugunList.do"
cu_gogun=[]
cu_payload={"pageIndex":" 1",
"listType":" ",
"jumpoCode":" ",
"jumpoLotto":" ",
"jumpoToto":" ",
"jumpoCash":" ",
"jumpoHour":" ",
"jumpoCafe":" ",
"jumpoDelivery":" ",
"jumpoBakery":" ",
"jumpoFry":" ",
"jumpoMultiDevice":" ",
"jumpoPosCash":" ",
"jumpoBattery":" ",
"jumpoAdderss":" ",
"jumpoSido":" 경기도",
"jumpoGugun":" ",
"jumpodong":" ",
"user_id":" ",
"sido":" 경기도",
"Gugun":" ",
"jumpoName":" ",}
for i in tqdm(range(len(cu_dosi))):
        cu_payload["jumpoSido"]=cu_dosi[i]
        cu_payload["sido"]=cu_dosi[i]
        test=requests.post(gogun_url,data=cu_payload)
        # print(test.json())
        temp=test.json()
        temp1=temp["GugunList"]
        for i in range(len(temp1)):
            # print(temp1[i]['CODE_NAME'])
            cu_gogun.append(temp1[i]['CODE_NAME'])
cu_dong=[]
dong_url="https://cu.bgfretail.com/store/DongList.do"
dong_payload={
    "pageIndex": "1",
"listType": "",
"jumpoCode": "",
"jumpoLotto": "",
"jumpoToto": "",
"jumpoCash": "",
"jumpoHour": "",
"jumpoCafe": "",
"jumpoDelivery": "",
"jumpoBakery": "",
"jumpoFry": "",
"jumpoMultiDevice": "",
"jumpoPosCash": "",
"jumpoBattery": "",
"jumpoAdderss": "",
"jumpoSido": "경기도",
"jumpoGugun": "구리시",
"jumpodong": "",
"user_id": "",
"sido": "경기도",
"Gugun": "구리시",
"jumpoName": ""}
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 18/18 [00:05<00:00,  3.53it/s]

# %%
for j in tqdm(range(len(cu_dosi))):
    for k in range(len(cu_gogun)):
        dong_payload["jumpoSido"]=cu_dosi[j]
        dong_payload["sido"]=cu_dosi[j]
        dong_payload["jumpoGugun"]=cu_gogun[k]
        dong_payload["Gugun"]=cu_gogun[k]
        test1=requests.post(dong_url,data=dong_payload)
        # print(test.json())
        # temp=test1.json()
        # print(temp)
        temp1=temp["GugunList"]
        for i in range(len(temp1)):
            # print(temp1[i]['CODE_NAME'])
            cu_gogun.append(temp1[i]['CODE_NAME'])
        # break
        
        # for i in range(len(temp1)):
        #     # print(temp1[i]['CODE_NAME'])
        #     cu_gogun.append(temp1[i]['CODE_NAME'])
# Out:
#   0%|                                                                                            | 0/18 [00:21<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[113], line 7
#       5 dong_payload["jumpoGugun"]=cu_gogun[k]
#       6 dong_payload["Gugun"]=cu_gogun[k]
# ----> 7 test1=requests.post(dong_url,data=dong_payload)
#       8 # print(test.json())
#       9 # temp=test1.json()
#      10 # print(temp)
#      11 temp1=temp["GugunList"]
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# ...

# %%
cu_gogun
# Out:
# ['가평군',
#  '고양시',
#  '과천시',
#  '광명시',
#  '광주시',
#  '구리시',
#  '군포시',
#  '김포시',
#  '남양주시',
#  '동두천시',
#  '부천시',
#  '성남시',
#  '수원시',
#  '시흥시',
#  '안산시',
#  '안성시',
#  '안양시',
#  '양주시',
#  '양평군',
#  '여주시',
#  '연천군',
#  '오산시',
#  '용인시',
#  '의왕시',
#  '의정부시',
#  '이천시',
#  '파주시',
#  '평택시',
#  '포천시',
#  '하남시',
#  '화성시',
#  '강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구',
#  '거제시',
#  '거창군',
#  '고성군',
#  '김해시',
#  '남해군',
#  '밀양시',
#  '사천시',
#  '산청군',
#  '양산시',
#  '의령군',
#  '진주시',
#  '창녕군',
#  '창원시',
#  '통영시',
#  '하동군',
#  '함안군',
#  '함양군',
#  '합천군',
#  '강서구',
#  '금정구',
#  '기장군',
#  '남구',
#  '동구',
#  '동래구',
#  '부산진구',
#  '북구',
#  '사상구',
#  '사하구',
#  '서구',
#  '수영구',
#  '연제구',
#  '영도구',
#  '중구',
#  '해운대구',
#  '강화군',
#  '계양구',
#  '남구',
#  '남동구',
#  '동구',
#  '미추홀구',
#  '미추홀구숭의동',
#  '부평구',
#  '서구',
# ...

# %%
# temp1=temp["GugunList"]
# print(temp1)
# for i in range(len(temp1)):
    # print(temp1[i]['CODE_NAME'])
# temp2=temp["CODE_NAME"]
# total.append(pd.DataFrame(eval(r2.json())['results']))
# Out:
# 가평군
# 고양시
# 과천시
# 광명시
# 광주시
# 구리시
# 군포시
# 김포시
# 남양주시
# 동두천시
# 부천시
# 성남시
# 수원시
# 시흥시
# 안산시
# 안성시
# 안양시
# 양주시
# 양평군
# 여주시
# 연천군
# 오산시
# 용인시
# 의왕시
# 의정부시
# 이천시
# 파주시
# 평택시
# 포천시
# 하남시
# 화성시

# %%
print(cu_dosi)
# Out:
# ['경기도', '서울특별시', '경상남도', '부산광역시', '인천광역시', '충청남도', '경상북도', '강원도', '충청북도', '제주특별자치도', '대구광역시', '전라북도', '전라남도', '대전광역시', '광주광역시', '울산광역시', '세종특별자치시', '강원특별자치도']
