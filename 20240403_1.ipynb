# %%
import requests

# %%
url = "https://www.genie.co.kr/chart/top200"

# %%
head = {"User-Agent": \
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.62"}

# %%
r = requests.get(url, headers=head)

# %%
from bs4 import BeautifulSoup

# %%
bs = BeautifulSoup(r.text)

# %%
import os
from tqdm import tqdm
import re
p = re.compile("[0-9]+")
lyrics_url = "https://www.genie.co.kr/detail/songInfo?xgnm={}"
if not os.path.isdir("./lyrics"):
    os.mkdir("./lyrics")
for x in tqdm(bs.find("div", {'class': \
                          "music-list-wrap"}).findAll("td", {"class" : "info"})):

    title = x.find("a", class_="title ellipsis").text.strip()
    artist = x.find("a", class_="artist ellipsis").text
    f = open(f"./lyrics/{artist}_{title}.txt", "w", encoding='utf-8')
    #print(f"{artist}-{title}.txt")
    r3 = requests.get(lyrics_url.format(p.findall(str(x))[0]),headers=head)
    f.write(BeautifulSoup(r3.text).find("pre", id="pLyrics").text.strip())
    f.close()
# Out:
# 100%|██████████| 50/50 [00:07<00:00,  7.01it/s]

# %%
# Out:
# '105260468'

# %%
x
# Out:
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105260468','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 나는 아픈 건 딱 질색이니까</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80632010');return false;">(여자)아이들</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105260468');" type="button">외</button>
# <ul class="list" id="RelationArtist_105260468"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84718499');return false;">2</a>
# </td>

# %%
r2 = requests.get("https://namu.wiki/w/%ED%94%84%EB%A1%9C%EB%93%80%EC%8A%A4%20101/%EC%B0%B8%EA%B0%80%EC%9E%90")

# %%
import re
p = re.compile("[가-힣]{3}")

# %%
p.findall(r2.text)
# Out:
# ['프로듀',
#  '참가자',
#  '나무위',
#  '나무위',
#  '나무위',
#  '프로듀',
#  '참가자',
#  '나무위',
#  '강경원',
#  '강미나',
#  '강시라',
#  '보컬그',
#  '데뷔한',
#  '강시원',
#  '강시현',
#  '강예빈',
#  '권은빈',
#  '나무위',
#  '나무위',
#  '문서로',
#  '여기에',
#  '프로듀',
#  '참가자',
#  '권한이',
#  '부족합',
#  '로그인',
#  '사용자',
#  '합니다',
#  '문서의',
#  '확인하',
#  '바랍니',
#  '권한이',
#  '부족한',
#  '아래의',
#  '버튼으',
#  '요청을',
#  '생성할',
#  '있습니',
#  '도움말',
#  '프로듀',
#  '참가자',
#  '아이콘',
#  '프로듀',
#  '프로듀',
#  '가나다',
#  '순으로',
#  '되어있',
#  '문서에',
#  '대용량',
#  '자료가',
#  '많으므',
#  '사용시',
#  '데이터',
#  '잔량을',
#  '확인하',
#  '열람하',
#  '권장한',
#  '프로듀',
#  '프로듀',
#  '화이트',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '참가자',
#  '프로듀',
#  '참가자',
#  '참가자',
#  '프로듀',
#  '순위표',
#  '순위표',
#  '아이오',
#  '아이오',
#  '프로듀',
#  '프로듀',
#  '갤러리',
#  '갤러리',
#  '프로듀',
#  '갤러리',
#  '프로듀',
#  '프로듀',
#  '화이트',
#  '프로듀',
#  '프로듀',
#  '참가자',
#  '펼치기',
#  '프로듀',
#  '참가자',
#  '참가자',
#  '아이오',
#  '아이오',
#  '스탠바',
#  '강미나',
#  '프로듀',
#  '강미나',
#  '김도연',
#  '위키미',
#  '프로듀',
#  '김도연',
#  '김세정',
#  '프로듀',
#  '김세정',
#  '김소혜',
#  '프로듀',
#  '김소혜',
#  '프로듀',
#  '김청하',
#  '우주소',
#  '프로듀',
#  '유연정',
#  '임나영',
#  '프로듀',
#  '임나영',
#  '전소미',
#  '프로듀',
#  '전소미',
#  '정채연',
#  '프로듀',
#  '정채연',
#  '주결경',
#  '프로듀',
#  '주결경',
#  '최유정',
#  '프로듀',
#  '최유정',
#  '프로듀',
#  '최종회',
#  '데뷔조',
#  '탈락자',
#  '강시라',
#  '강시라',
#  '기희현',
#  '프로듀',
#  '기희현',
#  '김나영',
#  '프로듀',
#  '김나영',
#  '프로듀',
#  '김소희',
#  '박소연',
#  '박소연',
#  '윤채경',
#  '프로듀',
#  '윤채경',
#  '프로듀',
#  '이수현',
#  '이해인',
#  '프로듀',
#  '이해인',
#  '전소연',
#  '프로듀',
#  '전소연',
#  '정은우',
#  '프로듀',
#  '정은우',
#  '한혜리',
#  '프로듀',
#  '한혜리',
#  '프로듀',
#  '방출자',
#  '강예빈',
#  '프로듀',
#  '강예빈',
#  '권은빈',
#  '프로듀',
#  '권은빈',
#  '프로듀',
#  '김다니',
#  '공원소',
#  '김서경',
#  '김주나',
#  '김주나',
#  '김형은',
#  '박시연',
#  '프로듀',
#  '박시연',
#  '성혜민',
#  '성혜민',
#  '안예슬',
#  '안예슬',
#  '이수민',
#  '이수민',
#  '허찬미',
#  '프로듀',
#  '허찬미',
#  '황인선',
#  '프로듀',
#  '황인선',
#  '프로듀',
#  '방출자',
#  '강경원',
#  '강경원',
#  '강시원',
#  '강시원',
#  '강시현',
#  '프로듀',
#  '김민경',
#  '김민정',
#  '김민정',
#  '김민지',
#  '프로듀',
#  '김시현',
#  '김연경',
#  '김연경',
#  '김태하',
#  '프로듀',
#  '김태하',
#  '프로듀',
#  '박가을',
#  '박세희',
#  '박세희',
#  '박하이',
#  '박하이',
#  '박해영',
#  '심채은',
#  '아리요',
#  '아리요',
#  '오서정',
#  '오서정',
#  '유수아',
#  '권잎새',
#  '윤서형',
#  '이윤서',
#  '이진희',
#  '이진희',
#  '임정민',
#  '임정민',
#  '위키미',
#  '프로듀',
#  '정해림',
#  '조시윤',
#  '프로듀',
#  '조시윤',
#  '추예진',
#  '추예진',
#  '황수연',
#  '황수연',
#  '황아영',
#  '황아영',
#  '프로듀',
#  '방출자',
#  '김다정',
#  '김다정',
#  '김도희',
#  '김도희',
#  '김미소',
#  '김미소',
#  '김보선',
#  '김아현',
#  '김설아',
#  '김솔이',
#  '프로듀',
#  '김수현',
#  '라운드',
#  '가능한',
#  '참가자',
#  '였으나',
#  '조작으',
#  '김시현',
#  '김시현',
#  '김우정',
#  '김윤지',
#  '김윤지',
#  '김자연',
#  '김자연',
#  '김지성',
#  '프로듀',
#  '김지성',
#  '김홍은',
#  '김홍은',
#  '남수진',
#  '시오리',
#  '문현주',
#  '문현주',
#  '프로듀',
#  '박민지',
#  '방준희',
#  '서혜린',
#  '라운드',
#  '가능한',
#  '참가자',
#  '였으나',
#  '조작으',
#  '신혜현',
#  '안유미',
#  '안유미',
#  '오한아',
#  '윤유담',
#  '윤유담',
#  '위키미',
#  '프로듀',
#  '이서정',
#  '이세흔',
#  '프로듀',
#  '이세흔',
#  '이수현',
#  '이채린',
#  '최유빈',
#  '최은빈',
#  '캐서린',
#  '편강윤',
#  '편강윤',
#  '한지연',
#  '함려원',
#  '프로듀',
#  '함예지',
#  '허재이',
#  '황리유',
#  '황세영',
#  '하차한',
#  '참가자',
#  '김하윤',
#  '마은진',
#  '마은진',
#  '임경하',
#  '임효선',
#  '라운드',
#  '가능한',
#  '참가자',
#  '였으나',
#  '조작으',
#  '강경원',
#  '강경원',
#  '강미나',
#  '프로듀',
#  '강미나',
#  '강시라',
#  '강시라',
#  '강시원',
#  '강시원',
#  '강시현',
#  '강예빈',
#  '프로듀',
#  '강예빈',
#  '권은빈',
#  '권은빈',
#  '기희현',
#  '프로듀',
#  '기희현',
#  '김나영',
#  '프로듀',
#  '김나영',
#  '프로듀',
#  '김다니',
#  '김다정',
#  '김다정',
#  '김도연',
#  '위키미',
#  '프로듀',
#  '김도연',
#  '김도희',
#  '김도희',
#  '김미소',
#  '김미소',
#  '김민경',
#  '프로듀',
#  '김민경',
#  '김민정',
#  '김민정',
#  '김민지',
#  '김보선',
#  '공원소',
#  '김서경',
#  '김아현',
#  '김설아',
#  '김세정',
#  '프로듀',
#  '김세정',
#  '김소혜',
#  '프로듀',
#  '김소혜',
#  '프로듀',
#  '김소희',
#  '김솔이',
#  '프로듀',
#  '김수현',
#  '프로듀',
#  '김시현',
#  '김시현',
#  '김시현',
#  '김연경',
#  '김연경',
#  '김우정',
#  '김윤지',
#  '김윤지',
#  '김자연',
#  '김자연',
#  '김주나',
#  '김주나',
#  '김지성',
#  '김지성',
#  '김청하',
#  '김태하',
#  '김태하',
#  '김하윤',
#  '김형은',
#  '김홍은',
#  '김홍은',
#  '남수진',
#  '시오리',
#  '마은진',
#  '마은진',
#  '문현주',
#  '문현주',
#  '프로듀',
#  '박가을',
#  '프로듀',
#  '박민지',
#  '박세희',
#  '박세희',
#  '박소연',
#  '박소연',
#  '박시연',
#  '프로듀',
#  '박시연',
#  '박하이',
#  '박하이',
#  '박해영',
#  '방준희',
#  '방준희',
#  '서혜린',
#  '성혜민',
#  '성혜민',
#  '신혜현',
#  '심채은',
#  '아리요',
#  '아리요',
#  '안예슬',
#  '안예슬',
#  '안유미',
#  '안유미',
#  '오서정',
#  '오서정',
#  '오한아',
#  '유수아',
#  '우주소',
#  '프로듀',
#  '유연정',
#  '권잎새',
#  '윤서형',
#  '윤유담',
#  '윤유담',
#  '윤채경',
#  '프로듀',
#  '윤채경',
#  '위키미',
#  '프로듀',
#  '이서정',
#  '이세흔',
#  '프로듀',
#  '이세흔',
#  '이수민',
#  '이수민',
#  '이수현',
#  '프로듀',
#  '이수현',
#  '이윤서',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '프로듀',
#  '이진희',
#  '이진희',
#  '이채린',
#  '이해인',
#  '프로듀',
#  '이해인',
#  '임경하',
#  '임나영',
#  '프로듀',
#  '임나영',
#  '임정민',
#  '임정민',
#  '임효선',
#  '전소미',
#  '프로듀',
#  '전소미',
#  '전소연',
#  '프로듀',
#  '전소연',
#  '정은우',
#  '프로듀',
#  '정은우',
#  '정채연',
#  '프로듀',
#  '정채연',
#  '위키미',
#  '프로듀',
#  '정해림',
#  '조시윤',
#  '조시윤',
#  '주결경',
#  '프로듀',
#  '주결경',
#  '최유빈',
#  '최유정',
#  '최유정',
#  '최은빈',
#  '추예진',
#  '추예진',
#  '캐서린',
#  '편강윤',
#  '편강윤',
#  '한지연',
#  '한혜리',
#  '프로듀',
#  '한혜리',
#  '프리즘',
#  '함예지',
#  '허재이',
#  '허찬미',
#  '허찬미',
#  '황리유',
#  '황세영',
#  '황수연',
#  '황수연',
#  '황아영',
#  '황아영',
#  '황인선',
#  '프로듀',
#  '황인선',
#  '강경원',
#  '강경원',
#  '강경원',
#  '강미나',
#  '강미나',
#  '프로듀',
#  '강미나',
#  '강시라',
#  '강시라',
#  '강시라',
#  '보컬그',
#  '데뷔한',
#  '강시원',
#  '강시원',
#  '강시원',
#  '강시현',
#  '강시현',
#  '강예빈',
#  '강예빈',
#  '프로듀',
#  '강예빈',
#  '권은빈',
#  '권은빈',
#  '권은빈',
#  '기희현',
#  '기희현',
#  '프로듀',
#  '기희현',
#  '김나영',
#  '김나영',
#  '프로듀',
#  '김나영',
#  '김다니',
#  '프로듀',
#  '김다니',
#  '김다정',
#  '김다정',
#  '김다정',
#  '김도연',
#  '김도연',
#  '위키미',
#  '프로듀',
#  '김도연',
#  '김도희',
#  '김도희',
#  '김도희',
#  '열아홉',
#  '믿어주',
#  '김도희',
#  '소속사',
#  '블레싱',
#  '혈액형',
#  '강아지',
#  '시키기',
#  '이어달',
#  '한마디',
#  '발전하',
#  '모습을',
#  '보여드',
#  '리겠습',
#  '순위표',
#  '미공개',
#  '영상평',
#  '평가내',
#  '달려라',
#  '팀득표',
#  '개인순',
#  '부문별',
#  '프로듀',
#  '자기소',
#  '히든박',
#  '블레싱',
#  '유리구',
#  '트윙클',
#  '멤버로',
#  '활동했',
#  '김미소',
#  '김미소',
#  '김미소',
#  '김민경',
#  '김민경',
#  '프로듀',
#  '김민경',
#  '김민정',
#  '김민정',
#  '김민정',
#  '김민지',
#  '김민지',
#  '김보선',
#  '김보선',
#  '노력파',
#  '김보선',
#  '소속사',
#  '혈액형',
#  '겨울에',
#  '성대모',
#  '걸스힙',
#  '방송댄',
#  '애교로',
#  '한마디',
#  '앞으로',
#  '발전하',
#  '보여드',
#  '릴게요',
#  '파이팅',
#  '순위표',
#  '미공개',
#  '영상평',
#  '평가내',
#  '바우바',
#  '메인래',
#  '팀득표',
#  '개인순',
#  '부문별',
#  '프로듀',
#  '자기소',
#  '히든박',
#  '데뷔한',
#  '아는동',
#  '멤버였',
#  '탈퇴하',
#  '연습생',
#  '돌아갔',
#  '소속사',
#  '모집을',
#  '김보선',
#  '소속사',
#  '듯하다',
#  '대표곡',
#  '뮤비는',
#  '댄스팀',
#  '활동을',
#  '예명으',
#  '싱글을',
#  '발매하',
#  '데뷔했',
#  '유튜브',
#  '근황올',
#  '근황올',
#  '채널에',
#  '출연해',
#  '근황을',
#  '알렸다',
#  '프로듀',
#  '롯데월',
#  '캐스트',
#  '롯데월',
#  '캐스트',
#  '건축자',
#  '회사에',
#  '경리로',
#  '입사했',
#  '낮에는',
#  '회사원',
#  '밤에는',
#  '활동하',
#  '크리에',
#  '이티브',
#  '커먼즈',
#  '라이선',
#  '문서의',
#  '일부는',
#  '김보선',
#  '김보선',
#  '김보선',
#  '김보선',
#  '김보선',
#  '문서의',
#  '김보선',
#  '김보선',
#  '김보선',
#  '김보선',
#  '가져왔',
#  '습니다',
#  '김보선',
#  '김보선',
#  '크리에',
#  '이티브',
#  '커먼즈',
#  '라이선',
#  '문서의',
#  '일부는',
#  '문서에',
#  '가져왔',
#  '습니다',
#  '펼치기',
#  '김보선',
#  '김보선',
#  '김보선',
#  '김보선',
#  '김보선',
#  '문서의',
#  '김보선',
#  '김보선',
#  '김보선',
#  '김보선',
#  '김보선',
#  '김보선',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '문서의',
#  '김서경',
#  '공원소',
#  '김서경',
#  '김설아',
#  '김아현',
#  '김설아',
#  '김세정',
#  '김세정',
#  '프로듀',
#  '김세정',
#  '김소혜',
#  '김소혜',
#  '프로듀',
#  '김소혜',
#  '김소희',
#  '프로듀',
#  '김소희',
#  '김솔이',
#  '김솔이',
#  '자이언',
#  '베이비',
#  '김솔이',
#  '소속사',
#  '블레싱',
#  '혈액형',
#  '인터넷',
#  '눈싸움',
#  '한마디',
#  '악물고',
#  '열심히',
#  '하겠습',
#  '순위표',
#  '미공개',
#  '영상평',
#  '평가내',
#  '핫스팟',
#  '서브보',
#  '팀득표',
#  '개인순',
#  '부문별',
#  '프로듀',
#  '자기소',
#  '히든박',
#  '블레싱',
#  '유리구',
#  '프로듀',
#  '참가자',
#  '번째로',
#  '어린데',
#  '번째로',
#  '초등학',
#  '때부터',
#  '였다고',
#  '엘리펀',
#  '엔터테',
#  '인먼트',
#  '소속이',
#  '김수현',
#  '프로듀',
#  '김수현',
#  '김시현',
#  '프로듀',
#  '김시현',
#  '김시현',
#  '김시현',
#  '김시현',
#  '김연경',
#  '김연경',
#  '김연경',
#  '김우정',
#  '김우정',
#  '백업은',
#  '김우정',
#  '소속사',
#  '해피페',
#  '혈액형',
#  '게임하',
#  '한마디',
#  '강남에',
#  '날까지',
#  '순위표',
#  '미공개',
#  '영상평',
#  '평가내',
#  '서브보',
#  '팀득표',
#  '개인순',
#  '부문별',
#  '프로듀',
#  '자기소',
#  '히든박',
#  '프로듀',
#  '해피페',
#  '엔터테',
#  '인먼트',
#  '연습생',
#  '프로듀',
#  '프로듀',
#  '사이트',
#  '공개되',
#  '걸그룹',
#  '포지션',
#  '포지션',
#  '소개명',
#  '백업은',
#  '지원사',
#  '송원근',
#  '송원근',
#  '달샤벳',
#  '달샤벳',
#  '솔직히',
#  '센터에',
#  '스티커',
#  '붙여주',
#  '센터는',
#  '특별한',
#  '것처럼',
#  '이렇게',
#  '만들어',
#  '버리니',
#  '솔직히',
#  '짜증나',
#  '솔직히',
#  '같아요',
#  '아무리',
#  '프로그',
#  '램이지',
#  '센터는',
#  '엄청난',
#  '이렇게',
#  '말씀하',
#  '시는데',
#  '솔직히',
#  '아니거',
#  '거기서',
#  '솔직히',
#  '짜증났',
#  '솔직히',
#  '같잖죠',
#  '솔직히',
#  '같잖아',
#  '뭐해요',
#  '프로듀',
#  '인터뷰',
#  '센터가',
#  '중요하',
#  '하는데',
#  '모르겠',
#  '솔직히',
#  '같잖다',
#  '요지의',
#  '발언을',
#  '센터란',
#  '역할은',
#  '무대에',
#  '서면서',
#  '동선이',
#  '바뀌는',
#  '걸그룹',
#  '그다지',
#  '중요시',
#  '역할은',
#  '아니었',
#  '심지어',
#  '프로그',
#  '결과를',
#  '센터를',
#  '공식적',
#  '아이오',
#  '아이조',
#  '센터가',
#  '자리에',
#  '고정되',
#  '비중도',
#  '센터에',
#  '몰아주',
#  '그러지',
#  '센터를',
#  '특전으',
#  '내놨냐',
#  '소리가',
#  '걸그룹',
#  '센터의',
#  '얘기가',
#  '나오게',
#  '프로듀',
#  '프로듀',
#  '직후에',
#  '보이는',
#  '타국의',
#  '걸그룹',
#  '시스템',
#  '의혹이',
#  '프로듀',
#  '센터란',
#  '의혹이',
#  '시스템',
#  '레퍼런',
#  '경쟁률',
#  '과열시',
#  '키려는',
#  '수단이',
#  '생각될',
#  '수밖에',
#  '무대만',
#  '무조건',
#  '센터였',
#  '센터에',
#  '않았던',
#  '방증이',
#  '연습해',
#  '김우정',
#  '센터의',
#  '이유가',
#  '단번에',
#  '보였고',
#  '연습생',
#  '센터의',
#  '이유에',
#  '상으로',
#  ...]
