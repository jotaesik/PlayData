# %%
import pickle
import pandas as pd

# %%
with open('./dacon_total_df_240504_00.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
df
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 0      ORDER_00329  PRODUCT_07734  SELLER_0146                 2017
# 1      ORDER_00616  PRODUCT_04278  SELLER_0914                 2017
# 2      ORDER_01235  PRODUCT_23369  SELLER_1445                 2017
# 3      ORDER_01293  PRODUCT_04377  SELLER_2603                 2017
# 4      ORDER_02078  PRODUCT_21531  SELLER_2660                 2017
# ...            ...            ...          ...                  ...
# 90188  ORDER_87982  PRODUCT_29370  SELLER_0335                 2019
# 90189  ORDER_88004  PRODUCT_02102  SELLER_1628                 2019
# 90190  ORDER_88021  PRODUCT_22041  SELLER_1230                 2019
# 90191  ORDER_88035  PRODUCT_02524  SELLER_1627                 2019
# 90192  ORDER_88059  PRODUCT_08954  SELLER_0612                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# ...

# %%
df.columns
# Out:
# Index(['Order_id', 'Product_id', 'Seller_id', 'Order_purchase_year',
#        'Order_purchase_month', 'Review_id', 'Review_score',
#        'Review_creation_date', 'Review_answer_timestamp', 'Price',
#        'Freight_value', 'Customer_id', 'Order_status',
#        'Order_purchase_timestamp', 'Order_delivered_carrier_date',
#        'Order_delivered_customer_date', 'Order_estimated_delivery_date',
#        'Payment_type', 'Payment_installments', 'Product_category_name',
#        'Customer_unique_id', 'Customer_zipcode_prefix', 'Customer_city',
#        'Customer_state', 'Seller_zipcode_prefix', 'Seller_city',
#        'Seller_state', 'order_count', 'Order_purchase_quarter', '순이익', '매출액',
#        'Customer_lat', 'Customer_lng', 'Seller_lat', 'Seller_lng', 'Distance',
#        'time_diff_purchase_carrier', 'time_diff_purchase_customer',
#        'time_diff_carrier_customer', 'time_diff_customer_delivery',
#        'time_diff_purchase_carrier_second',
# ...

# %%
df['day'] = df.Order_purchase_timestamp.dt.day

# %%
df
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 0      ORDER_00329  PRODUCT_07734  SELLER_0146                 2017
# 1      ORDER_00616  PRODUCT_04278  SELLER_0914                 2017
# 2      ORDER_01235  PRODUCT_23369  SELLER_1445                 2017
# 3      ORDER_01293  PRODUCT_04377  SELLER_2603                 2017
# 4      ORDER_02078  PRODUCT_21531  SELLER_2660                 2017
# ...            ...            ...          ...                  ...
# 90188  ORDER_87982  PRODUCT_29370  SELLER_0335                 2019
# 90189  ORDER_88004  PRODUCT_02102  SELLER_1628                 2019
# 90190  ORDER_88021  PRODUCT_22041  SELLER_1230                 2019
# 90191  ORDER_88035  PRODUCT_02524  SELLER_1627                 2019
# 90192  ORDER_88059  PRODUCT_08954  SELLER_0612                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# ...

# %%
df2 = df.groupby(['Order_purchase_year','Order_purchase_month','day','Customer_unique_id']).value_counts().reset_index()

# %%
df3 = df2[df2[['Order_purchase_year','Order_purchase_month','day','Customer_unique_id']].duplicated()]

# %%
df3
# Out:
#        Order_purchase_year  Order_purchase_month  day     Customer_unique_id  \
# 21                    2017                    10    4  CUSTOMER_Unique_19627
# 22                    2017                    10    4  CUSTOMER_Unique_19627
# 23                    2017                    10    4  CUSTOMER_Unique_19627
# 41                    2017                    10    4  CUSTOMER_Unique_44547
# 66                    2017                    10    4  CUSTOMER_Unique_84817
# ...                    ...                   ...  ...                    ...
# 90085                 2019                     7   26  CUSTOMER_Unique_39181
# 90143                 2019                     7   27  CUSTOMER_Unique_56790
# 90144                 2019                     7   27  CUSTOMER_Unique_56790
# 90151                 2019                     7   27  CUSTOMER_Unique_70772
# 90164                 2019                     7   28  CUSTOMER_Unique_72293
#
# ...

# %%
df3[df3[['Order_purchase_year', 'Order_purchase_month', 'day']].duplicated()]['Customer_unique_id']
# Out:
# 22       CUSTOMER_Unique_19627
# 23       CUSTOMER_Unique_19627
# 41       CUSTOMER_Unique_44547
# 66       CUSTOMER_Unique_84817
# 90       CUSTOMER_Unique_61228
#                  ...
# 90022    CUSTOMER_Unique_66663
# 90065    CUSTOMER_Unique_18520
# 90085    CUSTOMER_Unique_39181
# 90144    CUSTOMER_Unique_56790
# 90151    CUSTOMER_Unique_70772
# Name: Customer_unique_id, Length: 3572, dtype: object

# %%
# pd.options.display.max_columns = None

# %%
df3[df3.Customer_unique_id == 'CUSTOMER_Unique_39181'].Order_purchase_timestamp
# Out:
# 90085   2019-07-26 08:52:34
# Name: Order_purchase_timestamp, dtype: datetime64[ns]

# %%
df2
# Out:
#        Order_purchase_year  Order_purchase_month  day     Customer_unique_id  \
# 0                     2017                    10    3  CUSTOMER_Unique_06817
# 1                     2017                    10    3  CUSTOMER_Unique_09766
# 2                     2017                    10    3  CUSTOMER_Unique_16990
# 3                     2017                    10    3  CUSTOMER_Unique_17484
# 4                     2017                    10    3  CUSTOMER_Unique_47952
# ...                    ...                   ...  ...                    ...
# 90188                 2019                     7   30  CUSTOMER_Unique_33179
# 90189                 2019                     7   30  CUSTOMER_Unique_41777
# 90190                 2019                     7   30  CUSTOMER_Unique_45979
# 90191                 2019                     7   30  CUSTOMER_Unique_67226
# 90192                 2019                     7   30  CUSTOMER_Unique_78742
#
# ...

# %%
df
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 0      ORDER_00329  PRODUCT_07734  SELLER_0146                 2017
# 1      ORDER_00616  PRODUCT_04278  SELLER_0914                 2017
# 2      ORDER_01235  PRODUCT_23369  SELLER_1445                 2017
# 3      ORDER_01293  PRODUCT_04377  SELLER_2603                 2017
# 4      ORDER_02078  PRODUCT_21531  SELLER_2660                 2017
# ...            ...            ...          ...                  ...
# 90188  ORDER_87982  PRODUCT_29370  SELLER_0335                 2019
# 90189  ORDER_88004  PRODUCT_02102  SELLER_1628                 2019
# 90190  ORDER_88021  PRODUCT_22041  SELLER_1230                 2019
# 90191  ORDER_88035  PRODUCT_02524  SELLER_1627                 2019
# 90192  ORDER_88059  PRODUCT_08954  SELLER_0612                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# ...

# %%
df4 = df3[df3['order_count'] == 1]
df4
# Out:
#        Order_purchase_year  Order_purchase_month  day     Customer_unique_id  \
# 21                    2017                    10    4  CUSTOMER_Unique_19627
# 22                    2017                    10    4  CUSTOMER_Unique_19627
# 23                    2017                    10    4  CUSTOMER_Unique_19627
# 41                    2017                    10    4  CUSTOMER_Unique_44547
# 66                    2017                    10    4  CUSTOMER_Unique_84817
# ...                    ...                   ...  ...                    ...
# 90065                 2019                     7   26  CUSTOMER_Unique_18520
# 90085                 2019                     7   26  CUSTOMER_Unique_39181
# 90143                 2019                     7   27  CUSTOMER_Unique_56790
# 90151                 2019                     7   27  CUSTOMER_Unique_70772
# 90164                 2019                     7   28  CUSTOMER_Unique_72293
#
# ...

# %%
df5 = df4[~(df4['Order_purchase_timestamp'].duplicated()) & (df4.Customer_unique_id.duplicated())]
df5
# Out:
#        Order_purchase_year  Order_purchase_month  day     Customer_unique_id  \
# 280                   2018                     1    5  CUSTOMER_Unique_01758
# 290                   2018                     1    5  CUSTOMER_Unique_24930
# 291                   2018                     1    5  CUSTOMER_Unique_24930
# 292                   2018                     1    5  CUSTOMER_Unique_24930
# 293                   2018                     1    5  CUSTOMER_Unique_24930
# ...                    ...                   ...  ...                    ...
# 79079                 2019                     5   27  CUSTOMER_Unique_18160
# 80303                 2019                     6    4  CUSTOMER_Unique_16133
# 81168                 2019                     6    8  CUSTOMER_Unique_08656
# 81722                 2019                     6   11  CUSTOMER_Unique_00078
# 82694                 2019                     6   14  CUSTOMER_Unique_72018
#
# ...

# %%
df5[df5['Customer_unique_id'] == 'CUSTOMER_Unique_24930']
# Out:
#      Order_purchase_year  Order_purchase_month  day     Customer_unique_id  \
# 290                 2018                     1    5  CUSTOMER_Unique_24930
# 291                 2018                     1    5  CUSTOMER_Unique_24930
# 292                 2018                     1    5  CUSTOMER_Unique_24930
# 293                 2018                     1    5  CUSTOMER_Unique_24930
#
#         Order_id     Product_id    Seller_id     Review_id  Review_score  \
# 290  ORDER_24805  PRODUCT_24633  SELLER_1153  REVIEW_46599             5
# 291  ORDER_31693  PRODUCT_14098  SELLER_1153  REVIEW_44221             5
# 292  ORDER_72123  PRODUCT_11689  SELLER_1153  REVIEW_39683             5
# 293  ORDER_72952  PRODUCT_19938  SELLER_1153  REVIEW_22907             5
#
#     Review_creation_date  ... time_diff_purchase_carrier  \
# 290           2018-01-18  ...            6 days 00:34:04
# 291           2018-01-17  ...            6 days 01:08:14
# ...
