# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#데이터읽기
customers = pd.read_csv('./dacon_data/open/customers.csv')
locations = pd.read_csv('./dacon_data/open/locations.csv')
orders = pd.read_csv('./dacon_data/open/orders.csv')
order_items = pd.read_csv('./dacon_data/open/order_items.csv')
payments = pd.read_csv('./dacon_data/open/payments.csv')
products = pd.read_csv('./dacon_data/open/products.csv')
reviews = pd.read_csv('./dacon_data/open/reviews.csv')
sellers = pd.read_csv('./dacon_data/open/sellers.csv')

# %%
reviews.groupby(["Order_id"])["Review_score"].value_counts().unique()
# Out:
# array([1, 2, 3])

# %%
order_items.shape
# Out:
# (100557, 6)

# %%
temp = pd.merge(reviews,order_items, how='inner',on='Order_id')

# %%
temp.shape
# Out:
# (100415, 10)

# %%
# 데이터 merge하기
temp = pd.merge(reviews,order_items, how='inner',on='Order_id')
temp = pd.merge(temp,orders, how='inner',on='Order_id')
temp = pd.merge(temp,payments, how='inner',on='Order_id')
temp = pd.merge(temp,products, how='inner',on='Product_id')
temp = pd.merge(temp,customers, how='inner',on='Customer_id')
temp = pd.merge(temp,sellers, how='inner',on='Seller_id')

# %%
# locations[locations.Geolocation_zipcode_prefix==1037]
# 1037을 가진 우편번호가 여러개 존재함
# 여러개의 우편번호가 존재하므로 한우편번호에 있어서 평균을 구하기로함
locations_group_lat=locations.groupby(["Geolocation_zipcode_prefix"])["Geolocation_lat"].mean().reset_index()
locations_group_lng=locations.groupby(["Geolocation_zipcode_prefix"])["Geolocation_lng"].mean().reset_index()
locations_group =  pd.merge(locations_group_lat, locations_group_lng, how = 'inner', on="Geolocation_zipcode_prefix")

# %%
# 구입자의 위도경도
temp = pd.merge(temp, locations_group, left_on = 'Customer_zipcode_prefix', right_on = 'Geolocation_zipcode_prefix', how = 'inner')
temp = temp.rename(columns={'Geolocation_lat':'Customer_lat',"Geolocation_lng" : "Customer_lng" })

# %%
# 판매자의 위도경도
temp = pd.merge(temp, locations_group, left_on = 'Seller_zipcode_prefix', right_on = 'Geolocation_zipcode_prefix', how = 'inner')
temp = temp.rename(columns={'Geolocation_lat':'Seller_lat',"Geolocation_lng" : "Seller_lng" })

# %%
# 중복되는 구매자,판매자 우편번호 드랍
temp = temp.drop(["Geolocation_zipcode_prefix_x","Geolocation_zipcode_prefix_y"],axis=1)

# %%
# date 타입으로 변환
temp['Order_purchase_timestamp']=pd.to_datetime(temp['Order_purchase_timestamp'])
temp['Order_delivered_carrier_date']=pd.to_datetime(temp['Order_delivered_carrier_date'])
temp['Order_delivered_customer_date']=pd.to_datetime(temp['Order_delivered_customer_date'])
temp['Order_estimated_delivery_date']=pd.to_datetime(temp['Order_estimated_delivery_date'])
# temp[['Order_delivered_carrier_date','Order_delivered_customer_date',"Order_purchase_timestamp"]] = temp[['Order_delivered_carrier_date','Order_delivered_customer_date',"Order_purchase_timestamp"]].apply(pd.to_datetime)

# %%
# temp의 시계열이 datetype으로 바뀌었는지 확인
# temp.info()
# Order_purchase_timestamp : 구매 시간
# Order_delivered_carrier_date : 물류 처리 시간
# Order_delivered_customer_date : 실제 배송 날짜
# Order_estimated_delivery_date : 기대 배송 날짜

# 구매할때부터 물류처리할때까지 걸리는 시간
temp["time_diff_purchase_carrier"] = temp["Order_delivered_carrier_date"] - temp["Order_purchase_timestamp"]
# 구매할때부터 실제배송할때까지 걸리는 시간
temp["time_diff_purchase_customer"] = temp["Order_delivered_customer_date"] - temp["Order_purchase_timestamp"]
# 물류처리할때부터 실제배송할때까지 걸리는 시간
temp["time_diff_carrier_customer"] = temp["Order_delivered_customer_date"] - temp["Order_delivered_carrier_date"]
# 기대배송날짜와 실제배송날짜의 차이
temp["time_diff_customer_delivery"]= temp['Order_estimated_delivery_date'] - temp["Order_delivered_carrier_date"]

# %%
# 상관관계를 구하기 위하여 2days xx:xx:xx을 초로 변환
temp["time_diff_purchase_carrier_second"] = temp["time_diff_purchase_carrier"].apply(lambda x : x.total_seconds())
temp["time_diff_purchase_customer_second"] = temp["time_diff_purchase_customer"].apply(lambda x : x.total_seconds())
temp["time_diff_carrier_customer_second"] = temp["time_diff_carrier_customer"].apply(lambda x : x.total_seconds())
temp["time_diff_customer_delivery_second"] = temp["time_diff_customer_delivery"].apply(lambda x : x.total_seconds())

# %%
# 구매자와 판매자의 거기 변수 생성
temp["Distance"] = ((temp["Customer_lat"] - temp["Seller_lat"])**2 + (temp["Customer_lng"] - temp["Seller_lng"])**2) **(1/2)

# %%
# 제대로 sum이 안되는 columns 확인
# Product_weight_g 하나뿐 object로 되어있다.
# 타입 변경해주기
temp['Product_weight_g'] = temp['Product_weight_g'].replace('Unknown', np.nan).fillna(0).astype(float)
temp['YearMonth'] = temp['Order_purchase_timestamp'].dt.strftime('%Y%m') #월별로 분류

# %%
temp_product_group = temp.groupby(["Product_category_name","YearMonth"])[["Review_score","Price","Freight_value","Payment_value","time_diff_purchase_carrier_second","time_diff_purchase_customer_second","time_diff_carrier_customer_second","time_diff_customer_delivery_second"]].mean().reset_index()

# %%
# temp_product_group

# %%
#주에 따라 묶어서 주에서 거래한 개수
temp_group_count= temp.groupby(["Product_category_name","YearMonth"])["Review_id"].count().reset_index()
temp_group_count["count_ratio"]=temp_group_count["Review_id"].apply(lambda x : x/temp.shape[0])
temp_group_count = temp_group_count.drop(["Review_id"],axis=1)

# %%
# temp_group_count

# %%
# 그걸 기존 df와 묶기
temp_product_group= pd.merge(temp_product_group, temp_group_count, on=['Product_category_name','YearMonth'], how='inner')

# %%
temp_product_group
# Out:
#      Product_category_name YearMonth  Review_score       Price  Freight_value  \
# 0                  Unknown    201710      5.000000   32.945000      15.015000
# 1                  Unknown    201801      3.833333  133.636667      16.257500
# 2                  Unknown    201802      3.910714  152.105714      18.253929
# 3                  Unknown    201803      4.096774  111.628226      16.248387
# 4                  Unknown    201804      4.139241  125.618987      20.372152
# ...                    ...       ...           ...         ...            ...
# 1191         watches_gifts    201903      3.690141  228.547535      20.343967
# 1192         watches_gifts    201904      4.241779  185.727215      15.284275
# 1193         watches_gifts    201905      4.022117  190.958894      13.866746
# 1194         watches_gifts    201906      4.230290  178.123195      18.360290
# 1195         watches_gifts    201907      4.045093  170.151353      18.165332
#
#       Payment_value  time_diff_purchase_carrier_second  \
# 0         47.960000                       1.023936e+06
# 1        160.707500                       3.631958e+05
# 2        184.743393                       5.464914e+05
# 3        141.522742                       2.890181e+05
# 4        151.142911                       3.208460e+05
# ...             ...                                ...
# 1191     249.038779                       2.616281e+05
# 1192     205.954623                       2.800097e+05
# 1193     230.024882                       3.181820e+05
# 1194     217.650664                       2.387331e+05
# 1195     186.771273                       2.472471e+05
#
#       time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 0                           1.643517e+06                       6.195815e+05
# 1                           9.380359e+05                       5.748401e+05
# 2                           1.151913e+06                       6.054215e+05
# 3                           1.047002e+06                       7.579839e+05
# 4                           1.466365e+06                       1.145519e+06
# ...                                  ...                                ...
# 1191                        1.682952e+06                       1.421324e+06
# 1192                        1.116989e+06                       8.369788e+05
# 1193                        1.160220e+06                       8.420382e+05
# 1194                        8.305463e+05                       5.918132e+05
# 1195                        7.284381e+05                       4.811910e+05
#
#       time_diff_customer_delivery_second  count_ratio
# 0                           3.500696e+06     0.000019
# 1                           2.819958e+06     0.000115
# 2                           2.146633e+06     0.000536
# 3                           1.769171e+06     0.000594
# 4                           2.096951e+06     0.000756
# ...                                  ...          ...
# 1191                        1.729328e+06     0.004079
# 1192                        2.052820e+06     0.004950
# 1193                        1.861764e+06     0.006061
# 1194                        2.148818e+06     0.004615
# 1195                        1.609574e+06     0.003610
#
# [1196 rows x 11 columns]

# %%
# 전체 순수익 더하기
all_price_sum=temp.Price.sum()

# %%
# 카테고리에 따라 묶어서 순수익률 개수
temp_group_price= temp.groupby(["Product_category_name","YearMonth"])["Price"].sum().reset_index()
temp_group_price["price_ratio"]=temp_group_price["Price"].apply(lambda x : x/all_price_sum)
temp_group_price = temp_group_price.drop(["Price"],axis=1)

# %%
# 그걸 기존 df와 묶기
temp_product_group= pd.merge(temp_product_group, temp_group_price, on=['Product_category_name','YearMonth'], how='inner')

# %%
# temp_product_group

# %%
# 전체 매출액 더하기
all_payment_sum=temp.Payment_value.sum()

# %%
#주에 따라 묶어서 주에서 매출액
temp_group_payment= temp.groupby(["Product_category_name","YearMonth"])["Payment_value"].sum().reset_index() 
temp_group_payment["payment_ratio"]=temp_group_payment["Payment_value"].apply(lambda x : x/all_payment_sum)
temp_group_payment = temp_group_payment.drop(["Payment_value"],axis=1)

# %%
# 그걸 기존 df와 묶기
temp_product_group= pd.merge(temp_product_group, temp_group_payment, on=['Product_category_name','YearMonth'], how='inner')

# %%
#count_ratio 가 낮으면서 price_ratio 가 높은게 가치가 있다. 파생변수 생성
temp_product_group["value_ratio"] = temp_product_group["price_ratio"] / temp_product_group["count_ratio"] #짜피 payment_ratio와 연관성이 85

# %%
# temp_product_group.head(1)

# %%
temp_product_group.corr(numeric_only=True).style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_65b12_row0_col0, #T_65b12_row1_col1, #T_65b12_row1_col11, #T_65b12_row2_col2, #T_65b12_row3_col3, #T_65b12_row4_col4, #T_65b12_row5_col5, #T_65b12_row6_col6, #T_65b12_row7_col7, #T_65b12_row8_col8, #T_65b12_row9_col9, #T_65b12_row10_col10, #T_65b12_row11_col1, #T_65b12_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col1, #T_65b12_row0_col11, #T_65b12_row1_col0, #T_65b12_row3_col6, #T_65b12_row6_col3, #T_65b12_row11_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col2, #T_65b12_row2_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col3, #T_65b12_row2_col8, #T_65b12_row3_col0, #T_65b12_row8_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col4, #T_65b12_row4_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col5, #T_65b12_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col6, #T_65b12_row6_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col7, #T_65b12_row2_col4, #T_65b12_row4_col2, #T_65b12_row7_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_65b12_row0_col8, #T_65b12_row8_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col9, #T_65b12_row9_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_65b12_row0_col10, #T_65b12_row10_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_65b12_row1_col2, #T_65b12_row2_col1, #T_65b12_row2_col11, #T_65b12_row11_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_65b12_row1_col3, #T_65b12_row3_col1, #T_65b12_row3_col11, #T_65b12_row11_col3 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_65b12_row1_col4, #T_65b12_row1_col5, #T_65b12_row4_col1, #T_65b12_row4_col11, #T_65b12_row5_col1, #T_65b12_row5_col10, #T_65b12_row5_col11, #T_65b12_row10_col5, #T_65b12_row11_col4, #T_65b12_row11_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_65b12_row1_col6, #T_65b12_row6_col1, #T_65b12_row6_col11, #T_65b12_row11_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_65b12_row1_col7, #T_65b12_row1_col10, #T_65b12_row3_col5, #T_65b12_row3_col9, #T_65b12_row5_col3, #T_65b12_row7_col1, #T_65b12_row7_col11, #T_65b12_row9_col3, #T_65b12_row10_col1, #T_65b12_row10_col11, #T_65b12_row11_col7, #T_65b12_row11_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_65b12_row1_col8, #T_65b12_row7_col9, #T_65b12_row8_col1, #T_65b12_row8_col11, #T_65b12_row9_col7, #T_65b12_row11_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_65b12_row1_col9, #T_65b12_row2_col7, #T_65b12_row6_col9, #T_65b12_row7_col2, #T_65b12_row9_col1, #T_65b12_row9_col6, #T_65b12_row9_col11, #T_65b12_row11_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_65b12_row2_col3, #T_65b12_row3_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_65b12_row2_col5, #T_65b12_row5_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_65b12_row2_col6, #T_65b12_row6_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_65b12_row2_col9, #T_65b12_row4_col10, #T_65b12_row9_col2, #T_65b12_row10_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_65b12_row2_col10, #T_65b12_row3_col7, #T_65b12_row7_col3, #T_65b12_row10_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_65b12_row3_col4, #T_65b12_row4_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_65b12_row3_col8, #T_65b12_row4_col9, #T_65b12_row8_col3, #T_65b12_row9_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_65b12_row3_col10, #T_65b12_row6_col7, #T_65b12_row7_col6, #T_65b12_row10_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_65b12_row4_col5, #T_65b12_row5_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_65b12_row4_col6, #T_65b12_row6_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_65b12_row4_col7, #T_65b12_row7_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_65b12_row4_col8, #T_65b12_row8_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_65b12_row5_col6, #T_65b12_row6_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_65b12_row5_col7, #T_65b12_row7_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_65b12_row5_col8, #T_65b12_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_65b12_row5_col9, #T_65b12_row9_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_65b12_row6_col8, #T_65b12_row6_col10, #T_65b12_row8_col6, #T_65b12_row10_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_65b12_row7_col8, #T_65b12_row7_col10, #T_65b12_row8_col7, #T_65b12_row10_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_65b12_row8_col9, #T_65b12_row9_col8 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_65b12_row8_col10, #T_65b12_row10_col8 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_65b12_row9_col10, #T_65b12_row10_col9 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_65b12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65b12_level0_col0" class="col_heading level0 col0" >Review_score</th>
#       <th id="T_65b12_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_65b12_level0_col2" class="col_heading level0 col2" >Freight_value</th>
#       <th id="T_65b12_level0_col3" class="col_heading level0 col3" >Payment_value</th>
#       <th id="T_65b12_level0_col4" class="col_heading level0 col4" >time_diff_purchase_carrier_second</th>
#       <th id="T_65b12_level0_col5" class="col_heading level0 col5" >time_diff_purchase_customer_second</th>
#       <th id="T_65b12_level0_col6" class="col_heading level0 col6" >time_diff_carrier_customer_second</th>
#       <th id="T_65b12_level0_col7" class="col_heading level0 col7" >time_diff_customer_delivery_second</th>
#       <th id="T_65b12_level0_col8" class="col_heading level0 col8" >count_ratio</th>
#       <th id="T_65b12_level0_col9" class="col_heading level0 col9" >price_ratio</th>
#       <th id="T_65b12_level0_col10" class="col_heading level0 col10" >payment_ratio</th>
#       <th id="T_65b12_level0_col11" class="col_heading level0 col11" >value_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65b12_level0_row0" class="row_heading level0 row0" >Review_score</th>
#       <td id="T_65b12_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_65b12_row0_col1" class="data row0 col1" >-0.006718</td>
#       <td id="T_65b12_row0_col2" class="data row0 col2" >-0.054281</td>
#       <td id="T_65b12_row0_col3" class="data row0 col3" >-0.108433</td>
#       <td id="T_65b12_row0_col4" class="data row0 col4" >-0.174642</td>
#       <td id="T_65b12_row0_col5" class="data row0 col5" >-0.301704</td>
#       <td id="T_65b12_row0_col6" class="data row0 col6" >-0.243130</td>
#       <td id="T_65b12_row0_col7" class="data row0 col7" >0.077936</td>
#       <td id="T_65b12_row0_col8" class="data row0 col8" >-0.048668</td>
#       <td id="T_65b12_row0_col9" class="data row0 col9" >-0.041433</td>
#       <td id="T_65b12_row0_col10" class="data row0 col10" >-0.074251</td>
#       <td id="T_65b12_row0_col11" class="data row0 col11" >-0.006718</td>
#     </tr>
#     <tr>
#       <th id="T_65b12_level0_row1" class="row_heading level0 row1" >Price</th>
#       <td id="T_65b12_row1_col0" class="data row1 col0" >-0.006718</td>
#       <td id="T_65b12_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_65b12_row1_col2" class="data row1 col2" >0.426549</td>
#       <td id="T_65b12_row1_col3" class="data row1 col3" >0.711444</td>
#       <td id="T_65b12_row1_col4" class="data row1 col4" >0.026490</td>
#       <td id="T_65b12_row1_col5" class="data row1 col5" >0.026206</td>
#       <td id="T_65b12_row1_col6" class="data row1 col6" >0.014284</td>
#       <td id="T_65b12_row1_col7" class="data row1 col7" >0.030739</td>
#       <td id="T_65b12_row1_col8" class="data row1 col8" >-0.086328</td>
#       <td id="T_65b12_row1_col9" class="data row1 col9" >0.050310</td>
#       <td id="T_65b12_row1_col10" class="data row1 col10" >0.029877</td>
#       <td id="T

# %%
# tolist로 리스트화
unique_product_name_list = temp_product_group.Product_category_name.unique().tolist()

# %%
# 언노운제거
unique_product_name_list = unique_product_name_list[1:]

# %%
# product_caterory name 리스트
# unique_product_name_list

# %%
##### 테스트해보기

# %%
temp_agro_industry_and_commerce = temp_product_group[temp_product_group.Product_category_name=="agro_industry_and_commerce"]

# %%
temp_agro_industry_and_commerce
# Out:
#          Product_category_name YearMonth  Review_score        Price  \
# 20  agro_industry_and_commerce    201801      4.333333    21.990000
# 21  agro_industry_and_commerce    201802      4.111111    29.868889
# 22  agro_industry_and_commerce    201803      2.000000    40.995000
# 23  agro_industry_and_commerce    201805      4.750000   394.985000
# 24  agro_industry_and_commerce    201806      1.000000  1390.000000
# 25  agro_industry_and_commerce    201807      5.000000  1180.000000
# 26  agro_industry_and_commerce    201808      5.000000    22.000000
# 27  agro_industry_and_commerce    201809      3.250000   498.497500
# 28  agro_industry_and_commerce    201810      4.200000   670.056000
# 29  agro_industry_and_commerce    201811      2.789474   733.288947
# 30  agro_industry_and_commerce    201812      4.636364   481.063636
# 31  agro_industry_and_commerce    201901      4.500000   325.191111
# 32  agro_industry_and_commerce    201902      4.625000   342.693750
# 33  agro_industry_and_commerce    201903      4.560976   156.682927
# 34  agro_industry_and_commerce    201904      4.000000   375.058333
# 35  agro_industry_and_commerce    201905      4.500000   409.968750
# 36  agro_industry_and_commerce    201906      4.200000   351.580000
# 37  agro_industry_and_commerce    201907      4.250000   259.147500
#
#     Freight_value  Payment_value  time_diff_purchase_carrier_second  \
# 20      13.930000      56.393333                      238410.666667
# 21      14.942222      36.788889                      214357.666667
# 22      14.350000      55.345000                      152831.000000
# 23      45.950000     440.935000                      227591.000000
# 24      32.050000    1422.050000                      688547.000000
# 25      19.470000    1199.470000                      332744.000000
# 26      34.150000     224.600000                       78253.000000
# 27      31.425000     741.752500                      146451.250000
# 28      41.630000     711.686000                      240308.600000
# 29      35.675263    2414.653684                      591475.315789
# 30      33.849091     617.832727                      391618.181818
# 31      24.615000     375.666111                      302114.888889
# 32      26.165625     225.743333                      533134.395833
# 33      22.808293     144.125610                      195046.804878
# 34      23.580000     398.638333                      274302.833333
# 35      19.183750     429.152500                      170753.250000
# 36      32.725000     384.305000                      160919.100000
# 37      21.149000     236.501500                      204260.900000
#
#     time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 20                        7.241743e+05                       4.857637e+05
# 21                        1.078041e+06                       8.636837e+05
# 22                        8.032110e+05                       6.503800e+05
# 23                        1.034258e+06                       8.066675e+05
# 24                        8.624090e+05                       1.738620e+05
# 25                        4.074850e+05                       7.474100e+04
# 26                        1.611335e+06                       1.533082e+06
# 27                        8.861865e+05                       7.397352e+05
# 28                        9.196900e+05                       6.793814e+05
# 29                        1.585327e+06                       9.938519e+05
# 30                        1.077992e+06                       6.863739e+05
# 31                        1.164266e+06                       8.621512e+05
# 32                        1.338869e+06                       8.057349e+05
# 33                        8.565763e+05                       6.615295e+05
# 34                        1.054597e+06                       7.802938e+05
# 35                        7.939938e+05                       6.232405e+05
# 36                        9.300166e+05                       7.690975e+05
# 37                        5.472222e+05                       3.429613e+05
#
#     time_diff_customer_delivery_second  count_ratio  price_ratio  \
# 20                        2.258004e+06     0.000029     0.000005
# 21                        2.365468e+06     0.000086     0.000022
# 22                        1.686158e+06     0.000019     0.000007
# 23                        2.051464e+06     0.000038     0.000126
# 24                        1.681205e+06     0.000010     0.000111
# 25                        7.164450e+05     0.000010     0.000094
# 26                        3.034032e+06     0.000038     0.000007
# 27                        2.033410e+06     0.000038     0.000160
# 28                        1.792707e+06     0.000048     0.000268
# 29                        1.431674e+06     0.000182     0.001115
# 30                        1.857871e+06     0.000105     0.000423
# 31                        1.976561e+06     0.000172     0.000468
# 32                        1.491678e+06     0.000460     0.001316
# 33                        2.535657e+06     0.000393     0.000514
# 34                        1.775486e+06     0.000115     0.000360
# 35                        1.718925e+06     0.000077     0.000262
# 36                        2.250948e+06     0.000096     0.000281
# 37                        1.285008e+06     0.000192     0.000415
#
#     payment_ratio  value_ratio
# 20       0.000009     0.183750
# 21       0.000019     0.249587
# 22       0.000006     0.342557
# 23       0.000099     3.300525
# 24       0.000080    11.614945
# 25       0.000067     9.860169
# 26       0.000050     0.183834
# 27       0.000166     4.165483
# 28       0.000199     5.599039
# 29       0.002566     6.127418
# 30       0.000380     4.019804
# 31       0.000378     2.717322
# 32       0.000606     2.863575
# 33       0.000331     1.309254
# 34       0.000268     3.134016
# 35       0.000192     3.425730
# 36       0.000215     2.937829
# 37       0.000265     2.165456

# %%
temp_agro_industry_and_commerce.columns
# Out:
# Index(['Product_category_name', 'YearMonth', 'Review_score', 'Price',
#        'Freight_value', 'Payment_value', 'time_diff_purchase_carrier_second',
#        'time_diff_purchase_customer_second',
#        'time_diff_carrier_customer_second',
#        'time_diff_customer_delivery_second', 'count_ratio', 'price_ratio',
#        'payment_ratio', 'value_ratio'],
#       dtype='object')

# %%
temp_agro_industry_and_commerce.shape
# Out:
# (18, 14)

# %%
# temp_agro_industry_and_commerce["future"] = 1

# %%
# for i in range(1,10):
#     temp_agro_industry_and_commerce.loc[i,"future"] = i

# %%
temp_agro_industry_and_commerce
# Out:
#          Product_category_name YearMonth  Review_score        Price  \
# 20  agro_industry_and_commerce    201801      4.333333    21.990000
# 21  agro_industry_and_commerce    201802      4.111111    29.868889
# 22  agro_industry_and_commerce    201803      2.000000    40.995000
# 23  agro_industry_and_commerce    201805      4.750000   394.985000
# 24  agro_industry_and_commerce    201806      1.000000  1390.000000
# 25  agro_industry_and_commerce    201807      5.000000  1180.000000
# 26  agro_industry_and_commerce    201808      5.000000    22.000000
# 27  agro_industry_and_commerce    201809      3.250000   498.497500
# 28  agro_industry_and_commerce    201810      4.200000   670.056000
# 29  agro_industry_and_commerce    201811      2.789474   733.288947
# 30  agro_industry_and_commerce    201812      4.636364   481.063636
# 31  agro_industry_and_commerce    201901      4.500000   325.191111
# 32  agro_industry_and_commerce    201902      4.625000   342.693750
# 33  agro_industry_and_commerce    201903      4.560976   156.682927
# 34  agro_industry_and_commerce    201904      4.000000   375.058333
# 35  agro_industry_and_commerce    201905      4.500000   409.968750
# 36  agro_industry_and_commerce    201906      4.200000   351.580000
# 37  agro_industry_and_commerce    201907      4.250000   259.147500
#
#     Freight_value  Payment_value  time_diff_purchase_carrier_second  \
# 20      13.930000      56.393333                      238410.666667
# 21      14.942222      36.788889                      214357.666667
# 22      14.350000      55.345000                      152831.000000
# 23      45.950000     440.935000                      227591.000000
# 24      32.050000    1422.050000                      688547.000000
# 25      19.470000    1199.470000                      332744.000000
# 26      34.150000     224.600000                       78253.000000
# 27      31.425000     741.752500                      146451.250000
# 28      41.630000     711.686000                      240308.600000
# 29      35.675263    2414.653684                      591475.315789
# 30      33.849091     617.832727                      391618.181818
# 31      24.615000     375.666111                      302114.888889
# 32      26.165625     225.743333                      533134.395833
# 33      22.808293     144.125610                      195046.804878
# 34      23.580000     398.638333                      274302.833333
# 35      19.183750     429.152500                      170753.250000
# 36      32.725000     384.305000                      160919.100000
# 37      21.149000     236.501500                      204260.900000
#
#     time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 20                        7.241743e+05                       4.857637e+05
# 21                        1.078041e+06                       8.636837e+05
# 22                        8.032110e+05                       6.503800e+05
# 23                        1.034258e+06                       8.066675e+05
# 24                        8.624090e+05                       1.738620e+05
# 25                        4.074850e+05                       7.474100e+04
# 26                        1.611335e+06                       1.533082e+06
# 27                        8.861865e+05                       7.397352e+05
# 28                        9.196900e+05                       6.793814e+05
# 29                        1.585327e+06                       9.938519e+05
# 30                        1.077992e+06                       6.863739e+05
# 31                        1.164266e+06                       8.621512e+05
# 32                        1.338869e+06                       8.057349e+05
# 33                        8.565763e+05                       6.615295e+05
# 34                        1.054597e+06                       7.802938e+05
# 35                        7.939938e+05                       6.232405e+05
# 36                        9.300166e+05                       7.690975e+05
# 37                        5.472222e+05                       3.429613e+05
#
#     time_diff_customer_delivery_second  count_ratio  price_ratio  \
# 20                        2.258004e+06     0.000029     0.000005
# 21                        2.365468e+06     0.000086     0.000022
# 22                        1.686158e+06     0.000019     0.000007
# 23                        2.051464e+06     0.000038     0.000126
# 24                        1.681205e+06     0.000010     0.000111
# 25                        7.164450e+05     0.000010     0.000094
# 26                        3.034032e+06     0.000038     0.000007
# 27                        2.033410e+06     0.000038     0.000160
# 28                        1.792707e+06     0.000048     0.000268
# 29                        1.431674e+06     0.000182     0.001115
# 30                        1.857871e+06     0.000105     0.000423
# 31                        1.976561e+06     0.000172     0.000468
# 32                        1.491678e+06     0.000460     0.001316
# 33                        2.535657e+06     0.000393     0.000514
# 34                        1.775486e+06     0.000115     0.000360
# 35                        1.718925e+06     0.000077     0.000262
# 36                        2.250948e+06     0.000096     0.000281
# 37                        1.285008e+06     0.000192     0.000415
#
#     payment_ratio  value_ratio
# 20       0.000009     0.183750
# 21       0.000019     0.249587
# 22       0.000006     0.342557
# 23       0.000099     3.300525
# 24       0.000080    11.614945
# 25       0.000067     9.860169
# 26       0.000050     0.183834
# 27       0.000166     4.165483
# 28       0.000199     5.599039
# 29       0.002566     6.127418
# 30       0.000380     4.019804
# 31       0.000378     2.717322
# 32       0.000606     2.863575
# 33       0.000331     1.309254
# 34       0.000268     3.134016
# 35       0.000192     3.425730
# 36       0.000215     2.937829
# 37       0.000265     2.165456

# %%
# 이전 월의 평균 가격을 구하기 위해 현재 월의 가격을 한 칸씩 밑으로 이동합니다.
temp_agro_industry_and_commerce['Previous_month_price'] = temp_agro_industry_and_commerce['Price'].shift(1)

# 가격 상승률을 계산합니다.
# monthly_mean_price['Price_increase_rate'] = (monthly_mean_price['Price'] - monthly_mean_price['Previous_month_price']) / monthly_mean_price['Previous_month_price']

# 결과 확인
# print(monthly_mean_price)
# Out:
# /tmp/ipykernel_1534/4014912780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_agro_industry_and_commerce['Previous_month_price'] = temp_agro_industry_and_commerce['Price'].shift(1)

# %%
temp_agro_industry_and_commerce
# Out:
#          Product_category_name YearMonth  Review_score        Price  \
# 20  agro_industry_and_commerce    201801      4.333333    21.990000
# 21  agro_industry_and_commerce    201802      4.111111    29.868889
# 22  agro_industry_and_commerce    201803      2.000000    40.995000
# 23  agro_industry_and_commerce    201805      4.750000   394.985000
# 24  agro_industry_and_commerce    201806      1.000000  1390.000000
# 25  agro_industry_and_commerce    201807      5.000000  1180.000000
# 26  agro_industry_and_commerce    201808      5.000000    22.000000
# 27  agro_industry_and_commerce    201809      3.250000   498.497500
# 28  agro_industry_and_commerce    201810      4.200000   670.056000
# 29  agro_industry_and_commerce    201811      2.789474   733.288947
# 30  agro_industry_and_commerce    201812      4.636364   481.063636
# 31  agro_industry_and_commerce    201901      4.500000   325.191111
# 32  agro_industry_and_commerce    201902      4.625000   342.693750
# 33  agro_industry_and_commerce    201903      4.560976   156.682927
# 34  agro_industry_and_commerce    201904      4.000000   375.058333
# 35  agro_industry_and_commerce    201905      4.500000   409.968750
# 36  agro_industry_and_commerce    201906      4.200000   351.580000
# 37  agro_industry_and_commerce    201907      4.250000   259.147500
#
#     Freight_value  Payment_value  time_diff_purchase_carrier_second  \
# 20      13.930000      56.393333                      238410.666667
# 21      14.942222      36.788889                      214357.666667
# 22      14.350000      55.345000                      152831.000000
# 23      45.950000     440.935000                      227591.000000
# 24      32.050000    1422.050000                      688547.000000
# 25      19.470000    1199.470000                      332744.000000
# 26      34.150000     224.600000                       78253.000000
# 27      31.425000     741.752500                      146451.250000
# 28      41.630000     711.686000                      240308.600000
# 29      35.675263    2414.653684                      591475.315789
# 30      33.849091     617.832727                      391618.181818
# 31      24.615000     375.666111                      302114.888889
# 32      26.165625     225.743333                      533134.395833
# 33      22.808293     144.125610                      195046.804878
# 34      23.580000     398.638333                      274302.833333
# 35      19.183750     429.152500                      170753.250000
# 36      32.725000     384.305000                      160919.100000
# 37      21.149000     236.501500                      204260.900000
#
#     time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 20                        7.241743e+05                       4.857637e+05
# 21                        1.078041e+06                       8.636837e+05
# 22                        8.032110e+05                       6.503800e+05
# 23                        1.034258e+06                       8.066675e+05
# 24                        8.624090e+05                       1.738620e+05
# 25                        4.074850e+05                       7.474100e+04
# 26                        1.611335e+06                       1.533082e+06
# 27                        8.861865e+05                       7.397352e+05
# 28                        9.196900e+05                       6.793814e+05
# 29                        1.585327e+06                       9.938519e+05
# 30                        1.077992e+06                       6.863739e+05
# 31                        1.164266e+06                       8.621512e+05
# 32                        1.338869e+06                       8.057349e+05
# 33                        8.565763e+05                       6.615295e+05
# 34                        1.054597e+06                       7.802938e+05
# 35                        7.939938e+05                       6.232405e+05
# 36                        9.300166e+05                       7.690975e+05
# 37                        5.472222e+05                       3.429613e+05
#
#     time_diff_customer_delivery_second  count_ratio  price_ratio  \
# 20                        2.258004e+06     0.000029     0.000005
# 21                        2.365468e+06     0.000086     0.000022
# 22                        1.686158e+06     0.000019     0.000007
# 23                        2.051464e+06     0.000038     0.000126
# 24                        1.681205e+06     0.000010     0.000111
# 25                        7.164450e+05     0.000010     0.000094
# 26                        3.034032e+06     0.000038     0.000007
# 27                        2.033410e+06     0.000038     0.000160
# 28                        1.792707e+06     0.000048     0.000268
# 29                        1.431674e+06     0.000182     0.001115
# 30                        1.857871e+06     0.000105     0.000423
# 31                        1.976561e+06     0.000172     0.000468
# 32                        1.491678e+06     0.000460     0.001316
# 33                        2.535657e+06     0.000393     0.000514
# 34                        1.775486e+06     0.000115     0.000360
# 35                        1.718925e+06     0.000077     0.000262
# 36                        2.250948e+06     0.000096     0.000281
# 37                        1.285008e+06     0.000192     0.000415
#
#     payment_ratio  value_ratio  Previous_month_price
# 20       0.000009     0.183750                   NaN
# 21       0.000019     0.249587             21.990000
# 22       0.000006     0.342557             29.868889
# 23       0.000099     3.300525             40.995000
# 24       0.000080    11.614945            394.985000
# 25       0.000067     9.860169           1390.000000
# 26       0.000050     0.183834           1180.000000
# 27       0.000166     4.165483             22.000000
# 28       0.000199     5.599039            498.497500
# 29       0.002566     6.127418            670.056000
# 30       0.000380     4.019804            733.288947
# 31       0.000378     2.717322            481.063636
# 32       0.000606     2.863575            325.191111
# 33       0.000331     1.309254            342.693750
# 34       0.000268     3.134016            156.682927
# 35       0.000192     3.425730            375.058333
# 36       0.000215     2.937829            409.968750
# 37       0.000265     2.165456            351.580000

# %%
temp_agro_industry_and_commerce_min = temp_agro_industry_and_commerce[temp_agro_industry_and_commerce.value_ratio==0.1837501067222725]

# %%
temp_agro_industry_and_commerce_max = temp_agro_industry_and_commerce[temp_agro_industry_and_commerce.YearMonth=="201806"]

# %%
temp_agro_industry_and_commerce_min
# Out:
#          Product_category_name YearMonth  Review_score  Price  Freight_value  \
# 20  agro_industry_and_commerce    201801      4.333333  21.99          13.93
#
#     Payment_value  time_diff_purchase_carrier_second  \
# 20      56.393333                      238410.666667
#
#     time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 20                       724174.333333                      485763.666667
#
#     time_diff_customer_delivery_second  count_ratio  price_ratio  \
# 20                        2.258004e+06     0.000029     0.000005
#
#     payment_ratio  value_ratio  Previous_month_price
# 20       0.000009      0.18375                   NaN

# %%
temp_agro_industry_and_commerce_max
# Out:
#          Product_category_name YearMonth  Review_score   Price  Freight_value  \
# 24  agro_industry_and_commerce    201806           1.0  1390.0          32.05
#
#     Payment_value  time_diff_purchase_carrier_second  \
# 24        1422.05                           688547.0
#
#     time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 24                            862409.0                           173862.0
#
#     time_diff_customer_delivery_second  count_ratio  price_ratio  \
# 24                           1681205.0      0.00001     0.000111
#
#     payment_ratio  value_ratio  Previous_month_price
# 24        0.00008    11.614945               394.985

# %%
temp_product_group
# Out:
#      Product_category_name YearMonth  Review_score       Price  Freight_value  \
# 0                  Unknown    201710      5.000000   32.945000      15.015000
# 1                  Unknown    201801      3.833333  133.636667      16.257500
# 2                  Unknown    201802      3.910714  152.105714      18.253929
# 3                  Unknown    201803      4.096774  111.628226      16.248387
# 4                  Unknown    201804      4.139241  125.618987      20.372152
# ...                    ...       ...           ...         ...            ...
# 1191         watches_gifts    201903      3.690141  228.547535      20.343967
# 1192         watches_gifts    201904      4.241779  185.727215      15.284275
# 1193         watches_gifts    201905      4.022117  190.958894      13.866746
# 1194         watches_gifts    201906      4.230290  178.123195      18.360290
# 1195         watches_gifts    201907      4.045093  170.151353      18.165332
#
#       Payment_value  time_diff_purchase_carrier_second  \
# 0         47.960000                       1.023936e+06
# 1        160.707500                       3.631958e+05
# 2        184.743393                       5.464914e+05
# 3        141.522742                       2.890181e+05
# 4        151.142911                       3.208460e+05
# ...             ...                                ...
# 1191     249.038779                       2.616281e+05
# 1192     205.954623                       2.800097e+05
# 1193     230.024882                       3.181820e+05
# 1194     217.650664                       2.387331e+05
# 1195     186.771273                       2.472471e+05
#
#       time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 0                           1.643517e+06                       6.195815e+05
# 1                           9.380359e+05                       5.748401e+05
# 2                           1.151913e+06                       6.054215e+05
# 3                           1.047002e+06                       7.579839e+05
# 4                           1.466365e+06                       1.145519e+06
# ...                                  ...                                ...
# 1191                        1.682952e+06                       1.421324e+06
# 1192                        1.116989e+06                       8.369788e+05
# 1193                        1.160220e+06                       8.420382e+05
# 1194                        8.305463e+05                       5.918132e+05
# 1195                        7.284381e+05                       4.811910e+05
#
#       time_diff_customer_delivery_second  count_ratio  price_ratio  \
# 0                           3.500696e+06     0.000019     0.000005
# 1                           2.819958e+06     0.000115     0.000128
# 2                           2.146633e+06     0.000536     0.000682
# 3                           1.769171e+06     0.000594     0.000554
# 4                           2.096951e+06     0.000756     0.000794
# ...                                  ...          ...          ...
# 1191                        1.729328e+06     0.004079     0.007790
# 1192                        2.052820e+06     0.004950     0.007683
# 1193                        1.861764e+06     0.006061     0.009672
# 1194                        2.148818e+06     0.004615     0.006869
# 1195                        1.609574e+06     0.003610     0.005132
#
#       payment_ratio  value_ratio
# 0          0.000005     0.275291
# 1          0.000108     1.116678
# 2          0.000579     1.271007
# 3          0.000491     0.932774
# 4          0.000668     1.049682
# ...             ...          ...
# 1191       0.005934     1.909761
# 1192       0.005955     1.551951
# 1193       0.008144     1.595667
# 1194       0.005868     1.488411
# 1195       0.003938     1.421798
#
# [1196 rows x 14 columns]

# %%
# 전월별의 차이를 봐서 기대값을 올려가보자

# %%
# import matplotlib.pyplot as plt
# x=np.arange(27)
# width = 0.35
# fig, axes = plt.subplots()
# axes.bar(x - width/2, test_city_ratio_earn["ratio"], width, alpha = 0.5) #물품비율
# axes.bar(x + width/2, test_city_ratio_earn["earn_ratio"], width, alpha = 0.8) #매출비율
# plt.xticks(x)
# axes.set_xticklabels(test_city_ratio_earn["Customer_state"])

# %%
# value_ratio 기준으로 정렬하기
temp_product_group_sorted= temp_product_group.sort_values(["value_ratio"],ascending=False)

# %%
# temp_product_group_sorted
