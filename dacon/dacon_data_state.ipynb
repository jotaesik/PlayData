# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#데이터읽기
customers = pd.read_csv('./dacon_data/open/customers.csv')
locations = pd.read_csv('./dacon_data/open/locations.csv')
orders = pd.read_csv('./dacon_data/open/orders.csv')
order_items = pd.read_csv('./dacon_data/open/order_items.csv')
payments = pd.read_csv('./dacon_data/open/payments.csv')
products = pd.read_csv('./dacon_data/open/products.csv')
reviews = pd.read_csv('./dacon_data/open/reviews.csv')
sellers = pd.read_csv('./dacon_data/open/sellers.csv')

# %%
# 데이터 merge하기
temp = pd.merge(reviews,order_items, how='inner',on='Order_id')
temp = pd.merge(temp,orders, how='inner',on='Order_id')
temp = pd.merge(temp,payments, how='inner',on='Order_id')
temp = pd.merge(temp,products, how='inner',on='Product_id')
temp = pd.merge(temp,customers, how='inner',on='Customer_id')
temp = pd.merge(temp,sellers, how='inner',on='Seller_id')

# %%
# locations[locations.Geolocation_zipcode_prefix==1037]
# 1037을 가진 우편번호가 여러개 존재함

# %%
# 여러개의 우편번호가 존재하므로 한우편번호에 있어서 평균을 구하기로함
locations_group_lat=locations.groupby(["Geolocation_zipcode_prefix"])["Geolocation_lat"].mean().reset_index()
locations_group_lng=locations.groupby(["Geolocation_zipcode_prefix"])["Geolocation_lng"].mean().reset_index()
locations_group =  pd.merge(locations_group_lat, locations_group_lng, how = 'inner', on="Geolocation_zipcode_prefix")

# %%
# 구입자의 위도경도
temp = pd.merge(temp, locations_group, left_on = 'Customer_zipcode_prefix', right_on = 'Geolocation_zipcode_prefix', how = 'inner')
temp = temp.rename(columns={'Geolocation_lat':'Customer_lat',"Geolocation_lng" : "Customer_lng" })

# %%
# 판매자의 위도경도
temp = pd.merge(temp, locations_group, left_on = 'Seller_zipcode_prefix', right_on = 'Geolocation_zipcode_prefix', how = 'inner')
temp = temp.rename(columns={'Geolocation_lat':'Seller_lat',"Geolocation_lng" : "Seller_lng" })

# %%
# 중복되는 구매자,판매자 우편번호 드랍
temp = temp.drop(["Geolocation_zipcode_prefix_x","Geolocation_zipcode_prefix_y"],axis=1)

# %%
# date 타입으로 변환
temp['Order_purchase_timestamp']=pd.to_datetime(temp['Order_purchase_timestamp'])
temp['Order_delivered_carrier_date']=pd.to_datetime(temp['Order_delivered_carrier_date'])
temp['Order_delivered_customer_date']=pd.to_datetime(temp['Order_delivered_customer_date'])
temp['Order_estimated_delivery_date']=pd.to_datetime(temp['Order_estimated_delivery_date'])
# temp[['Order_delivered_carrier_date','Order_delivered_customer_date',"Order_purchase_timestamp"]] = temp[['Order_delivered_carrier_date','Order_delivered_customer_date',"Order_purchase_timestamp"]].apply(pd.to_datetime)

# %%
# temp의 시계열이 datetype으로 바뀌었는지 확인
# temp.info()

# %%
# Order_purchase_timestamp : 구매 시간
# Order_delivered_carrier_date : 물류 처리 시간
# Order_delivered_customer_date : 실제 배송 날짜
# Order_estimated_delivery_date : 기대 배송 날짜

# 구매할때부터 물류처리할때까지 걸리는 시간
temp["time_diff_purchase_carrier"] = temp["Order_delivered_carrier_date"] - temp["Order_purchase_timestamp"]
# 구매할때부터 실제배송할때까지 걸리는 시간
temp["time_diff_purchase_customer"] = temp["Order_delivered_customer_date"] - temp["Order_purchase_timestamp"]
# 물류처리할때부터 실제배송할때까지 걸리는 시간
temp["time_diff_carrier_customer"] = temp["Order_delivered_customer_date"] - temp["Order_delivered_carrier_date"]
# 기대배송날짜와 실제배송날짜의 차이
temp["time_diff_customer_delivery"]= temp['Order_estimated_delivery_date'] - temp["Order_delivered_carrier_date"]

# %%
# 상관관계를 구하기 위하여 2days xx:xx:xx을 초로 변환
temp["time_diff_purchase_carrier_second"] = temp["time_diff_purchase_carrier"].apply(lambda x : x.total_seconds())
temp["time_diff_purchase_customer_second"] = temp["time_diff_purchase_customer"].apply(lambda x : x.total_seconds())
temp["time_diff_carrier_customer_second"] = temp["time_diff_carrier_customer"].apply(lambda x : x.total_seconds())
temp["time_diff_customer_delivery_second"] = temp["time_diff_customer_delivery"].apply(lambda x : x.total_seconds())

# %%
# 구매자와 판매자의 거기 변수 생성
temp["Distance"] = ((temp["Customer_lat"] - temp["Seller_lat"])**2 + (temp["Customer_lng"] - temp["Seller_lng"])**2) **(1/2)

# %%
# 일단 매출액과 기간의 상관관계를 보아보자
temp_corr = temp[["Review_score","Price","Freight_value","Payment_value","Product_weight_g","time_diff_purchase_carrier_second","time_diff_purchase_customer_second","time_diff_carrier_customer_second","time_diff_customer_delivery_second","Distance"]]

# %%
# 원본데이터일때 상관관계
temp_corr.corr(numeric_only=True).style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_a8320_row0_col0, #T_a8320_row1_col1, #T_a8320_row2_col2, #T_a8320_row3_col3, #T_a8320_row4_col4, #T_a8320_row5_col5, #T_a8320_row6_col6, #T_a8320_row7_col7, #T_a8320_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a8320_row0_col1, #T_a8320_row1_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_a8320_row0_col2, #T_a8320_row2_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_a8320_row0_col3, #T_a8320_row3_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_a8320_row0_col4, #T_a8320_row4_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_a8320_row0_col5, #T_a8320_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a8320_row0_col6, #T_a8320_row6_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a8320_row0_col7, #T_a8320_row7_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a8320_row0_col8, #T_a8320_row8_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_a8320_row1_col2, #T_a8320_row2_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a8320_row1_col3, #T_a8320_row3_col1 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_a8320_row1_col4, #T_a8320_row1_col5, #T_a8320_row4_col1, #T_a8320_row5_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_a8320_row1_col6, #T_a8320_row1_col7, #T_a8320_row3_col7, #T_a8320_row6_col1, #T_a8320_row7_col1, #T_a8320_row7_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_a8320_row1_col8, #T_a8320_row8_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_a8320_row2_col3, #T_a8320_row3_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_a8320_row2_col4, #T_a8320_row4_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_a8320_row2_col5, #T_a8320_row5_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_a8320_row2_col6, #T_a8320_row6_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_a8320_row2_col7, #T_a8320_row7_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_a8320_row2_col8, #T_a8320_row8_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a8320_row3_col4, #T_a8320_row4_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_a8320_row3_col5, #T_a8320_row5_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_a8320_row3_col6, #T_a8320_row6_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_a8320_row3_col8, #T_a8320_row8_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_a8320_row4_col5, #T_a8320_row5_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a8320_row4_col6, #T_a8320_row6_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a8320_row4_col7, #T_a8320_row7_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a8320_row4_col8, #T_a8320_row8_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_a8320_row5_col6, #T_a8320_row6_col5 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_a8320_row5_col7, #T_a8320_row7_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_a8320_row5_col8, #T_a8320_row8_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_a8320_row6_col7, #T_a8320_row7_col6 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_a8320_row6_col8, #T_a8320_row8_col6 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_a8320_row7_col8, #T_a8320_row8_col7 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# </style>
# <table id="T_a8320">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8320_level0_col0" class="col_heading level0 col0" >Review_score</th>
#       <th id="T_a8320_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_a8320_level0_col2" class="col_heading level0 col2" >Freight_value</th>
#       <th id="T_a8320_level0_col3" class="col_heading level0 col3" >Payment_value</th>
#       <th id="T_a8320_level0_col4" class="col_heading level0 col4" >time_diff_purchase_carrier_second</th>
#       <th id="T_a8320_level0_col5" class="col_heading level0 col5" >time_diff_purchase_customer_second</th>
#       <th id="T_a8320_level0_col6" class="col_heading level0 col6" >time_diff_carrier_customer_second</th>
#       <th id="T_a8320_level0_col7" class="col_heading level0 col7" >time_diff_customer_delivery_second</th>
#       <th id="T_a8320_level0_col8" class="col_heading level0 col8" >Distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8320_level0_row0" class="row_heading level0 row0" >Review_score</th>
#       <td id="T_a8320_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a8320_row0_col1" class="data row0 col1" >0.004214</td>
#       <td id="T_a8320_row0_col2" class="data row0 col2" >-0.035906</td>
#       <td id="T_a8320_row0_col3" class="data row0 col3" >-0.082358</td>
#       <td id="T_a8320_row0_col4" class="data row0 col4" >-0.149300</td>
#       <td id="T_a8320_row0_col5" class="data row0 col5" >-0.308265</td>
#       <td id="T_a8320_row0_col6" class="data row0 col6" >-0.275310</td>
#       <td id="T_a8320_row0_col7" class="data row0 col7" >0.008873</td>
#       <td id="T_a8320_row0_col8" class="data row0 col8" >-0.058759</td>
#     </tr>
#     <tr>
#       <th id="T_a8320_level0_row1" class="row_heading level0 row1" >Price</th>
#       <td id="T_a8320_row1_col0" class="data row1 col0" >0.004214</td>
#       <td id="T_a8320_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a8320_row1_col2" class="data row1 col2" >0.410670</td>
#       <td id="T_a8320_row1_col3" class="data row1 col3" >0.732582</td>
#       <td id="T_a8320_row1_col4" class="data row1 col4" >0.063354</td>
#       <td id="T_a8320_row1_col5" class="data row1 col5" >0.061012</td>
#       <td id="T_a8320_row1_col6" class="data row1 col6" >0.040461</td>
#       <td id="T_a8320_row1_col7" class="data row1 col7" >0.043452</td>
#       <td id="T_a8320_row1_col8" class="data row1 col8" >0.084659</td>
#     </tr>
#     <tr>
#       <th id="T_a8320_level0_row2" class="row_heading level0 row2" >Freight_value</th>
#       <td id="T_a8320_row2_col0" class="data row2 col0" >-0.035906</td>
#       <td id="T_a8320_row2_col1" class="data row2 col1" >0.410670</td>
#       <td id="T_a8320_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a8320_row2_col3" class="data row2 col3" >0.368607</td>
#       <td id="T_a8320_row2_col4" class="data row2 col4" >0.093304</td>
#       <td id="T_a8320_row2_col5" class="data row2 col5" >0.220326</td>
#       <td id="T_a8320_row2_col6" class="data row2 col6" >0.202336</td>
#       <td id="T_a8320_row2_col7" class="data row2 col7" >0.251835</td>
#       <td id="T_a8320_row2_col8" class="data row2 col8" >0.389278</td>
#     </tr>
#     <tr>
#       <th id="T_a8320_level0_row3" class="row_heading level0 row3" >Payment_value</th>
#       <td id="T_a8320_row3_col0" class="data row3 col0" >-0.082358</td>
#       <td id="T_a8320_row3_col1" class="data row3 col1" >0.732582</td>
#       <td id="T_a8320_row3_col2" class="data row3 col2" >0.368607</td>
#       <td id="T_a8320_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a8320_row3_col4" class="data row3 col4" >0.095513</td>
#       <td id="T_a8320_row3_col5" class="data row3 col5" >0.059390</td>
#       <td id="T_a8320_row3_col6" class="data row3 col6" >0.025340</td>
#       <td id="T_a8320_row3_col7" class="data row3 col7" >0.043680</td>
#       <td id="T_a8320_row3_col8" class="data row3 col8" >0.086384</td>
#     </tr>
#     <tr>
#       <th id="T_a8320_level0_row4" class="row_heading level0 row4" >time_diff_purchase_carrier_second</th>
#       <td id="T_a8320_row4_col0" class="data row4 col0" >-0.149300</td>
#       <td id="T_a8320_row4_col1" class="data row4 col1" >0.063354</td>
#       <td id="T_a8320_row4_col2" class="data row4 col2" >0.093304</td>
#       <td id="T_a8320_row4_col3" class="data row4 col3" >0.095513</td>
#       <td id="T_a8320_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a8320_row4_col5" class="data row4 col5" >0.406626</td>
#       <td id="T_a8320_row4_col6" class="data row4 col6" >0.029893</td>
#       <td id="T_a8320_row4_col7" class="data row4 col7" >-0.217128</td>
#       <td id="T_

# %%
# orders

# %%
# 제대로 sum이 안되는 columns 확인
# Product_weight_g 하나뿐 object로 되어있다.
# 타입 변경해주기
temp['Product_weight_g'] = temp['Product_weight_g'].replace('Unknown', np.nan).fillna(0).astype(float)

# %%
# 배송비를 줄이면 리뷰점수가 오른다.
# 결제금액이 클수록 만족도가 떠러진다.
# 리뷰점수가 좋으면 판매자가 인기가 있는가??

# merge된 temp를 주별로 묶기
temp_group_city = temp.groupby(["Customer_state"])[["Review_score","Price","Freight_value","Payment_value","Product_weight_g","Distance","time_diff_purchase_carrier_second","time_diff_purchase_customer_second","time_diff_carrier_customer_second","time_diff_customer_delivery_second"]].mean().reset_index()

# %%
payments
# 할부가 존재하는건 신용카드
# Out:
#           Order_id  Payment_sequential Payment_type  Payment_installments  \
# 0      ORDER_66617                   1  credit_card                     8
# 1      ORDER_86954                   1  credit_card                     1
# 2      ORDER_38852                   1  credit_card                     1
# 3      ORDER_57443                   1  credit_card                     8
# 4      ORDER_11244                   1  credit_card                     2
# ...            ...                 ...          ...                   ...
# 91966  ORDER_46197                   1  credit_card                     1
# 91967  ORDER_37509                   1  credit_card                     2
# 91968  ORDER_85760                   1       boleto                     1
# 91969  ORDER_35237                   1  credit_card                     2
# 91970  ORDER_61019                   1       boleto                     1
#
#        Payment_value
# 0              99.33
# 1              24.39
# 2              65.71
# 3             107.78
# 4             128.45
# ...              ...
# 91966         194.11
# 91967         198.94
# 91968         363.31
# 91969          96.80
# 91970         191.58
#
# [91971 rows x 5 columns]

# %%
temp_group_city.head(1)
#303591.691358 이게 구매할때부터 포장할때까지의 ㅅ간평균이라고?
# Out:
#   Customer_state  Review_score       Price  Freight_value  Payment_value  \
# 0             AC      4.012346  183.849383      40.437531     235.288889
#
#    Product_weight_g   Distance  time_diff_purchase_carrier_second  \
# 0       2057.320988  24.502951                      303591.691358
#
#    time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 0                        1.871732e+06                       1.568140e+06
#
#    time_diff_customer_delivery_second
# 0                        3.303366e+06

# %%
# 주로 mean한 상관관계 구하기
# temp_group_city.corr(numeric_only=True).style.background_gradient(cmap='coolwarm', axis=None)

# %%
# 일단 기대배송일자와 매출액을 비교해봤을때 
# time_diff_customer_delivery_second와 Price
# 0.547777 양의 상관관계를 가지고있다. 
# 위의 표를 정리해보면 0.4 이상을 유의미한 값으로 지정

# 반비례 : 리뷰점수와 구매시간부터 포장시간 차이(-0.48), 
        
# 비례   : 순이익과 운임요금(0.86), 순이익과 거래가치(0.85), 가격과 거리(0.71), 가격과 구매부터 도착까지(0.65), 가격과 포장부터 도착(0.64)
        #  가격과 기대배송날짜와 실제배송날짜의 차이(0.54), 운임요금과 거래가치(0.83), 운임요금과 거리(0.88), 운인요금과 구매부터 도착(0.77)
        # 운임요금과 포장부터 도착(0.76), 운임요금과 ㄱ대배송 실제배송창(0.70), 거래가치는 거리(0.73), 거래가치와 구입부터 배송까지(0.74),
        # 거래가치와 포장부터 고객까지(0.73), 거래가치와 실제배송 예측차이(0.62), 거리와 구입부터 고객까지(0.91), 거리와 포장고객(0.91),
        # 거리와 실제배송 예측(0.89),

# %%
#주에 따라 묶어서 주에서 거래한 개수
temp_group_count= temp.groupby(["Customer_state"])["Customer_city"].count().reset_index()
temp_group_count["count_ratio"]=temp_group_count["Customer_city"].apply(lambda x : x/temp.shape[0])

# %%
# 그걸 기존 df와 묶기
temp_group_city= pd.merge(temp_group_city, temp_group_count, on='Customer_state', how='inner')

# %%
# 전체 순수익 더하기
all_price_sum=temp.Price.sum()

# %%
# 주에 따라 묶어서 순수익률 개수
temp_group_price= temp.groupby(["Customer_state"])["Price"].sum().reset_index()
temp_group_price["price_ratio"]=temp_group_price["Price"].apply(lambda x : x/all_price_sum)

# %%
# 그걸 기존 df와 묶기
temp_group_city= pd.merge(temp_group_city, temp_group_price, on='Customer_state', how='inner')

# %%
# 중복도는 컬럼 drop
temp_group_city = temp_group_city.drop(["Price_y"],axis=1)

# %%
# # 실질적인 ratio 비율 확인
# temp_group_city["ratio_gap"] = temp_group_city["price_ratio"] - temp_group_city["count_ratio"]

# %%
# 전체 매출액 더하기
all_payment_sum=temp.Payment_value.sum()

# %%
#주에 따라 묶어서 주에서 매출액
temp_group_payment= temp.groupby(["Customer_state"])["Payment_value"].sum().reset_index()
temp_group_payment["payment_ratio"]=temp_group_payment["Payment_value"].apply(lambda x : x/all_payment_sum)

# %%
# 그걸 기존 df와 묶기
temp_group_city= pd.merge(temp_group_city, temp_group_payment, on='Customer_state', how='inner')

# %%
# 중복도는 컬럼 drop
temp_group_city = temp_group_city.drop(["Payment_value_y"],axis=1)

# %%
#count_ratio 가 낮으면서 price_ratio 가 높은게 가치가 있다. 파생변수 생성
temp_group_city["value_ratio"] = temp_group_city["price_ratio"] / temp_group_city["count_ratio"] #짜피 payment_ratio와 연관성이 85

# %%
# value_ratio 기준으로 정렬하기
temp_group_city_sorted= temp_group_city.sort_values(["value_ratio"],ascending=False)

# %%
# 1이 안되는 애들은 판매되는 개수는 많은데 순이익이 안나오므로 그에 비하여 성장시킬 필요가 없다.(물론 손해를 안보는 쪽으로 하는)
temp_group_city_sorted_up = temp_group_city_sorted[temp_group_city_sorted.value_ratio>1]

# %%
# 1이 안되는 애들은 판매되는 개수는 많은데 순이익이 안나오므로 그에 비하여 성장시킬 필요가 없다.(물론 손해를 안보는 쪽으로 하는)
temp_group_city_sorted_down = temp_group_city_sorted[temp_group_city_sorted.value_ratio<=1]

# %%
# 가치가 있는 애들의 상관관계 구하기
temp_group_city_sorted_up.corr(numeric_only=True).style.background_gradient(cmap='coolwarm', axis=None)
# 해석
# 물건살때부터 포장할때까지 걸리는 시간이 줄어들면 리뷰점수가올라간다. -0.48이므로 100이 오르면 48이 바뀐다.
# Out:
# <style type="text/css">
# #T_635c0_row0_col0, #T_635c0_row1_col1, #T_635c0_row1_col14, #T_635c0_row2_col2, #T_635c0_row3_col3, #T_635c0_row4_col4, #T_635c0_row5_col5, #T_635c0_row6_col6, #T_635c0_row7_col7, #T_635c0_row7_col8, #T_635c0_row8_col7, #T_635c0_row8_col8, #T_635c0_row9_col9, #T_635c0_row10_col10, #T_635c0_row10_col11, #T_635c0_row10_col12, #T_635c0_row10_col13, #T_635c0_row11_col10, #T_635c0_row11_col11, #T_635c0_row11_col12, #T_635c0_row11_col13, #T_635c0_row12_col10, #T_635c0_row12_col11, #T_635c0_row12_col12, #T_635c0_row12_col13, #T_635c0_row13_col10, #T_635c0_row13_col11, #T_635c0_row13_col12, #T_635c0_row13_col13, #T_635c0_row14_col1, #T_635c0_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_635c0_row0_col1, #T_635c0_row0_col14, #T_635c0_row1_col0, #T_635c0_row14_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_635c0_row0_col2, #T_635c0_row2_col0, #T_635c0_row6_col9, #T_635c0_row9_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_635c0_row0_col3, #T_635c0_row3_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_635c0_row0_col4, #T_635c0_row4_col0, #T_635c0_row4_col6, #T_635c0_row6_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_635c0_row0_col5, #T_635c0_row5_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_635c0_row0_col6, #T_635c0_row6_col0, #T_635c0_row7_col10, #T_635c0_row7_col11, #T_635c0_row7_col12, #T_635c0_row8_col13, #T_635c0_row10_col7, #T_635c0_row11_col7, #T_635c0_row12_col7, #T_635c0_row13_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_635c0_row0_col7, #T_635c0_row7_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_635c0_row0_col8, #T_635c0_row8_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_635c0_row0_col9, #T_635c0_row9_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_635c0_row0_col10, #T_635c0_row0_col11, #T_635c0_row10_col0, #T_635c0_row11_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_635c0_row0_col12, #T_635c0_row12_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_635c0_row0_col13, #T_635c0_row13_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_635c0_row1_col2, #T_635c0_row2_col1, #T_635c0_row2_col14, #T_635c0_row14_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_635c0_row1_col3, #T_635c0_row3_col1, #T_635c0_row3_col14, #T_635c0_row14_col3 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_635c0_row1_col4, #T_635c0_row3_col6, #T_635c0_row4_col1, #T_635c0_row4_col14, #T_635c0_row6_col3, #T_635c0_row14_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_635c0_row1_col5, #T_635c0_row5_col1, #T_635c0_row5_col14, #T_635c0_row14_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_635c0_row1_col6, #T_635c0_row6_col1, #T_635c0_row6_col14, #T_635c0_row14_col6 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_635c0_row1_col7, #T_635c0_row3_col9, #T_635c0_row7_col1, #T_635c0_row7_col14, #T_635c0_row9_col3, #T_635c0_row14_col7 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_635c0_row1_col8, #T_635c0_row8_col1, #T_635c0_row8_col14, #T_635c0_row14_col8 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_635c0_row1_col9, #T_635c0_row9_col1, #T_635c0_row9_col14, #T_635c0_row14_col9 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_635c0_row1_col10, #T_635c0_row1_col11, #T_635c0_row10_col1, #T_635c0_row10_col14, #T_635c0_row11_col1, #T_635c0_row11_col14, #T_635c0_row14_col10, #T_635c0_row14_col11 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_635c0_row1_col12, #T_635c0_row1_col13, #T_635c0_row12_col1, #T_635c0_row12_col14, #T_635c0_row13_col1, #T_635c0_row13_col14, #T_635c0_row14_col12, #T_635c0_row14_col13 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_635c0_row2_col3, #T_635c0_row3_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_635c0_row2_col4, #T_635c0_row4_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_635c0_row2_col5, #T_635c0_row5_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_635c0_row2_col6, #T_635c0_row6_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_635c0_row2_col7, #T_635c0_row7_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_635c0_row2_col8, #T_635c0_row8_col2 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_635c0_row2_col9, #T_635c0_row9_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_635c0_row2_col10, #T_635c0_row2_col11, #T_635c0_row10_col2, #T_635c0_row11_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_635c0_row2_col12, #T_635c0_row2_col13, #T_635c0_row5_col10, #T_635c0_row5_col11, #T_635c0_row10_col5, #T_635c0_row11_col5, #T_635c0_row12_col2, #T_635c0_row13_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_635c0_row3_col4, #T_635c0_row4_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_635c0_row3_col5, #T_635c0_row3_col7, #T_635c0_row5_col3, #T_635c0_row7_col3 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_635c0_row3_col8, #T_635c0_row8_col3 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_635c0_row3_col10, #T_635c0_row3_col11, #T_635c0_row10_col3, #T_635c0_row11_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_635c0_row3_col12, #T_635c0_row12_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_635c0_row3_col13, #T_635c0_row13_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_635c0_row4_col5, #T_635c0_row5_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_635c0_row4_col7, #T_635c0_row4_col9, #T_635c0_row7_col4, #T_635c0_row9_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_635c0_row4_col8, #T_635c0_row8_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_635c0_row4_col10, #T_635c0_row4_col11, #T_635c0_row10_col4, #T_635c0_row11_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_635c0_row4_col12, #T_635c0_row4_col13, #T_635c0_row12_col4, #T_635c0_row13_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_635c0_row5_col6, #T_635c0_row6_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_635c0_row5_col7, #T_635c0_row5_col8, #T_635c0_row7_col5, #T_635c0_row8_col5, #T_635c0_row8_col9, #T_635c0_row9_col8 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_635c0_row5_col9, #T_635c0_row9_col5 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_635c0_row5_col12, #T_635c0_row5_col13, #T_635c0_row12_col5, #T_635c0_row13_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_635c0_row6_col7, #T_635c0_row7_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_635c0_row6_col8, #T_635c0_row8_col6 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_635c0_row6_col10, #T_635c0_row6_col11, #T_635c0_row10_col6, #T_635c0_row11_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_635c0_row6_col12, #T_635c0_row6_col13, #T_635c0_row12_col6, #T_635c0_row13_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_635c0_row7_col9, #T_635c0_row9_col7 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_635c0_row7_col13, #T_635c0_row13_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_635c0_row8_col10, #T_635c0_row8_col11, #T_635c0_row8_col12, #T_635c0_row10_col8, #T_635c0_row11_col8, #T_635c0_row12_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_635c0_row9_col10, #T_635c0_row9_col11, #T_635c0_row10_col9, #T_635c0_row11_col9 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_635c0_row9_col12, #T_635c0_row9_col13, #T_635c0_row12_col9, #T_635c0_row13_col9 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_635c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_635c0_level0_col0" class="col_heading level0 col0" >Review_score</th>
#       <th id="T_635c0_level0_col1" class="col_heading level0 col1" >Price_x</th>
#       <th id="T_635c0_level0_col2" class="col_heading level0 col2" >Freight_value</th>
#       <th id="T_635c0_level0_col3" class="col_heading level0 col3" >Payment_value_x</th>
#       <th id="T_635c0_level0_col4" class="col_heading level0 col4" >Product_weight_g</th>

# %%
import numpy as np
np.random.seed(2021)
X = np.array(temp_group_city_sorted_up["time_diff_purchase_carrier_second"].tolist())
y = np.array(temp_group_city_sorted_up["Review_score"].tolist())
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X=X.reshape(-1, 1), y=y)
# Out:
# LinearRegression()

# %%
model.intercept_ #model.coef_ #[0.6]
# Out:
# 4.780350742124

# %%
model.coef_ #array([-2.75162645e-06])
# Out:
# array([-2.75162645e-06])

# %%
temp_group_city_sorted_up["time_diff_purchase_carrier_second"] = temp_group_city_sorted_up["time_diff_purchase_carrier_second"].apply(lambda x : x-145794)
# Out:
# /tmp/ipykernel_1229/3836647404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_group_city_sorted_up["time_diff_purchase_carrier_second"] = temp_group_city_sorted_up["time_diff_purchase_carrier_second"].apply(lambda x : x-145794)

# %%
import numpy as np
np.random.seed(2021)
X = np.array(temp_group_city_sorted_up["time_diff_purchase_carrier_second"].tolist())
y = np.array(temp_group_city_sorted_up["Review_score"].tolist())
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X=X.reshape(-1, 1), y=y)
# Out:
# LinearRegression()

# %%
model.intercept_ #4.37918011476355
# Out:
# 4.37918011476355

# %%
model.coef_ #array([-2.75162645e-06])
# Out:
# array([-2.75162645e-06])

# %%
# 4.780350742124/4.37918011476355 == 1.0916086155049851
# 물품준비시간을 50퍼를 줄이면 10퍼의 리뷰점수가 오르는 효과를 볼수있다. 그런데

# %%
# 가치가 없는 애들의 상관관계 구하기
temp_group_city_sorted_down.corr(numeric_only=True).style.background_gradient(cmap='coolwarm', axis=None)
# 해석
# 리뷰점수와 운임요금은 반비례다 리뷰점수가 높으면 운임요금이 싸다
# Out:
# <style type="text/css">
# #T_b6dfc_row0_col0, #T_b6dfc_row1_col1, #T_b6dfc_row1_col14, #T_b6dfc_row2_col2, #T_b6dfc_row3_col3, #T_b6dfc_row4_col4, #T_b6dfc_row5_col5, #T_b6dfc_row5_col7, #T_b6dfc_row5_col8, #T_b6dfc_row6_col6, #T_b6dfc_row7_col5, #T_b6dfc_row7_col7, #T_b6dfc_row7_col8, #T_b6dfc_row8_col5, #T_b6dfc_row8_col7, #T_b6dfc_row8_col8, #T_b6dfc_row9_col9, #T_b6dfc_row10_col10, #T_b6dfc_row10_col11, #T_b6dfc_row10_col12, #T_b6dfc_row10_col13, #T_b6dfc_row11_col10, #T_b6dfc_row11_col11, #T_b6dfc_row11_col12, #T_b6dfc_row11_col13, #T_b6dfc_row12_col10, #T_b6dfc_row12_col11, #T_b6dfc_row12_col12, #T_b6dfc_row12_col13, #T_b6dfc_row13_col10, #T_b6dfc_row13_col11, #T_b6dfc_row13_col12, #T_b6dfc_row13_col13, #T_b6dfc_row14_col1, #T_b6dfc_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col1, #T_b6dfc_row0_col14, #T_b6dfc_row1_col0, #T_b6dfc_row4_col6, #T_b6dfc_row6_col4, #T_b6dfc_row14_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_b6dfc_row0_col2, #T_b6dfc_row2_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col3, #T_b6dfc_row3_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_b6dfc_row0_col4, #T_b6dfc_row4_col0, #T_b6dfc_row4_col7, #T_b6dfc_row7_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_b6dfc_row0_col5, #T_b6dfc_row5_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col6, #T_b6dfc_row6_col0, #T_b6dfc_row6_col13, #T_b6dfc_row7_col10, #T_b6dfc_row7_col11, #T_b6dfc_row8_col10, #T_b6dfc_row8_col11, #T_b6dfc_row10_col7, #T_b6dfc_row10_col8, #T_b6dfc_row11_col7, #T_b6dfc_row11_col8, #T_b6dfc_row13_col6 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col7, #T_b6dfc_row7_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col8, #T_b6dfc_row8_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col9, #T_b6dfc_row9_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col10, #T_b6dfc_row0_col11, #T_b6dfc_row10_col0, #T_b6dfc_row11_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col12, #T_b6dfc_row12_col0 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_b6dfc_row0_col13, #T_b6dfc_row13_col0 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_b6dfc_row1_col2, #T_b6dfc_row2_col1, #T_b6dfc_row2_col14, #T_b6dfc_row14_col2 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_b6dfc_row1_col3, #T_b6dfc_row2_col5, #T_b6dfc_row3_col1, #T_b6dfc_row3_col14, #T_b6dfc_row5_col2, #T_b6dfc_row14_col3 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_b6dfc_row1_col4, #T_b6dfc_row4_col1, #T_b6dfc_row4_col14, #T_b6dfc_row14_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_b6dfc_row1_col5, #T_b6dfc_row5_col1, #T_b6dfc_row5_col14, #T_b6dfc_row14_col5 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_b6dfc_row1_col6, #T_b6dfc_row6_col1, #T_b6dfc_row6_col14, #T_b6dfc_row14_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_b6dfc_row1_col7, #T_b6dfc_row1_col8, #T_b6dfc_row7_col1, #T_b6dfc_row7_col14, #T_b6dfc_row8_col1, #T_b6dfc_row8_col14, #T_b6dfc_row14_col7, #T_b6dfc_row14_col8 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_b6dfc_row1_col9, #T_b6dfc_row9_col1, #T_b6dfc_row9_col14, #T_b6dfc_row14_col9 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_b6dfc_row1_col10, #T_b6dfc_row1_col11, #T_b6dfc_row10_col1, #T_b6dfc_row10_col14, #T_b6dfc_row11_col1, #T_b6dfc_row11_col14, #T_b6dfc_row14_col10, #T_b6dfc_row14_col11 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b6dfc_row1_col12, #T_b6dfc_row12_col1, #T_b6dfc_row12_col14, #T_b6dfc_row14_col12 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b6dfc_row1_col13, #T_b6dfc_row13_col1, #T_b6dfc_row13_col14, #T_b6dfc_row14_col13 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b6dfc_row2_col3, #T_b6dfc_row3_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_b6dfc_row2_col4, #T_b6dfc_row4_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_b6dfc_row2_col6, #T_b6dfc_row6_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_b6dfc_row2_col7, #T_b6dfc_row2_col8, #T_b6dfc_row5_col6, #T_b6dfc_row6_col5, #T_b6dfc_row7_col2, #T_b6dfc_row8_col2 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_b6dfc_row2_col9, #T_b6dfc_row9_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_b6dfc_row2_col10, #T_b6dfc_row2_col11, #T_b6dfc_row2_col12, #T_b6dfc_row2_col13, #T_b6dfc_row9_col10, #T_b6dfc_row9_col11, #T_b6dfc_row9_col12, #T_b6dfc_row9_col13, #T_b6dfc_row10_col2, #T_b6dfc_row10_col9, #T_b6dfc_row11_col2, #T_b6dfc_row11_col9, #T_b6dfc_row12_col2, #T_b6dfc_row12_col9, #T_b6dfc_row13_col2, #T_b6dfc_row13_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b6dfc_row3_col4, #T_b6dfc_row4_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_b6dfc_row3_col5, #T_b6dfc_row5_col3 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_b6dfc_row3_col6, #T_b6dfc_row6_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_b6dfc_row3_col7, #T_b6dfc_row3_col8, #T_b6dfc_row7_col3, #T_b6dfc_row8_col3 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_b6dfc_row3_col9, #T_b6dfc_row9_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_b6dfc_row3_col10, #T_b6dfc_row3_col11, #T_b6dfc_row5_col12, #T_b6dfc_row5_col13, #T_b6dfc_row6_col10, #T_b6dfc_row6_col11, #T_b6dfc_row10_col3, #T_b6dfc_row10_col6, #T_b6dfc_row11_col3, #T_b6dfc_row11_col6, #T_b6dfc_row12_col5, #T_b6dfc_row13_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b6dfc_row3_col12, #T_b6dfc_row3_col13, #T_b6dfc_row5_col10, #T_b6dfc_row5_col11, #T_b6dfc_row10_col5, #T_b6dfc_row11_col5, #T_b6dfc_row12_col3, #T_b6dfc_row13_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b6dfc_row4_col5, #T_b6dfc_row5_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_b6dfc_row4_col8, #T_b6dfc_row8_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_b6dfc_row4_col9, #T_b6dfc_row9_col4 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_b6dfc_row4_col10, #T_b6dfc_row4_col11, #T_b6dfc_row10_col4, #T_b6dfc_row11_col4 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_b6dfc_row4_col12, #T_b6dfc_row4_col13, #T_b6dfc_row12_col4, #T_b6dfc_row13_col4 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_b6dfc_row5_col9, #T_b6dfc_row9_col5 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_b6dfc_row6_col7, #T_b6dfc_row6_col8, #T_b6dfc_row7_col6, #T_b6dfc_row8_col6 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_b6dfc_row6_col9, #T_b6dfc_row9_col6 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_b6dfc_row6_col12, #T_b6dfc_row12_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b6dfc_row7_col9, #T_b6dfc_row8_col9, #T_b6dfc_row9_col7, #T_b6dfc_row9_col8 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_b6dfc_row7_col12, #T_b6dfc_row8_col12, #T_b6dfc_row8_col13, #T_b6dfc_row12_col7, #T_b6dfc_row12_col8, #T_b6dfc_row13_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_b6dfc_row7_col13, #T_b6dfc_row13_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6dfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6dfc_level0_col0" class="col_heading level0 col0" >Review_score</th>
#       <th id="T_b6dfc_level0_col1" class="col_heading level0 col1" >Price_x</th>
#       <th id="T_b6dfc_level0_col2" class="col_heading level0 col2" >Freight_value</th>
#       <th id="T_b6dfc_level0_col3" class="col_heading level0 col3" >Payment_value_x</th>
#       <th id="T_b6dfc_level0_col4" class="col_heading level0 col4" >Product_weight_g</th>
#       <th id="T_b6dfc_level0_col5" class="col_heading level0 col5" >Distance</th>
#       <th id="T_b6dfc_level0_col6" class="col_heading level0 col6" >time_diff_purchase_carrier_second</th>
#       <th id="T_b6dfc_level0_col7" class="col_heading level0 col7" >time_diff_purchase_customer_second</th>
#       <th id="T_b6dfc_level0_col8" class="col_heading level0 col8" >time_diff_carrier_customer_second</

# %%
temp_group_city_sorted_down.Customer_state
# Out:
# 10    MG
# 17    PR
# 7     ES
# 25    SP
# Name: Customer_state, dtype: object

# %%
# temp_group_city_sorted_down

# %%
temp_group_city_sorted
# Out:
#    Customer_state  Review_score     Price_x  Freight_value  Payment_value_x  \
# 1              AL      3.795567  184.119754      35.245813       246.528867
# 0              AC      4.012346  183.849383      40.437531       235.288889
# 14             PB      4.023508  182.902315      42.803725       281.165045
# 26             TO      4.120000  171.019767      39.582000       211.071133
# 16             PI      3.906561  162.413837      38.612028       246.462425
# 3              AP      4.297297  161.676622      33.661081       264.598649
# 13             PA      3.804260  160.043479      34.640071       222.986582
# 19             RN      4.061185  157.806711      34.894761       196.293901
# 20             RO      4.049808  155.818851      40.956513       223.376475
# 5              CE      3.864394  153.950210      32.230696       217.432313
# 24             SE      3.835777  147.650381      35.017331       218.030499
# 9              MA      3.737333  146.615827      38.310907       243.543947
# 12             MT      3.994888  146.436738      28.018640       237.312812
# 15             PE      4.020457  142.019320      31.824747       197.071149
# 11             MS      4.118182  141.770896      23.038195       194.690468
# 21             RR      3.785714  141.637381      40.252619       218.881429
# 2              AM      4.116438  139.688767      33.781301       208.852945
# 4              BA      3.841087  131.760594      26.035255       197.625381
# 6              DF      4.030527  126.754476      20.995874       172.827986
# 8              GO      4.013432  125.834289      22.394632       189.332631
# 18             RJ      3.854270  123.946166      20.765978       181.397068
# 23             SC      4.022733  121.887293      21.068540       179.763322
# 22             RS      4.061764  120.265774      21.405924       170.476096
# 10             MG      4.110121  118.876852      20.298114       169.406683
# 17             PR      4.123441  117.895936      20.318697       178.558237
# 7              ES      3.980907  114.841103      21.540563       167.158673
# 25             SP      4.176120  109.446383      15.059011       152.674036
#
#     Product_weight_g   Distance  time_diff_purchase_carrier_second  \
# 1        1950.679803  17.024909                      319321.546798
# 0        2057.320988  24.502951                      303591.691358
# 14       2281.244123  19.298416                      318265.875226
# 26       3589.853333  13.015428                      308919.310000
# 16       2491.934394  17.645286                      279247.602386
# 3        1871.054054  23.512257                      289961.229730
# 13       2163.530426  20.589619                      299794.632860
# 19       1942.535373  19.080020                      324341.780115
# 20       2480.704981  20.509862                      250603.873563
# 5        1995.771574  19.726289                      297688.116026
# 24       2297.395894  15.236851                      305379.307918
# 9        2022.301333  19.106909                      334750.421333
# 12       2283.617587  12.537498                      274096.323108
# 15       1900.480746  18.024941                      284322.798436
# 11       2342.019481   8.050004                      273909.718182
# 21       1832.476190  29.466362                      326923.880952
# 2        1609.054795  23.863128                      233192.657534
# 4        2264.320908  12.350098                      296316.839686
# 6        1723.396356   7.447976                      288264.011817
# 8        1984.711904   7.032200                      266800.145438
# 18       2323.792161   4.693773                      296302.900685
# 23       2135.640661   5.275273                      295898.898734
# 22       2081.610476   8.060639                      284671.911107
# 10       2185.058423   4.962829                      285044.555790
# 17       2074.881400   4.642935                      292217.177621
# 7        2083.123150   7.630136                      298644.341289
# 25       2076.513433   2.329926                      279880.519116
#
#     time_diff_purchase_customer_second  time_diff_carrier_customer_second  \
# 1                         2.160449e+06                       1.841127e+06
# 0                         1.871732e+06                       1.568140e+06
# 14                        1.817279e+06                       1.499013e+06
# 26                        1.517516e+06                       1.208596e+06
# 16                        1.711384e+06                       1.432136e+06
# 3                         2.430999e+06                       2.141038e+06
# 13                        2.091381e+06                       1.791586e+06
# 19                        1.727412e+06                       1.403071e+06
# 20                        1.736080e+06                       1.485476e+06
# 5                         1.849262e+06                       1.551574e+06
# 24                        1.913391e+06                       1.608012e+06
# 9                         1.890389e+06                       1.555638e+06
# 12                        1.585109e+06                       1.311013e+06
# 15                        1.603595e+06                       1.319272e+06
# 11                        1.347152e+06                       1.073242e+06
# 21                        2.457689e+06                       2.130765e+06
# 2                         2.351501e+06                       2.118309e+06
# 4                         1.690146e+06                       1.393829e+06
# 6                         1.149730e+06                       8.614657e+05
# 8                         1.353241e+06                       1.086441e+06
# 18                        1.350484e+06                       1.054181e+06
# 23                        1.324869e+06                       1.028970e+06
# 22                        1.343154e+06                       1.058482e+06
# 10                        1.057141e+06                       7.720969e+05
# 17                        1.059437e+06                       7.672196e+05
# 7                         1.358245e+06                       1.059601e+06
# 25                        7.710981e+05                       4.912176e+05
#
#     time_diff_customer_delivery_second  Customer_city  count_ratio  \
# 1                         2.510456e+06            406     0.003888
# 0                         3.303366e+06             81     0.000776
# 14                        2.587447e+06            553     0.005295
# 26                        2.252126e+06            300     0.002873
# 16                        2.354693e+06            503     0.004816
# 3                         3.756678e+06             74     0.000709
# 13                        2.974306e+06            986     0.009441
# 19                        2.534230e+06            523     0.005008
# 20                        3.185226e+06            261     0.002499
# 5                         2.424422e+06           1379     0.013204
# 24                        2.390792e+06            341     0.003265
# 9                         2.378794e+06            750     0.007181
# 12                        2.493617e+06            978     0.009365
# 15                        2.451819e+06           1662     0.015914
# 11                        2.026561e+06            770     0.007373
# 21                        3.672195e+06             42     0.000402
# 2                         3.723177e+06            146     0.001398
# 4                         2.281951e+06           3568     0.034164
# 6                         1.876802e+06           2031     0.019447
# 8                         2.113255e+06           2159     0.020673
# 18                        2.040062e+06          13573     0.129965
# 23                        1.980863e+06           3871     0.037066
# 22                        2.247241e+06           5861     0.056120
# 10                        1.890943e+06          12341     0.118168
# 17                        1.908192e+06           5371     0.051429
# 7                         1.937133e+06           2095     0.020060
# 25                        1.452697e+06          43811     0.419501
#
#     price_ratio  payment_ratio  value_ratio
# 1      0.005981       0.005598     1.538519
# 0      0.001192       0.001066     1.536259
# 14     0.008093       0.008696     1.528346
# 26     0.004105       0.003542     1.429054
# 16     0.006536       0.006934     1.357142
# 3      0.000957       0.001095     1.350982
# 13     0.012626       0.012297     1.337335
# 19     0.006604       0.005742     1.318645
# 20     0.003254       0.003261     1.302034
# 5      0.016986       0.016770     1.286420
# 24     0.004028       0.004158     1.233778
# 9      0.008798       0.010216     1.225133
# 12     0.011459       0.012981     1.223636
# 15     0.018886       0.018319     1.186724
# 11     0.008734       0.008385     1.184648
# 21     0.000476       0.000514     1.183533
# 2      0.001632       0.001705     1.167250
# 4      0.037615       0.039439     1.101002
# 6      0.020598       0.019633     1.059170
# 8      0.021737       0.022863     1.051481
# 18     0.134605       0.137708     1.035704
# 23     0.037751       0.038920     1.018499
# 22     0.056398       0.055884     1.004950
# 10     0.117382       0.116932     0.993344
# 17     0.050665       0.053640     0.985147
# 7      0.019250       0.019587     0.959621
# 25     0.383651       0.374112     0.914542
