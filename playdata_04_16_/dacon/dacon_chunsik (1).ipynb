# %% [markdown]
# # 취합된 데이터 파일 확인

# %%
# 피클 import
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# pickle 주소위치 확인!! total_df에 저장
with open ("./dacon_total_df_240504_00.pkl", "rb") as file:
    df = pickle.load(file)

# %%
with open ("./purchase_number_of_orders.pkl", "rb") as file:
    구매건수 = pickle.load(file)

# %%
# pd.options.display.max_columns = None

# %%
df['YearMonthDay'] = df['Order_purchase_timestamp'].dt.strftime('%Y%m%d')

# %%
# 값 확인
df
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 0      ORDER_00329  PRODUCT_07734  SELLER_0146                 2017
# 1      ORDER_00616  PRODUCT_04278  SELLER_0914                 2017
# 2      ORDER_01235  PRODUCT_23369  SELLER_1445                 2017
# 3      ORDER_01293  PRODUCT_04377  SELLER_2603                 2017
# 4      ORDER_02078  PRODUCT_21531  SELLER_2660                 2017
# ...            ...            ...          ...                  ...
# 90188  ORDER_87982  PRODUCT_29370  SELLER_0335                 2019
# 90189  ORDER_88004  PRODUCT_02102  SELLER_1628                 2019
# 90190  ORDER_88021  PRODUCT_22041  SELLER_1230                 2019
# 90191  ORDER_88035  PRODUCT_02524  SELLER_1627                 2019
# 90192  ORDER_88059  PRODUCT_08954  SELLER_0612                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# 0                        10  REVIEW_65349             1           2017-10-21
# 1                        10  REVIEW_21396             1           2017-10-22
# 2                        10  REVIEW_50469             3           2017-10-25
# 3                        10  REVIEW_75101             1           2017-10-27
# 4                        10  REVIEW_58071             4           2017-10-28
# ...                     ...           ...           ...                  ...
# 90188                     7  REVIEW_24242             4           2019-07-13
# 90189                     7  REVIEW_72610             5           2019-07-28
# 90190                     7  REVIEW_55262             5           2019-07-26
# 90191                     7  REVIEW_32238             5           2019-07-25
# 90192                     7  REVIEW_30982             5           2019-07-25
#
#       Review_answer_timestamp   Price  ...  time_diff_purchase_carrier  \
# 0         2017-10-22 10:10:28   75.00  ...             4 days 19:14:35
# 1         2017-10-24 23:33:19  294.90  ...             5 days 00:36:27
# 2         2017-10-26 23:52:15   93.90  ...             4 days 00:33:27
# 3         2017-10-27 10:41:59   44.90  ...            18 days 10:41:12
# 4         2018-01-08 15:09:32   39.90  ...            16 days 03:22:15
# ...                       ...     ...  ...                         ...
# 90188     2019-07-15 14:23:30   24.90  ...             2 days 21:39:21
# 90189     2019-07-29 02:33:56   70.00  ...             1 days 13:29:56
# 90190     2019-07-26 22:20:21   40.99  ...             2 days 15:11:54
# 90191     2019-07-26 01:32:39   31.50  ...             1 days 12:45:44
# 90192     2019-07-26 10:33:47  159.00  ...             0 days 22:13:22
#
#       time_diff_purchase_customer time_diff_carrier_customer  \
# 0                11 days 07:04:11            6 days 11:49:36
# 1                 8 days 00:36:27            3 days 00:00:00
# 2                 7 days 00:33:27            3 days 00:00:00
# 3                20 days 16:37:27            2 days 05:56:15
# 4                21 days 23:20:46            5 days 19:58:31
# ...                           ...                        ...
# 90188             6 days 06:30:13            3 days 08:50:52
# 90189             3 days 01:05:13            1 days 11:35:17
# 90190             4 days 16:36:34            2 days 01:24:40
# 90191             9 days 23:01:43            8 days 10:15:59
# 90192             2 days 05:48:00            1 days 07:34:38
#
#       time_diff_customer_delivery time_diff_purchase_carrier_second  \
# 0                51 days 09:24:00                          414875.0
# 1                46 days 08:15:33                          434187.0
# 2                49 days 09:13:11                          347607.0
# 3                34 days 06:27:53                         1593672.0
# 4                32 days 11:26:31                         1394535.0
# ...                           ...                               ...
# 90188            12 days 06:11:08                          250761.0
# 90189             4 days 00:56:43                          134996.0
# 90190            11 days 06:22:20                          227514.0
# 90191            14 days 04:41:01                          132344.0
# 90192             6 days 01:13:22                           80002.0
#
#       time_diff_purchase_customer_second time_diff_carrier_customer_second  \
# 0                               975851.0                          560976.0
# 1                               693387.0                          259200.0
# 2                               606807.0                          259200.0
# 3                              1787847.0                          194175.0
# 4                              1898446.0                          503911.0
# ...                                  ...                               ...
# 90188                           541813.0                          291052.0
# 90189                           263113.0                          128117.0
# 90190                           405394.0                          177880.0
# 90191                           860503.0                          728159.0
# 90192                           193680.0                          113678.0
#
#       time_diff_customer_delivery_second  YearMonth YearMonthDay
# 0                              4440240.0     201710     20171005
# 1                              4004133.0     201710     20171005
# 2                              4266791.0     201710     20171004
# 3                              2960873.0     201710     20171007
# 4                              2805991.0     201710     20171005
# ...                                  ...        ...          ...
# 90188                          1059068.0     201907     20190706
# 90189                           349003.0     201907     20190724
# 90190                           973340.0     201907     20190721
# 90191                          1226461.0     201907     20190714
# 90192                           522802.0     201907     20190722
#
# [90193 rows x 46 columns]

# %%
구매건수
# Out:
#       YearMonthDay     Customer_unique_id  order_count  당일구매  재구매  일별구매
# 0         20181121  CUSTOMER_Unique_45441            1     7    0     1
# 1         20190512  CUSTOMER_Unique_66687            1     7    0     1
# 2         20180615  CUSTOMER_Unique_00387            1     7    0     1
# 3         20180115  CUSTOMER_Unique_29448            1     6    0     1
# 4         20180620  CUSTOMER_Unique_16144            1     6    0     1
# ...            ...                    ...          ...   ...  ...   ...
# 86462     20181025  CUSTOMER_Unique_70253            1     1    0     1
# 86463     20181025  CUSTOMER_Unique_69963            1     1    0     1
# 86464     20181025  CUSTOMER_Unique_69383            1     1    0     1
# 86465     20181025  CUSTOMER_Unique_68513            1     1    0     1
# 86466     20190730  CUSTOMER_Unique_78742            1     1    0     1
#
# [86467 rows x 6 columns]

# %%
total_df = df.merge(구매건수, how='inner', on=['Customer_unique_id','order_count','YearMonthDay'])
total_df
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 0      ORDER_00329  PRODUCT_07734  SELLER_0146                 2017
# 1      ORDER_00616  PRODUCT_04278  SELLER_0914                 2017
# 2      ORDER_01235  PRODUCT_23369  SELLER_1445                 2017
# 3      ORDER_01293  PRODUCT_04377  SELLER_2603                 2017
# 4      ORDER_02078  PRODUCT_21531  SELLER_2660                 2017
# ...            ...            ...          ...                  ...
# 90188  ORDER_87982  PRODUCT_29370  SELLER_0335                 2019
# 90189  ORDER_88004  PRODUCT_02102  SELLER_1628                 2019
# 90190  ORDER_88021  PRODUCT_22041  SELLER_1230                 2019
# 90191  ORDER_88035  PRODUCT_02524  SELLER_1627                 2019
# 90192  ORDER_88059  PRODUCT_08954  SELLER_0612                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# 0                        10  REVIEW_65349             1           2017-10-21
# 1                        10  REVIEW_21396             1           2017-10-22
# 2                        10  REVIEW_50469             3           2017-10-25
# 3                        10  REVIEW_75101             1           2017-10-27
# 4                        10  REVIEW_58071             4           2017-10-28
# ...                     ...           ...           ...                  ...
# 90188                     7  REVIEW_24242             4           2019-07-13
# 90189                     7  REVIEW_72610             5           2019-07-28
# 90190                     7  REVIEW_55262             5           2019-07-26
# 90191                     7  REVIEW_32238             5           2019-07-25
# 90192                     7  REVIEW_30982             5           2019-07-25
#
#       Review_answer_timestamp   Price  ...  time_diff_customer_delivery  \
# 0         2017-10-22 10:10:28   75.00  ...             51 days 09:24:00
# 1         2017-10-24 23:33:19  294.90  ...             46 days 08:15:33
# 2         2017-10-26 23:52:15   93.90  ...             49 days 09:13:11
# 3         2017-10-27 10:41:59   44.90  ...             34 days 06:27:53
# 4         2018-01-08 15:09:32   39.90  ...             32 days 11:26:31
# ...                       ...     ...  ...                          ...
# 90188     2019-07-15 14:23:30   24.90  ...             12 days 06:11:08
# 90189     2019-07-29 02:33:56   70.00  ...              4 days 00:56:43
# 90190     2019-07-26 22:20:21   40.99  ...             11 days 06:22:20
# 90191     2019-07-26 01:32:39   31.50  ...             14 days 04:41:01
# 90192     2019-07-26 10:33:47  159.00  ...              6 days 01:13:22
#
#       time_diff_purchase_carrier_second time_diff_purchase_customer_second  \
# 0                              414875.0                           975851.0
# 1                              434187.0                           693387.0
# 2                              347607.0                           606807.0
# 3                             1593672.0                          1787847.0
# 4                             1394535.0                          1898446.0
# ...                                 ...                                ...
# 90188                          250761.0                           541813.0
# 90189                          134996.0                           263113.0
# 90190                          227514.0                           405394.0
# 90191                          132344.0                           860503.0
# 90192                           80002.0                           193680.0
#
#       time_diff_carrier_customer_second time_diff_customer_delivery_second  \
# 0                              560976.0                          4440240.0
# 1                              259200.0                          4004133.0
# 2                              259200.0                          4266791.0
# 3                              194175.0                          2960873.0
# 4                              503911.0                          2805991.0
# ...                                 ...                                ...
# 90188                          291052.0                          1059068.0
# 90189                          128117.0                           349003.0
# 90190                          177880.0                           973340.0
# 90191                          728159.0                          1226461.0
# 90192                          113678.0                           522802.0
#
#       YearMonth YearMonthDay 당일구매  재구매 일별구매
# 0        201710     20171005    1    0    1
# 1        201710     20171005    1    0    1
# 2        201710     20171004    1    0    1
# 3        201710     20171007    1    1    1
# 4        201710     20171005    1    1    1
# ...         ...          ...  ...  ...  ...
# 90188    201907     20190706    1    0    1
# 90189    201907     20190724    1    0    1
# 90190    201907     20190721    1    0    1
# 90191    201907     20190714    1    0    1
# 90192    201907     20190722    1    0    1
#
# [90193 rows x 49 columns]

# %%
total_df[total_df.Customer_unique_id.duplicated()]
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 28     ORDER_07781  PRODUCT_09474  SELLER_1696                 2017
# 48     ORDER_14790  PRODUCT_20924  SELLER_1886                 2017
# 118    ORDER_39447  PRODUCT_12361  SELLER_0556                 2017
# 127    ORDER_43046  PRODUCT_29434  SELLER_0556                 2017
# 158    ORDER_54125  PRODUCT_22861  SELLER_2668                 2017
# ...            ...            ...          ...                  ...
# 90096  ORDER_85970  PRODUCT_26930  SELLER_1601                 2019
# 90110  ORDER_86347  PRODUCT_22963  SELLER_0338                 2019
# 90125  ORDER_86798  PRODUCT_21235  SELLER_1347                 2019
# 90126  ORDER_86798  PRODUCT_29096  SELLER_1856                 2019
# 90176  ORDER_87604  PRODUCT_14452  SELLER_2744                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# 28                       10  REVIEW_63634             5           2017-10-19
# 48                       10  REVIEW_51125             4           2017-11-09
# 118                      10  REVIEW_47885             3           2017-11-10
# 127                      10  REVIEW_29609             1           2017-12-08
# 158                      10  REVIEW_65696             5           2017-11-09
# ...                     ...           ...           ...                  ...
# 90096                     7  REVIEW_58698             4           2019-07-25
# 90110                     7  REVIEW_43709             5           2019-07-31
# 90125                     7  REVIEW_15060             3           2019-07-08
# 90126                     7  REVIEW_15060             3           2019-07-08
# 90176                     7  REVIEW_52269             5           2019-07-22
#
#       Review_answer_timestamp   Price  ...  time_diff_customer_delivery  \
# 28        2017-10-19 20:43:13   59.90  ...             44 days 09:23:01
# 48        2017-11-12 09:52:41   39.90  ...             27 days 09:56:02
# 118       2017-11-16 20:16:14   59.90  ...             34 days 10:18:40
# 127       2017-12-08 04:22:22   39.90  ...             49 days 10:57:39
# 158       2017-11-10 15:57:56  177.90  ...             19 days 10:51:23
# ...                       ...     ...  ...                          ...
# 90096     2019-07-26 11:38:03   44.00  ...             12 days 06:35:29
# 90110     2019-08-01 00:48:11   18.90  ...              6 days 05:08:13
# 90125     2019-07-08 17:48:22   29.99  ...             22 days 10:44:12
# 90126     2019-07-08 17:48:22   24.00  ...             22 days 10:44:12
# 90176     2019-07-24 17:33:18   91.55  ...              4 days 09:56:27
#
#       time_diff_purchase_carrier_second time_diff_purchase_customer_second  \
# 28                             391207.0                           654007.0
# 48                            2040891.0                          2993414.0
# 118                            349100.0                          2784959.0
# 127                            393956.0                           656756.0
# 158                           1919695.0                          2866233.0
# ...                                 ...                                ...
# 90096                          485328.0                          1103239.0
# 90110                          154198.0                           697125.0
# 90125                           62068.0                           492676.0
# 90126                           62068.0                           492676.0
# 90176                          354378.0                           421791.0
#
#       time_diff_carrier_customer_second time_diff_customer_delivery_second  \
# 28                             262800.0                          3835381.0
# 48                             952523.0                          2368562.0
# 118                           2435859.0                          2974720.0
# 127                            262800.0                          4273059.0
# 158                            946538.0                          1680683.0
# ...                                 ...                                ...
# 90096                          617911.0                          1060529.0
# 90110                          542927.0                           536893.0
# 90125                          430608.0                          1939452.0
# 90126                          430608.0                          1939452.0
# 90176                           67413.0                           381387.0
#
#       YearMonth YearMonthDay 당일구매  재구매 일별구매
# 28       201710     20171009    2    0    1
# 48       201710     20171004    2    0    1
# 118      201710     20171008    1    1    2
# 127      201710     20171009    2    1    1
# 158      201710     20171006    2    0    1
# ...         ...          ...  ...  ...  ...
# 90096    201907     20190711    2    0    1
# 90110    201907     20190718    2    0    1
# 90125    201907     20190701    3    0    1
# 90126    201907     20190701    3    0    1
# 90176    201907     20190716    2    0    1
#
# [6063 rows x 49 columns]

# %%
total_df[total_df.Customer_unique_id == 'CUSTOMER_Unique_12500']
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 12425  ORDER_68322  PRODUCT_17813  SELLER_1513                 2018
# 15144  ORDER_04560  PRODUCT_20683  SELLER_2051                 2018
# 16927  ORDER_16944  PRODUCT_06065  SELLER_0248                 2018
# 18722  ORDER_29830  PRODUCT_27845  SELLER_2136                 2018
# 21873  ORDER_52036  PRODUCT_00174  SELLER_1513                 2018
# 34146  ORDER_34886  PRODUCT_22712  SELLER_2136                 2018
# 42211  ORDER_75218  PRODUCT_27845  SELLER_2136                 2018
# 44386  ORDER_86124  PRODUCT_10865  SELLER_2136                 2018
# 66597  ORDER_03243  PRODUCT_02458  SELLER_0574                 2019
# 70796  ORDER_22012  PRODUCT_13656  SELLER_2283                 2019
# 88961  ORDER_61547  PRODUCT_28549  SELLER_0574                 2019
# 89479  ORDER_72482  PRODUCT_05816  SELLER_2136                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# 12425                     6  REVIEW_39426             5           2018-06-25
# 15144                     9  REVIEW_02941             5           2018-09-12
# 16927                     7  REVIEW_19052             5           2018-08-01
# 18722                     7  REVIEW_74986             5           2018-07-22
# 21873                     8  REVIEW_02730             5           2018-08-10
# 34146                    11  REVIEW_40285             5           2018-11-28
# 42211                    10  REVIEW_30787             5           2018-11-01
# 44386                    10  REVIEW_35083             5           2018-10-24
# 66597                     5  REVIEW_68970             5           2019-05-24
# 70796                     5  REVIEW_59539             5           2019-05-25
# 88961                     7  REVIEW_35090             5           2019-07-27
# 89479                     7  REVIEW_05046             5           2019-07-11
#
#       Review_answer_timestamp   Price  ...  time_diff_customer_delivery  \
# 12425     2018-06-26 20:53:55   39.90  ...             13 days 11:04:10
# 15144     2018-09-13 01:39:44   39.90  ...             10 days 10:32:11
# 16927     2018-08-02 01:22:24  149.90  ...             14 days 07:00:02
# 18722     2018-07-24 12:52:56   13.99  ...              9 days 07:40:20
# 21873     2018-08-11 03:39:10   69.90  ...             15 days 08:37:32
# 34146     2018-11-28 21:59:16   13.99  ...              6 days 05:10:47
# 42211     2018-11-02 01:42:01   13.99  ...              9 days 08:26:13
# 44386     2018-10-24 16:55:12   29.99  ...              6 days 05:26:59
# 66597     2019-05-24 18:57:51   45.99  ...              5 days 08:26:51
# 70796     2019-05-25 15:32:23   51.80  ...              5 days 12:01:37
# 88961     2019-07-28 13:07:54   99.00  ...              6 days 05:30:32
# 89479     2019-07-12 01:52:09   22.99  ...              6 days 02:32:30
#
#       time_diff_purchase_carrier_second time_diff_purchase_customer_second  \
# 12425                           76538.0                           395942.0
# 15144                           61880.0                           486777.0
# 16927                           99013.0                           586088.0
# 18722                          157744.0                           234522.0
# 21873                          208217.0                           368565.0
# 34146                          158763.0                           427640.0
# 42211                           82850.0                           167745.0
# 44386                          150406.0                           414477.0
# 66597                           56009.0                           146918.0
# 70796                           71585.0                           132568.0
# 88961                          131518.0                           246986.0
# 89479                          128387.0                           514337.0
#
#       time_diff_carrier_customer_second time_diff_customer_delivery_second  \
# 12425                          319404.0                          1163050.0
# 15144                          424897.0                           901931.0
# 16927                          487075.0                          1234802.0
# 18722                           76778.0                           805220.0
# 21873                          160348.0                          1327052.0
# 34146                          268877.0                           537047.0
# 42211                           84895.0                           807973.0
# 44386                          264071.0                           538019.0
# 66597                           90909.0                           462411.0
# 70796                           60983.0                           475297.0
# 88961                          115468.0                           538232.0
# 89479                          385950.0                           527550.0
#
#       YearMonth YearMonthDay 당일구매  재구매 일별구매
# 12425    201806     20180618    1    0   12
# 15144    201809     20180905    1    0   12
# 16927    201807     20180724    1    0   12
# 18722    201807     20180718    1    0   12
# 21873    201808     20180805    1    0   12
# 34146    201811     20181122    1    0   12
# 42211    201810     20181029    1    0   12
# 44386    201810     20181018    1    0   12
# 66597    201905     20190521    1    0   12
# 70796    201905     20190522    1    0   12
# 88961    201907     20190723    1    0   12
# 89479    201907     20190704    1    0   12
#
# [12 rows x 49 columns]

# %%
# 각 고객별 최근 주문 일시를 구합니다.
max_order_timestamps = total_df.groupby('Customer_unique_id')['Order_purchase_timestamp'].transform('max')
# latest_order_timestamp 열에 각 고객별 최근 주문 일시를 할당합니다.
total_df['latest_order_timestamp'] = max_order_timestamps

# %%
# 각 고객별 첫 주문 일시를 구합니다.
min_order_timestamps = total_df.groupby('Customer_unique_id')['Order_purchase_timestamp'].transform('min')
# latest_order_timestamp 열에 각 고객별 첫 주문 일시를 할당합니다.
total_df['first_order_timestamp'] = min_order_timestamps

# %%
# '재구매여부' 열 추가
# order_count컬럼에 대하여 이 값이 2보다 크면 재구매여부에는 y 아니면 n을 저장
total_df['재구매여부'] = total_df['order_count'].apply(lambda x: 'Y' if x >= 2 else 'N')

# %%
# '구매간격' 열 추가
# latest_order_timestamp  first_order_timestamp 컬럼 데이트타입 변경
total_df['latest_order_timestamp'] = pd.to_datetime(total_df['latest_order_timestamp'])
total_df['first_order_timestamp'] = pd.to_datetime(total_df['first_order_timestamp'])

# 두 값의 차이를 days로 변경
total_df['구매간격'] = (total_df['latest_order_timestamp'] - total_df['first_order_timestamp']).dt.days

# %%
# order_count는 customer_unique_id별 order_count를 의미한다
#

# %%
# '구매주기' 열 추가
# 만약 order_count의 값이 1이거나 구매간격이 0이라면 => 한번만 샀거나 그날 산것이므로 구매주기에 0을 저장
# 그게 아닐시 구매간격에서 order_count에서 1뺀거를 나눈것이 구매주기 
total_df['구매주기'] = total_df.apply\
(lambda row: 0 if (row['order_count'] - 1 == 0) or (row['구매간격'] == 0) else row['구매간격'] / (row['order_count'] - 1), axis=1)

# %%
# total_df[total_df.구매주기==0.500000]
# 값 확인

# %%
# total_df.구매주기.value_counts()
# 값 확인

# %%
total_df[total_df['구매주기'] > 0]
# 값확인
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 491    ORDER_03520  PRODUCT_23978  SELLER_1849                 2018
# 750    ORDER_07689  PRODUCT_15510  SELLER_0567                 2018
# 856    ORDER_09816  PRODUCT_24900  SELLER_1678                 2018
# 1424   ORDER_19702  PRODUCT_29235  SELLER_0671                 2018
# 2025   ORDER_30725  PRODUCT_23978  SELLER_1849                 2018
# ...            ...            ...          ...                  ...
# 88286  ORDER_48690  PRODUCT_00774  SELLER_2669                 2019
# 88563  ORDER_54123  PRODUCT_03512  SELLER_2199                 2019
# 88564  ORDER_54123  PRODUCT_05125  SELLER_2199                 2019
# 89226  ORDER_67028  PRODUCT_07667  SELLER_0775                 2019
# 89905  ORDER_81809  PRODUCT_00976  SELLER_2123                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# 491                       1  REVIEW_38126             1           2018-01-31
# 750                       3  REVIEW_28047             4           2018-04-07
# 856                       3  REVIEW_78421             5           2018-04-08
# 1424                      3  REVIEW_53691             5           2018-03-15
# 2025                      1  REVIEW_48137             1           2018-01-31
# ...                     ...           ...           ...                  ...
# 88286                     7  REVIEW_03824             5           2019-07-24
# 88563                     7  REVIEW_81940             2           2019-07-15
# 88564                     7  REVIEW_81940             2           2019-07-15
# 89226                     7  REVIEW_29228             5           2019-07-24
# 89905                     7  REVIEW_79588             3           2019-07-26
#
#       Review_answer_timestamp  Price  Freight_value     Customer_id  \
# 491       2018-01-31 12:17:41    9.9          10.96  CUSTOMER_34143
# 750       2018-04-09 22:01:06   29.0          10.96  CUSTOMER_66237
# 856       2018-04-08 21:03:08   24.9          14.52  CUSTOMER_16237
# 1424      2018-03-16 10:55:04   98.3          41.92  CUSTOMER_14371
# 2025      2018-01-31 12:16:03    9.9           9.62  CUSTOMER_50092
# ...                       ...    ...            ...             ...
# 88286     2019-07-24 20:25:55   26.0           7.02  CUSTOMER_82818
# 88563     2019-07-15 15:12:14  290.0          34.40  CUSTOMER_53416
# 88564     2019-07-15 15:12:14  320.0          17.20  CUSTOMER_53416
# 89226     2019-07-27 09:46:18   34.0          19.43  CUSTOMER_50825
# 89905     2019-07-27 18:51:59   59.8          19.61  CUSTOMER_08098
#
#       Order_status Order_purchase_timestamp Order_delivered_carrier_date  \
# 491      delivered      2018-01-23 13:31:26          2018-01-24 10:57:50
# 750      delivered      2018-03-29 23:48:57          2018-04-03 17:00:21
# 856      delivered      2018-03-30 13:21:20          2018-04-03 10:34:32
# 1424     delivered      2018-03-02 15:22:55          2018-03-08 15:30:31
# 2025     delivered      2018-01-21 06:58:31          2018-01-24 09:36:22
# ...            ...                      ...                          ...
# 88286    delivered      2019-07-17 23:36:52          2019-07-18 13:41:00
# 88563    delivered      2019-07-05 00:58:05          2019-07-11 10:39:00
# 88564    delivered      2019-07-05 00:58:05          2019-07-11 10:39:00
# 89226    delivered      2019-07-18 07:41:58          2019-07-18 13:43:00
# 89905    delivered      2019-07-17 14:25:51          2019-07-19 11:58:00
#
#       Order_delivered_customer_date Order_estimated_delivery_date  \
# 491             2018-01-30 15:12:57                    2018-02-28
# 750             2018-04-06 13:28:49                    2018-04-18
# 856             2018-04-07 11:33:15                    2018-04-25
# 1424            2018-03-14 13:12:23                    2018-03-31
# 2025            2018-01-30 13:57:45                    2018-03-21
# ...                             ...                           ...
# 88286           2019-07-23 16:47:30                    2019-08-10
# 88563           2019-07-14 00:04:50                    2019-07-25
# 88564           2019-07-14 00:04:50                    2019-07-25
# 89226           2019-07-23 21:39:38                    2019-08-02
# 89905           2019-07-25 14:38:31                    2019-08-07
#
#       Payment_type  Payment_installments            Product_category_name  \
# 491    credit_card                     1                  furniture_decor
# 750         boleto                     1                    health_beauty
# 856         boleto                     1                   bed_bath_table
# 1424        boleto                     1                   home_utilities
# 2025   credit_card                     1                  furniture_decor
# ...            ...                   ...                              ...
# 88286  credit_card                     2                   bed_bath_table
# 88563       boleto                     1                   home_utilities
# 88564       boleto                     1                   home_utilities
# 89226  credit_card                     8  construction_tools_construction
# 89905  credit_card                     5                  furniture_decor
#
#           Customer_unique_id  Customer_zipcode_prefix          Customer_city  \
# 491    CUSTOMER_Unique_33681                    13844             mogi-guacu
# 750    CUSTOMER_Unique_09818                     7417                  aruja
# 856    CUSTOMER_Unique_16129                    35180                timoteo
# 1424   CUSTOMER_Unique_14283                    22221         rio de janeiro
# 2025   CUSTOMER_Unique_33681                    13844             mogi-guacu
# ...                      ...                      ...                    ...
# 88286  CUSTOMER_Unique_05776                     4111              sao paulo
# 88563  CUSTOMER_Unique_05195                    15084  sao jose do rio preto
# 88564  CUSTOMER_Unique_05195                    15084  sao jose do rio preto
# 89226  CUSTOMER_Unique_16065                    39801          teofilo otoni
# 89905  CUSTOMER_Unique_08075                    88070          florianopolis
#
#       Customer_state  Seller_zipcode_prefix   Seller_city Seller_state  \
# 491               SP                   4362     sao paulo           SP
# 750               SP                  11701  praia grande           SP
# 856               MG                  13405    piracicaba           SP
# 1424              RJ                   4361     sao paulo           SP
# 2025              SP                   4362     sao paulo           SP
# ...              ...                    ...           ...          ...
# 88286             SP                  14940      ibitinga           SP
# 88563             SP                   3111     sao paulo           SP
# 88564             SP                   3111     sao paulo           SP
# 89226             MG                   2124     sao paulo           SP
# 89905             SC                  18608      botucatu           SP
#
#        order_count  Order_purchase_quarter     순이익      매출액  Customer_lat  \
# 491              5                       1    49.5   104.30    -22.383437
# 750              2                       1    58.0    79.92    -23.383802
# 856              3                       1    74.7   118.26    -19.545341
# 1424             2                       1   196.6   280.44    -22.928999
# 2025             5                       1    49.5    97.60    -22.383437
# ...            ...                     ...     ...      ...           ...
# 88286            2                       3    52.0    66.04    -23.586393
# 88563            4                       3  1160.0  1297.60    -20.829838
# 88564            2                       3   640.0   674.40    -20.829838
# 89226            6                       3   204.0   320.58    -17.858065
# 89905            3                       3   179.4   238.23    -27.591471
#
#        Customer_lng  Seller_lat  Seller_lng    Distance  \
# 491      -46.947927  -23.645348  -46.668963  143.193262
# 750      -46.323443  -24.008923  -46.419125   70.189749
# 856      -42.643849  -22.708702  -47.664701  628.334921
# 1424     -43.181450  -23.643527  -46.662809  364.333108
# 2025     -46.947927  -23.645348  -46.668963  143.193262
# ...             ...         ...         ...         ...
# 88286    -46.632292  -21.757321  -48.829744  303.630923
# 88563    -49.378392  -23.560183  -46.604393  416.791609
# 88564    -49.378392  -23.560183  -46.604393  416.791609
# 89226    -41.495279  -23.506977  -46.577121  820.781032
# 89905    -48.583157  -22.866053  -48.460692  525.587477
#
#       time_diff_purchase_carrier time_diff_purchase_customer  \
# 491              0 days 21:26:24             7 days 01:41:31
# 750              4 days 17:11:24             7 days 13:39:52
# 856              3 days 21:13:12             7 days 22:11:55
# 1424             6 days 00:07:36            11 days 21:49:28
# 2025             3 days 02:37:51             9 days 06:59:14
# ...                          ...                         ...
# 88286            0 days 14:04:08             5 days 17:10:38
# 88563            6 days 09:40:55             8 days 23:06:45
# 88564            6 days 09:40:55             8 days 23:06:45
# 89226            0 days 06:01:02             5 days 13:57:40
# 89905            1 days 21:32:09             8 days 00:12:40
#
#       time_diff_carrier_customer time_diff_customer_delivery  \
# 491              6 days 04:15:07            28 days 08:47:03
# 750              2 days 20:28:28            11 days 10:31:11
# 856              4 days 00:58:43            17 days 12:26:45
# 1424             5 days 21:41:52            16 days 10:47:37
# 2025             6 days 04:21:23            49 days 10:02:15
# ...                          ...                         ...
# 88286            5 days 03:06:30            17 days 07:12:30
# 88563            2 days 13:25:50            10 days 23:55:10
# 88564            2 days 13:25:50            10 days 23:55:10
# 89226            5 days 07:56:38             9 days 02:20:22
# 89905            6 days 02:40:31            12 days 09:21:29
#
#        time_diff_purchase_carrier_second  time_diff_purchase_customer_second  \
# 491                              77184.0                            610891.0
# 750                             407484.0                            653992.0
# 856                             335592.0                            684715.0
# 1424                            518856.0                           1028968.0
# 2025                            268671.0                            802754.0
# ...                                  ...                                 ...
# 88286                            50648.0                            493838.0
# 88563                           553255.0                            774405.0
# 88564                           553255.0                            774405.0
# 89226                            21662.0                            482260.0
# 89905                           163929.0                            691960.0
#
#        time_diff_carrier_customer_second  time_diff_customer_delivery_second  \
# 491                             533707.0                           2450823.0
# 750                             246508.0                            988271.0
# 856                             349123.0                           1513605.0
# 1424                            510112.0                           1421257.0
# 2025                            534083.0                           4269735.0
# ...                                  ...                                 ...
# 88286                           443190.0                           1494750.0
# 88563                           221150.0                            950110.0
# 88564                           221150.0                            950110.0
# 89226                           460598.0                            786022.0
# 89905                           528031.0                           1070489.0
#
#       YearMonth YearMonthDay  당일구매  재구매  일별구매 latest_order_timestamp  \
# 491      201801     20180123     1    1     3    2018-01-23 13:31:26
# 750      201803     20180329     1    1     2    2018-05-22 23:38:44
# 856      201803     20180330     1    1     3    2019-01-12 16:26:06
# 1424     201803     20180302     1    1     2    2018-05-09 15:29:51
# 2025     201801     20180121     1    1     3    2018-01-23 13:31:26
# ...         ...          ...   ...  ...   ...                    ...
# 88286    201907     20190717     1    1     4    2019-07-17 23:36:52
# 88563    201907     20190705     1    1     3    2019-07-20 04:05:49
# 88564    201907     20190705     1    1     3    2019-07-20 04:05:49
# 89226    201907     20190718     1    1     2    2019-07-18 07:41:58
# 89905    201907     20190717     1    1     2    2019-07-17 14:25:51
#
#       first_order_timestamp 재구매여부  구매간격   구매주기
# 491     2018-01-21 06:58:31     Y     2    0.5
# 750     2018-03-29 23:48:57     Y    53   53.0
# 856     2018-03-30 13:21:20     Y   288  144.0
# 1424    2018-03-02 15:22:55     Y    68   68.0
# 2025    2018-01-21 06:58:31     Y     2    0.5
# ...                     ...   ...   ...    ...
# 88286   2019-05-02 01:27:50     Y    76   76.0
# 88563   2019-07-05 00:58:05     Y    15    5.0
# 88564   2019-07-05 00:58:05     Y    15   15.0
# 89226   2018-10-26 14:42:55     Y   264   52.8
# 89905   2019-04-11 02:48:15     Y    97   48.5
#
# [368 rows x 54 columns]

# %%
total_df[total_df['Customer_unique_id'] == 'CUSTOMER_Unique_85216']
#값 확인
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 64960  ORDER_84288  PRODUCT_27785  SELLER_1049                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# 64960                     1  REVIEW_67953             5           2019-02-08
#
#       Review_answer_timestamp  Price  Freight_value     Customer_id  \
# 64960     2019-02-10 20:07:29   29.9           14.1  CUSTOMER_88065
#
#       Order_status Order_purchase_timestamp Order_delivered_carrier_date  \
# 64960    delivered      2019-01-24 02:22:12          2019-01-26 21:28:37
#
#       Order_delivered_customer_date Order_estimated_delivery_date  \
# 64960           2019-02-07 17:42:55                    2019-02-22
#
#       Payment_type  Payment_installments Product_category_name  \
# 64960  credit_card                     8           electronics
#
#           Customer_unique_id  Customer_zipcode_prefix Customer_city  \
# 64960  CUSTOMER_Unique_85216                    26112  belford roxo
#
#       Customer_state  Seller_zipcode_prefix Seller_city Seller_state  \
# 64960             RJ                   5588   sao paulo           SP
#
#        order_count  Order_purchase_quarter   순이익   매출액  Customer_lat  \
# 64960            2                       1  59.8  88.0    -22.748891
#
#        Customer_lng  Seller_lat  Seller_lng    Distance  \
# 64960    -43.402189  -23.576017  -46.741186  353.514031
#
#       time_diff_purchase_carrier time_diff_purchase_customer  \
# 64960            2 days 19:06:25            14 days 15:20:43
#
#       time_diff_carrier_customer time_diff_customer_delivery  \
# 64960           11 days 20:14:18            14 days 06:17:05
#
#        time_diff_purchase_carrier_second  time_diff_purchase_customer_second  \
# 64960                           241585.0                           1264843.0
#
#        time_diff_carrier_customer_second  time_diff_customer_delivery_second  \
# 64960                          1023258.0                           1232225.0
#
#       YearMonth YearMonthDay  당일구매  재구매  일별구매 latest_order_timestamp  \
# 64960    201901     20190124     1    1     1    2019-01-24 02:22:12
#
#       first_order_timestamp 재구매여부  구매간격  구매주기
# 64960   2019-01-24 02:22:12     Y     0   0.0

# %%
total_df.iloc[0]
# Out:
# Order_id                                        ORDER_00329
# Product_id                                    PRODUCT_07734
# Seller_id                                       SELLER_0146
# Order_purchase_year                                    2017
# Order_purchase_month                                     10
# Review_id                                      REVIEW_65349
# Review_score                                              1
# Review_creation_date                    2017-10-21 00:00:00
# Review_answer_timestamp                 2017-10-22 10:10:28
# Price                                                  75.0
# Freight_value                                         20.58
# Customer_id                                  CUSTOMER_06208
# Order_status                                      delivered
# Order_purchase_timestamp                2017-10-05 07:31:49
# Order_delivered_carrier_date            2017-10-10 02:46:24
# Order_delivered_customer_date           2017-10-16 14:36:00
# Order_estimated_delivery_date           2017-12-07 00:00:00
# Payment_type                                         boleto
# Payment_installments                                      1
# Product_category_name                 computers_accessories
# Customer_unique_id                    CUSTOMER_Unique_06197
# Customer_zipcode_prefix                               50090
# Customer_city                                        recife
# Customer_state                                           PE
# Seller_zipcode_prefix                                 30190
# Seller_city                                  belo horizonte
# Seller_state                                             MG
# order_count                                               1
# Order_purchase_quarter                                    4
# 순이익                                                    75.0
# 매출액                                                   95.58
# Customer_lat                                      -8.074551
# Customer_lng                                     -34.895035
# Seller_lat                                        -19.92464
# Seller_lng                                       -43.946122
# Distance                                         1638.82195
# time_diff_purchase_carrier                  4 days 19:14:35
# time_diff_purchase_customer                11 days 07:04:11
# time_diff_carrier_customer                  6 days 11:49:36
# time_diff_customer_delivery                51 days 09:24:00
# time_diff_purchase_carrier_second                  414875.0
# time_diff_purchase_customer_second                 975851.0
# time_diff_carrier_customer_second                  560976.0
# time_diff_customer_delivery_second                4440240.0
# YearMonth                                            201710
# YearMonthDay                                       20171005
# 당일구매                                                      1
# 재구매                                                       0
# 일별구매                                                      1
# Name: 0, dtype: object

# %%
total_df[total_df['order_count'] >= 2].sort_values(by='Customer_unique_id')
# 값확인
# Out:
#           Order_id     Product_id    Seller_id  Order_purchase_year  \
# 37105  ORDER_50057  PRODUCT_04082  SELLER_0417                 2018
# 67776  ORDER_08495  PRODUCT_14758  SELLER_1822                 2019
# 19271  ORDER_33608  PRODUCT_27916  SELLER_1192                 2018
# 74212  ORDER_37143  PRODUCT_02080  SELLER_1933                 2019
# 2715   ORDER_42637  PRODUCT_19338  SELLER_0525                 2018
# ...            ...            ...          ...                  ...
# 16002  ORDER_10401  PRODUCT_26756  SELLER_1695                 2018
# 29658  ORDER_13012  PRODUCT_09019  SELLER_2592                 2018
# 37417  ORDER_51621  PRODUCT_11899  SELLER_2669                 2018
# 46511  ORDER_07342  PRODUCT_10765  SELLER_1059                 2019
# 64960  ORDER_84288  PRODUCT_27785  SELLER_1049                 2019
#
#        Order_purchase_month     Review_id  Review_score Review_creation_date  \
# 37105                    10  REVIEW_59807             1           2018-10-26
# 67776                     4  REVIEW_22414             2           2019-04-27
# 19271                     7  REVIEW_22368             5           2018-07-22
# 74212                     6  REVIEW_32926             1           2019-06-14
# 2715                      3  REVIEW_68307             4           2018-04-05
# ...                     ...           ...           ...                  ...
# 16002                     7  REVIEW_06824             3           2018-07-29
# 29658                    11  REVIEW_42458             1           2018-12-09
# 37417                    10  REVIEW_84161             5           2018-10-31
# 46511                     1  REVIEW_40449             1           2019-03-16
# 64960                     1  REVIEW_67953             5           2019-02-08
#
#       Review_answer_timestamp  Price  Freight_value     Customer_id  \
# 37105     2018-10-27 09:19:26  59.90          17.67  CUSTOMER_00019
# 67776     2019-04-27 20:35:22  11.99          13.47  CUSTOMER_00042
# 19271     2018-07-24 11:19:02  99.97          16.14  CUSTOMER_00052
# 74212     2019-06-18 18:14:36  12.09          18.23  CUSTOMER_00053
# 2715      2018-04-08 23:14:41  14.99          15.56  CUSTOMER_00068
# ...                       ...    ...            ...             ...
# 16002     2018-08-02 12:21:42  15.99          21.48  CUSTOMER_88036
# 29658     2018-12-11 17:51:56  49.00          11.38  CUSTOMER_88049
# 37417     2018-10-31 14:45:02  47.99          12.69  CUSTOMER_88053
# 46511     2019-03-16 12:32:19  79.99          30.40  CUSTOMER_88064
# 64960     2019-02-10 20:07:29  29.90          14.10  CUSTOMER_88065
#
#       Order_status Order_purchase_timestamp Order_delivered_carrier_date  \
# 37105    delivered      2018-10-15 11:08:48          2018-10-16 21:36:29
# 67776    delivered      2019-04-18 14:18:09          2019-04-20 00:47:44
# 19271    delivered      2018-07-11 09:36:46          2018-07-11 19:42:28
# 74212    delivered      2019-06-06 16:53:30          2019-06-08 14:46:00
# 2715     delivered      2018-03-23 11:07:12          2018-03-24 10:36:22
# ...            ...                      ...                          ...
# 16002    delivered      2018-07-15 14:31:13          2018-07-18 20:12:44
# 29658    delivered      2018-11-14 18:25:42          2018-11-23 22:10:31
# 37417    delivered      2018-10-24 10:44:15          2018-10-25 20:37:04
# 46511    delivered      2019-01-30 15:28:21          2019-02-16 16:28:33
# 64960    delivered      2019-01-24 02:22:12          2019-01-26 21:28:37
#
#       Order_delivered_customer_date Order_estimated_delivery_date  \
# 37105           2018-10-25 22:30:58                    2018-11-06
# 67776           2019-04-26 16:26:38                    2019-05-11
# 19271           2018-07-21 20:06:22                    2018-08-04
# 74212           2019-06-13 20:48:25                    2019-07-17
# 2715            2018-04-04 14:58:07                    2018-04-13
# ...                             ...                           ...
# 16002           2018-07-28 18:32:36                    2018-08-10
# 29658           2018-12-08 00:18:54                    2018-12-14
# 37417           2018-10-30 21:16:59                    2018-11-10
# 46511           2019-03-16 20:03:53                    2019-03-13
# 64960           2019-02-07 17:42:55                    2019-02-22
#
#       Payment_type  Payment_installments  Product_category_name  \
# 37105  credit_card                     2           garden_tools
# 67776       boleto                     1        furniture_decor
# 19271  credit_card                     5         bed_bath_table
# 74212  credit_card                     3         home_utilities
# 2715   credit_card                     4                 drinks
# ...            ...                   ...                    ...
# 16002  credit_card                    10        furniture_decor
# 29658  credit_card                     2  computers_accessories
# 37417       boleto                     1         bed_bath_table
# 46511  credit_card                     6       office_furniture
# 64960  credit_card                     8            electronics
#
#           Customer_unique_id  Customer_zipcode_prefix          Customer_city  \
# 37105  CUSTOMER_Unique_00019                    74914   aparecida de goiania
# 67776  CUSTOMER_Unique_00042                    30320         belo horizonte
# 19271  CUSTOMER_Unique_00052                    75388               trindade
# 74212  CUSTOMER_Unique_00053                    85808               cascavel
# 2715   CUSTOMER_Unique_00068                     5890              sao paulo
# ...                      ...                      ...                    ...
# 16002  CUSTOMER_Unique_85188                    95020          caxias do sul
# 29658  CUSTOMER_Unique_85201                    59082                  natal
# 37417  CUSTOMER_Unique_85205                    15063  sao jose do rio preto
# 46511  CUSTOMER_Unique_85215                    82410               curitiba
# 64960  CUSTOMER_Unique_85216                    26112           belford roxo
#
#       Customer_state  Seller_zipcode_prefix            Seller_city  \
# 37105             GO                  15025  sao jose do rio preto
# 67776             MG                  38408             uberlandia
# 19271             GO                  32677                  betim
# 74212             PR                   2030              sao paulo
# 2715              SP                  37706        pocos de caldas
# ...              ...                    ...                    ...
# 16002             RS                  19800                  assis
# 29658             RN                  12327                jacarei
# 37417             SP                  14940               ibitinga
# 46511             PR                   8577        itaquaquecetuba
# 64960             RJ                   5588              sao paulo
#
#       Seller_state  order_count  Order_purchase_quarter     순이익     매출액  \
# 37105           SP            3                       4  179.70  232.71
# 67776           MG            2                       2   23.98   50.92
# 19271           MG            2                       3  199.94  232.22
# 74212           SP            5                       2   60.45  151.60
# 2715            MG            2                       1   29.98   61.10
# ...            ...          ...                     ...     ...     ...
# 16002           SP            2                       3   31.98   74.94
# 29658           SP            3                       4  147.00  181.14
# 37417           SP            2                       4   95.98  121.36
# 46511           SP            6                       1  479.94  662.34
# 64960           SP            2                       1   59.80   88.00
#
#        Customer_lat  Customer_lng  Seller_lat  Seller_lng     Distance  \
# 37105    -16.753520    -49.263289  -20.806707  -49.389165   450.889144
# 67776    -19.967129    -43.939936  -18.924080  -48.249267   466.471567
# 19271    -16.652982    -49.483372  -19.943004  -44.113624   674.587439
# 74212    -24.951323    -53.515340  -23.505871  -46.624683   716.865791
# 2715     -23.665643    -46.788618  -21.830410  -46.549391   205.537886
# ...             ...           ...         ...         ...          ...
# 16002    -29.166314    -51.178314  -22.665586  -50.415247   726.859067
# 29658     -5.862579    -35.196031  -23.302318  -45.971888  2256.654533
# 37417    -20.812008    -49.337907  -21.757321  -48.829744   117.562759
# 46511    -25.381120    -49.330147  -23.486111  -46.366721   366.590548
# 64960    -22.748891    -43.402189  -23.576017  -46.741186   353.514031
#
#       time_diff_purchase_carrier time_diff_purchase_customer  \
# 37105            1 days 10:27:41            10 days 11:22:10
# 67776            1 days 10:29:35             8 days 02:08:29
# 19271            0 days 10:05:42            10 days 10:29:36
# 74212            1 days 21:52:30             7 days 03:54:55
# 2715             0 days 23:29:10            12 days 03:50:55
# ...                          ...                         ...
# 16002            3 days 05:41:31            13 days 04:01:23
# 29658            9 days 03:44:49            23 days 05:53:12
# 37417            1 days 09:52:49             6 days 10:32:44
# 46511           17 days 01:00:12            45 days 04:35:32
# 64960            2 days 19:06:25            14 days 15:20:43
#
#       time_diff_carrier_customer time_diff_customer_delivery  \
# 37105            9 days 00:54:29            11 days 01:29:02
# 67776            6 days 15:38:54            14 days 07:33:22
# 19271           10 days 00:23:54            13 days 03:53:38
# 74212            5 days 06:02:25            33 days 03:11:35
# 2715            11 days 04:21:45             8 days 09:01:53
# ...                          ...                         ...
# 16002            9 days 22:19:52            12 days 05:27:24
# 29658           14 days 02:08:23             5 days 23:41:06
# 37417            5 days 00:39:55            10 days 02:43:01
# 46511           28 days 03:35:20           -4 days +03:56:07
# 64960           11 days 20:14:18            14 days 06:17:05
#
#        time_diff_purchase_carrier_second  time_diff_purchase_customer_second  \
# 37105                           124061.0                            904930.0
# 67776                           124175.0                            698909.0
# 19271                            36342.0                            901776.0
# 74212                           165150.0                            618895.0
# 2715                             84550.0                           1050655.0
# ...                                  ...                                 ...
# 16002                           279691.0                           1137683.0
# 29658                           791089.0                           2008392.0
# 37417                           121969.0                            556364.0
# 46511                          1472412.0                           3904532.0
# 64960                           241585.0                           1264843.0
#
#        time_diff_carrier_customer_second  time_diff_customer_delivery_second  \
# 37105                           780869.0                            955742.0
# 67776                           574734.0                           1236802.0
# 19271                           865434.0                           1137218.0
# 74212                           453745.0                           2862695.0
# 2715                            966105.0                            723713.0
# ...                                  ...                                 ...
# 16002                           857992.0                           1056444.0
# 29658                          1217303.0                            517266.0
# 37417                           434395.0                            873781.0
# 46511                          2432120.0                           -331433.0
# 64960                          1023258.0                           1232225.0
#
#       YearMonth YearMonthDay  당일구매  재구매  일별구매 latest_order_timestamp  \
# 37105    201810     20181015     1    1     1    2018-10-15 11:08:48
# 67776    201904     20190418     1    1     1    2019-04-18 14:18:09
# 19271    201807     20180711     1    1     1    2018-07-11 09:36:46
# 74212    201906     20190606     1    1     1    2019-06-06 16:53:30
# 2715     201803     20180323     1    1     1    2018-03-23 11:07:12
# ...         ...          ...   ...  ...   ...                    ...
# 16002    201807     20180715     1    1     2    2018-07-15 14:31:13
# 29658    201811     20181114     1    1     1    2018-11-14 18:25:42
# 37417    201810     20181024     1    1     1    2018-10-24 10:44:15
# 46511    201901     20190130     1    1     1    2019-01-30 15:28:21
# 64960    201901     20190124     1    1     1    2019-01-24 02:22:12
#
#       first_order_timestamp 재구매여부  구매간격  구매주기
# 37105   2018-10-15 11:08:48     Y     0   0.0
# 67776   2019-04-18 14:18:09     Y     0   0.0
# 19271   2018-07-11 09:36:46     Y     0   0.0
# 74212   2019-06-06 16:53:30     Y     0   0.0
# 2715    2018-03-23 11:07:12     Y     0   0.0
# ...                     ...   ...   ...   ...
# 16002   2018-07-15 14:31:13     Y     0   0.0
# 29658   2018-11-14 18:25:42     Y     0   0.0
# 37417   2018-10-24 10:44:15     Y     0   0.0
# 46511   2019-01-30 15:28:21     Y     0   0.0
# 64960   2019-01-24 02:22:12     Y     0   0.0
#
# [6321 rows x 54 columns]

# %%
# Customer_unique_id로 묶어서 order_count Freight_value Price의 합 을 df로 
tmp2 = total_df.groupby(['Customer_unique_id'], as_index=False)[['order_count', 'Freight_value', 'Price']].sum()

# %%
tmp2.head(1)
# 값 확인
# Out:
#       Customer_unique_id  order_count  Freight_value   Price
# 0  CUSTOMER_Unique_00000            1          21.88  124.99

# %%
#tmp3 = total_df.groupby(['Customer_unique_id'])[['재구매여부', '구매주기']]
# tatal-df에서 컬럼 3개 추출해서 새로운 df로
tmp3 = total_df[['Customer_unique_id','재구매여부', '구매주기']]

# %%
tmp3.head(1)
# 값 확인
# Out:
#       Customer_unique_id 재구매여부  구매주기
# 0  CUSTOMER_Unique_06197     N   0.0

# %%
# 위에서 뽑은 tmp2 tmp3를 Customer_unique_id 기준으로 left join
reorder = pd.merge(tmp2, tmp3, on='Customer_unique_id', how='left')
reorder
# Out:
#           Customer_unique_id  order_count  Freight_value   Price 재구매여부  구매주기
# 0      CUSTOMER_Unique_00000            1          21.88  124.99     N   0.0
# 1      CUSTOMER_Unique_00001            1          46.48  289.00     N   0.0
# 2      CUSTOMER_Unique_00002            1          17.79  139.94     N   0.0
# 3      CUSTOMER_Unique_00003            1          23.36  149.94     N   0.0
# 4      CUSTOMER_Unique_00004            2          59.36  506.52     N   0.0
# ...                      ...          ...            ...     ...   ...   ...
# 90188  CUSTOMER_Unique_85234            1          13.88   74.90     N   0.0
# 90189  CUSTOMER_Unique_85235            1          14.16  114.90     N   0.0
# 90190  CUSTOMER_Unique_85236            1          19.04   37.00     N   0.0
# 90191  CUSTOMER_Unique_85237            1          22.07  689.00     N   0.0
# 90192  CUSTOMER_Unique_85238            1           7.78   13.99     N   0.0
#
# [90193 rows x 6 columns]

# %%
# 다시 재구매여부를 기준으로 sum출력
temp = reorder.groupby(['재구매여부'], as_index=False)[['order_count', 'Freight_value', 'Price']].sum()

# 재구여부를 기준으로 Customer_unique_id 개수새기
temp2 = reorder.groupby(['재구매여부'], as_index=False)[['Customer_unique_id']].count()

# merge하기 재구매여부를 기준
reorder_yn = pd.merge(temp,temp2, on='재구매여부', how='inner')
reorder_yn
# Out:
#   재구매여부  order_count  Freight_value        Price  Customer_unique_id
# 0     N        98930     1927758.38  11885798.71               83872
# 1     Y        17482      140656.73    653055.06                6321

# %%
# 재구매여부에 따른 차지하는 비율 컬럼 생성
reorder_yn["재구매여부_ratio"] = reorder_yn["Customer_unique_id"] / reorder_yn["Customer_unique_id"].sum()

# %%
reorder_yn
# 값 확인
# Out:
#   재구매여부  order_count  Freight_value        Price  Customer_unique_id  \
# 0     N        98930     1927758.38  11885798.71               83872
# 1     Y        17482      140656.73    653055.06                6321
#
#    재구매여부_ratio
# 0     0.929917
# 1     0.070083

# %%
temp
# 값 확인
# Out:
#   재구매여부  order_count  Freight_value        Price
# 0     N        98930     1927758.38  11885798.71
# 1     Y        17482      140656.73    653055.06

# %%
# 운임비와 순수익을 더해서 매출액 컬럼 생성
reorder_yn['Payment_value'] = reorder_yn['Freight_value'] + reorder_yn['Price']

# %%
reorder_yn
# Out:
#   재구매여부  order_count  Freight_value        Price  Customer_unique_id  \
# 0     N        98930     1927758.38  11885798.71               83872
# 1     Y        17482      140656.73    653055.06                6321
#
#    재구매여부_ratio  Payment_value
# 0     0.929917    13813557.09
# 1     0.070083      793711.79

# %%
# 위의 표를 참고!
reorder_yn['구매당순이익'] = round(reorder_yn['Price'] / reorder_yn['order_count'], 2)
reorder_yn['구매당운송비'] = round(reorder_yn['Freight_value'] / reorder_yn['order_count'], 2)
reorder_yn['고객당순이익'] = round(reorder_yn['Price'] / reorder_yn['Customer_unique_id'], 0)
reorder_yn['고객당구매수'] = round(reorder_yn['order_count'] / reorder_yn['Customer_unique_id'], 2)
reorder_yn['고객당매출액'] = round(reorder_yn['Payment_value'] / reorder_yn['Customer_unique_id'], 0)

# %%
reorder_yn
# Out:
#   재구매여부  order_count  Freight_value        Price  Customer_unique_id  \
# 0     N        98930     1927758.38  11885798.71               83872
# 1     Y        17482      140656.73    653055.06                6321
#
#    재구매여부_ratio  Payment_value  구매당순이익  구매당운송비  고객당순이익  고객당구매수  고객당매출액
# 0     0.929917    13813557.09  120.14   19.49   142.0    1.18   165.0
# 1     0.070083      793711.79   37.36    8.05   103.0    2.77   126.0

# %%
# reorder

# %%
# '구매주기_구간' 열 추가
reorder_filtered = reorder[reorder['구매주기'] > 0]

# %%
# 재구매가 없는 고객 그리고 구매주기가 0인 고객
reorder_filtered_zero =  reorder[(reorder['구매주기'] == 0) & (reorder.재구매여부=="N")]

# %%
reorder_filtered_zero.shape
# 모양보기
# Out:
# (83872, 6)

# %%
reorder_filtered_zero.shape[0] + reorder_filtered.shape[0]
# 의미없는 코드
# Out:
# 84240

# %%
reorder_filtered_zero
# Out:
#           Customer_unique_id  order_count  Freight_value   Price 재구매여부  구매주기
# 0      CUSTOMER_Unique_00000            1          21.88  124.99     N   0.0
# 1      CUSTOMER_Unique_00001            1          46.48  289.00     N   0.0
# 2      CUSTOMER_Unique_00002            1          17.79  139.94     N   0.0
# 3      CUSTOMER_Unique_00003            1          23.36  149.94     N   0.0
# 4      CUSTOMER_Unique_00004            2          59.36  506.52     N   0.0
# ...                      ...          ...            ...     ...   ...   ...
# 90188  CUSTOMER_Unique_85234            1          13.88   74.90     N   0.0
# 90189  CUSTOMER_Unique_85235            1          14.16  114.90     N   0.0
# 90190  CUSTOMER_Unique_85236            1          19.04   37.00     N   0.0
# 90191  CUSTOMER_Unique_85237            1          22.07  689.00     N   0.0
# 90192  CUSTOMER_Unique_85238            1           7.78   13.99     N   0.0
#
# [83872 rows x 6 columns]

# %%
with open("./reorder_filtered_zero.pkl", "wb") as file:
    pickle.dump(reorder_filtered_zero, file)
#중간 피클파일추출

# %%
# 중복값 출ㄹ력되는지 확
count=0
for i in range(100):
    sample_df = reorder_filtered_zero.sample(frac=0.1, random_state=None)
    # print(sample_df)
    if (sample_df.shape[0] == sample_df.duplicated().shape[0]):
        count=count+1
print(count)
# Out:
# 100

# %%
reorder_filtered_zero[~reorder_filtered_zero.Customer_unique_id.duplicated()]
# Out:
#           Customer_unique_id  order_count  Freight_value   Price 재구매여부  구매주기
# 0      CUSTOMER_Unique_00000            1          21.88  124.99     N   0.0
# 1      CUSTOMER_Unique_00001            1          46.48  289.00     N   0.0
# 2      CUSTOMER_Unique_00002            1          17.79  139.94     N   0.0
# 3      CUSTOMER_Unique_00003            1          23.36  149.94     N   0.0
# 4      CUSTOMER_Unique_00004            2          59.36  506.52     N   0.0
# ...                      ...          ...            ...     ...   ...   ...
# 90188  CUSTOMER_Unique_85234            1          13.88   74.90     N   0.0
# 90189  CUSTOMER_Unique_85235            1          14.16  114.90     N   0.0
# 90190  CUSTOMER_Unique_85236            1          19.04   37.00     N   0.0
# 90191  CUSTOMER_Unique_85237            1          22.07  689.00     N   0.0
# 90192  CUSTOMER_Unique_85238            1           7.78   13.99     N   0.0
#
# [78571 rows x 6 columns]

# %%
# 재구매를 하지 않는 고객에서 랜덤으로 매번 10퍼씩 뽑는
# sample_df = reorder_filtered_zero.sample(frac=0.1, random_state=None)
sample_df = reorder_filtered_zero[~reorder_filtered_zero.Customer_unique_id.duplicated()].sample(frac=0.1, random_state=None)
# print(sample_df)
sample_df.duplicated().shape[0]
# Out:
# 7857

# %%
sample_df
# Out:
#           Customer_unique_id  order_count  Freight_value   Price 재구매여부  구매주기
# 17740  CUSTOMER_Unique_16274            1          12.65   67.91     N   0.0
# 21775  CUSTOMER_Unique_19987            1          12.97   89.90     N   0.0
# 75305  CUSTOMER_Unique_70786            1           9.27   37.90     N   0.0
# 71989  CUSTOMER_Unique_67571            1          14.16   59.00     N   0.0
# 54637  CUSTOMER_Unique_50954            1          25.38   15.00     N   0.0
# ...                      ...          ...            ...     ...   ...   ...
# 27592  CUSTOMER_Unique_25404            1          14.10   32.00     N   0.0
# 10987  CUSTOMER_Unique_10054            5          48.79  229.59     N   0.0
# 15713  CUSTOMER_Unique_14417            1           7.39   30.00     N   0.0
# 32     CUSTOMER_Unique_00030            2          38.85   74.98     N   0.0
# 85735  CUSTOMER_Unique_80899            1          15.10   29.00     N   0.0
#
# [7857 rows x 6 columns]

# %%
reorder_filtered
# Out:
#           Customer_unique_id  order_count  Freight_value   Price 재구매여부   구매주기
# 212    CUSTOMER_Unique_00188            4          26.87  118.90     Y   28.0
# 213    CUSTOMER_Unique_00188            4          26.87  118.90     Y   28.0
# 255    CUSTOMER_Unique_00227            4          22.76  109.90     Y    5.5
# 465    CUSTOMER_Unique_00414            3          47.23  105.50     Y   32.0
# 528    CUSTOMER_Unique_00470            5          99.25  578.32     Y  207.0
# ...                      ...          ...            ...     ...   ...    ...
# 81464  CUSTOMER_Unique_76745            3          22.49   74.70     Y   41.0
# 82186  CUSTOMER_Unique_77444            3          34.90  126.46     Y  176.0
# 84376  CUSTOMER_Unique_79562            4          23.19  330.32     Y   20.0
# 86891  CUSTOMER_Unique_82027            4          22.90  163.90     Y  120.0
# 86892  CUSTOMER_Unique_82027            4          22.90  163.90     Y  120.0
#
# [368 rows x 6 columns]

# %%
reorder_filtered['구매주기_구간'] = pd.cut(reorder_filtered['구매주기'], \
                    bins=[-float('inf'), 7, 14, 21, 28, float('inf')], \
                    labels=['7일 이내', '14일 이내', '21일 이내', '28일 이내', '29일 이상'], right=False)
# ~7일 미만, ~14일 미만 ~21일 미만 ~28일 미만 ~29이상
# Out:
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3114017426.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reorder_filtered['구매주기_구간'] = pd.cut(reorder_filtered['구매주기'], \

# %%
# reorder_filtered.head(20)
# 값 확인

# %%
# 이상치를 제거하기 이ㅜ해서 컬럼 unique 리스트화
reorder_구매주기_구간_list = reorder_filtered.구매주기_구간.unique().tolist()

# %%
reorder_구매주기_구간_list
# Out:
# ['29일 이상', '7일 이내', '14일 이내', '28일 이내', '21일 이내']

# %%
# 구매주기 구간에 있는 이상치를 제거하기
def remove_outliers(df, column):
    Q1 = df['Price'].quantile(0.25)
    Q3 = df['Price'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df['Price'] >= lower_bound) & (df['Price'] <= upper_bound)]

    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# 구매주기 구간별로 이상치 제거
reorder_filtered_cleaned = reorder_filtered.groupby('구매주기_구간').apply(remove_outliers, column='Price').reset_index(drop=True)
# Out:
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3379321410.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   reorder_filtered_cleaned = reorder_filtered.groupby('구매주기_구간').apply(remove_outliers, column='Price').reset_index(drop=True)
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3379321410.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reorder_filtered_cleaned = reorder_filtered.groupby('구매주기_구간').apply(remove_outliers, column='Price').reset_index(drop=True)

# %%
reorderfiltered_cleaned = reorder_filtered.groupby('구매주기_구간').apply(remove_outliers, column='Price').reset_index(drop=True)
# Out:
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3622697133.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   reorderfiltered_cleaned = reorder_filtered.groupby('구매주기_구간').apply(remove_outliers, column='Price').reset_index(drop=True)
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3622697133.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reorderfiltered_cleaned = reorder_filtered.groupby('구매주기_구간').apply(remove_outliers, column='Price').reset_index(drop=True)

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=reorder_filtered_cleaned, x='구매주기_구간', y='Price')
# Out:
# <Axes: xlabel='구매주기_구간', ylabel='Price'>
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 45236 (\N{HANGUL SYLLABLE NAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45236 (\N{HANGUL SYLLABLE NAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
re_df = reorder_filtered_cleaned.groupby(['구매주기_구간'], as_index=False)[['Customer_unique_id']].count()
# Out:
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\1356318949.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   re_df = reorder_filtered_cleaned.groupby(['구매주기_구간'], as_index=False)[['Customer_unique_id']].count()

# %%
reorder_filtered_cleaned.Customer_unique_id.count() # 370개
# Out:
# 354

# %%
re_df
# Out:
#   구매주기_구간  Customer_unique_id
# 0   7일 이내                  37
# 1  14일 이내                  25
# 2  21일 이내                  30
# 3  28일 이내                  21
# 4  29일 이상                 241

# %%
sample_df["Customer_unique_id"].count()
# Out:
# 7857

# %%
re_df[re_df.구매주기_구간=="29일 이상"].Customer_unique_id
# Out:
# 4    241
# Name: Customer_unique_id, dtype: int64

# %%
sample_df["Customer_unique_id"].count()
# Out:
# 7857

# %%
temp_sum = re_df[re_df.구매주기_구간=="29일 이상"]["Customer_unique_id"]+sample_df["Customer_unique_id"].count()

# %%
# 위에서 재구매안한고객의 10퍼를 기존의 값과 더한
re_df.loc[(re_df.구매주기_구간=="29일 이상"),"Customer_unique_id" ] = temp_sum

# %%
re_df
# Out:
#   구매주기_구간  Customer_unique_id
# 0   7일 이내                  37
# 1  14일 이내                  25
# 2  21일 이내                  30
# 3  28일 이내                  21
# 4  29일 이상                8098

# %%
## 위에서 재구매안한고객의 10퍼를 기존의 값과 더한
re_df2 = reorder_filtered_cleaned.groupby(['구매주기_구간'], as_index=False)[['order_count', 'Freight_value', 'Price']].sum()
re_df2
# Out:
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\1830360116.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   re_df2 = reorder_filtered_cleaned.groupby(['구매주기_구간'], as_index=False)[['order_count', 'Freight_value', 'Price']].sum()
#   구매주기_구간  order_count  Freight_value     Price
# 0   7일 이내          222        1596.29   6838.84
# 1  14일 이내          121        1148.54   5520.18
# 2  21일 이내          197        1695.56   4863.40
# 3  28일 이내          116         744.44   3055.26
# 4  29일 이상         1162       12555.87  55768.80

# %%
# sample_df
sample_df_order_count_sum = sample_df['order_count'].sum()
sample_df_Freight_value_sum = sample_df['Freight_value'].sum()
sample_df_Price_sum = sample_df['Price'].sum()
print(sample_df_order_count_sum, sample_df_Freight_value_sum, sample_df_Price_sum)
# Out:
# 8592 170483.97 1064272.13

# %%
## 위에서 재구매안한고객의 10퍼를 기존의 값과 더한
re_df2.loc[(re_df.구매주기_구간=="29일 이상"),"order_count"] = re_df2[re_df2.구매주기_구간=="29일 이상"]["order_count"]+sample_df_order_count_sum

# %%
re_df2.loc[(re_df.구매주기_구간=="29일 이상"),"Freight_value"] = re_df2[re_df2.구매주기_구간=="29일 이상"]["Freight_value"]+sample_df_Freight_value_sum

# %%
re_df2.loc[(re_df.구매주기_구간=="29일 이상"),"Price"] = re_df2[re_df2.구매주기_구간=="29일 이상"]["Price"]+sample_df_Price_sum

# %%
re_df2
# Out:
#   구매주기_구간  order_count  Freight_value       Price
# 0   7일 이내          222        1596.29     6838.84
# 1  14일 이내          121        1148.54     5520.18
# 2  21일 이내          197        1695.56     4863.40
# 3  28일 이내          116         744.44     3055.26
# 4  29일 이상         9754      183039.84  1120040.93

# %%
re_df

# %%
re_df3 = pd.merge(re_df, re_df2, on='구매주기_구간', how='inner')
re_df3
# Out:
#   구매주기_구간  Customer_unique_id  order_count  Freight_value       Price
# 0   7일 이내                  37          222        1596.29     6838.84
# 1  14일 이내                  25          121        1148.54     5520.18
# 2  21일 이내                  30          197        1695.56     4863.40
# 3  28일 이내                  21          116         744.44     3055.26
# 4  29일 이상                8098         9754      183039.84  1120040.93

# %%
re_df3['Payment_value'] = re_df3['Freight_value'] + re_df3['Price']
re_df3['구매당순이익'] = round(re_df3['Price'] / re_df3['order_count'], 2)
re_df3['구매당운송비'] = round(re_df3['Freight_value'] / re_df3['order_count'], 2)
re_df3['고객당순이익'] = round(re_df3['Price'] / re_df3['Customer_unique_id'], 0)
re_df3['고객당구매수'] = round(re_df3['order_count'] / re_df3['Customer_unique_id'], 2)
re_df3['고객당매출액'] = round(re_df3['Payment_value'] / re_df3['Customer_unique_id'], 0)

# %%
# 폰트없어서 안돼
# from matplotlib import font_manager, rc
# font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
# font_name = font_manager.FontProperties(fname = font_path).get_name()
# rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, axes = plt.subplots(1, 3, figsize=(15,6))

plt.subplot(1, 3, 1)
sns.barplot(x='구매주기_구간', y='고객당구매수', data=re_df3, palette='muted')
plt.title('구매주기별 고객당 구매횟수')
for p in axes[0].patches:
    axes[0].annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')

plt.subplot(1, 3, 2)
sns.barplot(x='구매주기_구간', y='고객당순이익', data=re_df3, palette='muted')
plt.title('구매주기별 인당 순수익')
for p in axes[1].patches:
    axes[1].annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')

plt.subplot(1, 3, 3)
sns.barplot(x='구매주기_구간', y='고객당매출액', data=re_df3, palette='muted')
plt.title('구매주기별 1회 구매당 매출액')
for p in axes[2].patches:
    axes[2].annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='구매주기_구간', y='고객당구매수', data=re_df3, palette='muted')
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='구매주기_구간', y='고객당순이익', data=re_df3, palette='muted')
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='구매주기_구간', y='고객당매출액', data=re_df3, palette='muted')
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 45236 (\N{HANGUL SYLLABLE NAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 54943 (\N{HANGUL SYLLABLE HOES}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 51061 (\N{HANGUL SYLLABLE IG}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Local\Temp\ipykernel_1736\3075114023.py:25: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from current font.
#   plt.tight_layout()
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54943 (\N{HANGUL SYLLABLE HOES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45236 (\N{HANGUL SYLLABLE NAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51061 (\N{HANGUL SYLLABLE IG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sh022\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
re_df3.sort_values(by='고객당순이익', ascending=False)
# Out:
#   구매주기_구간  Customer_unique_id  order_count  Freight_value       Price  \
# 1  14일 이내                  25          121        1148.54     5520.18
# 0   7일 이내                  37          222        1596.29     6838.84
# 2  21일 이내                  30          197        1695.56     4863.40
# 3  28일 이내                  21          116         744.44     3055.26
# 4  29일 이상                8098         9754      183039.84  1120040.93
#
#    Payment_value  구매당순이익  구매당운송비  고객당순이익  고객당구매수  고객당매출액
# 1        6668.72   45.62    9.49   221.0    4.84   267.0
# 0        8435.13   30.81    7.19   185.0    6.00   228.0
# 2        6558.96   24.69    8.61   162.0    6.57   219.0
# 3        3799.70   26.34    6.42   145.0    5.52   181.0
# 4     1303080.77  114.83   18.77   138.0    1.20   161.0

# %%
reorder_yn
# Out:
#   재구매여부  order_count  Freight_value        Price  Customer_unique_id  \
# 0     N        98930     1927758.38  11885798.71               83872
# 1     Y        17482      140656.73    653055.06                6321
#
#    재구매여부_ratio  Payment_value  구매당순이익  구매당운송비  고객당순이익  고객당구매수  고객당매출액
# 0     0.929917    13813557.09  120.14   19.49   142.0    1.18   165.0
# 1     0.070083      793711.79   37.36    8.05   103.0    2.77   126.0

# %%
reorder_filtered
# Out:
#           Customer_unique_id  order_count  Freight_value   Price 재구매여부   구매주기  \
# 212    CUSTOMER_Unique_00188            4          26.87  118.90     Y   28.0
# 213    CUSTOMER_Unique_00188            4          26.87  118.90     Y   28.0
# 255    CUSTOMER_Unique_00227            4          22.76  109.90     Y    5.5
# 465    CUSTOMER_Unique_00414            3          47.23  105.50     Y   32.0
# 528    CUSTOMER_Unique_00470            5          99.25  578.32     Y  207.0
# ...                      ...          ...            ...     ...   ...    ...
# 81464  CUSTOMER_Unique_76745            3          22.49   74.70     Y   41.0
# 82186  CUSTOMER_Unique_77444            3          34.90  126.46     Y  176.0
# 84376  CUSTOMER_Unique_79562            4          23.19  330.32     Y   20.0
# 86891  CUSTOMER_Unique_82027            4          22.90  163.90     Y  120.0
# 86892  CUSTOMER_Unique_82027            4          22.90  163.90     Y  120.0
#
#       구매주기_구간
# 212    29일 이상
# 213    29일 이상
# 255     7일 이내
# 465    29일 이상
# 528    29일 이상
# ...       ...
# 81464  29일 이상
# 82186  29일 이상
# 84376  21일 이내
# 86891  29일 이상
# 86892  29일 이상
#
# [368 rows x 7 columns]

# %%
# plt.figure(figsize=(15,6))
# sns.boxplot(data = reorder_filtered_cleaned, x="구매주기_구간", y="Price")
# # 이상치가 존재한다.

# %%
re_df3.corr(numeric_only=True).style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_d8f14_row0_col0, #T_d8f14_row0_col1, #T_d8f14_row0_col2, #T_d8f14_row0_col3, #T_d8f14_row0_col4, #T_d8f14_row1_col0, #T_d8f14_row1_col1, #T_d8f14_row1_col2, #T_d8f14_row1_col3, #T_d8f14_row1_col4, #T_d8f14_row2_col0, #T_d8f14_row2_col1, #T_d8f14_row2_col2, #T_d8f14_row2_col3, #T_d8f14_row2_col4, #T_d8f14_row3_col0, #T_d8f14_row3_col1, #T_d8f14_row3_col2, #T_d8f14_row3_col3, #T_d8f14_row3_col4, #T_d8f14_row4_col0, #T_d8f14_row4_col1, #T_d8f14_row4_col2, #T_d8f14_row4_col3, #T_d8f14_row4_col4, #T_d8f14_row5_col5, #T_d8f14_row6_col6, #T_d8f14_row7_col7, #T_d8f14_row8_col8, #T_d8f14_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d8f14_row0_col5, #T_d8f14_row0_col6, #T_d8f14_row1_col5, #T_d8f14_row1_col6, #T_d8f14_row2_col5, #T_d8f14_row2_col6, #T_d8f14_row3_col5, #T_d8f14_row3_col6, #T_d8f14_row4_col5, #T_d8f14_row4_col6, #T_d8f14_row5_col0, #T_d8f14_row5_col1, #T_d8f14_row5_col2, #T_d8f14_row5_col3, #T_d8f14_row5_col4, #T_d8f14_row6_col0, #T_d8f14_row6_col1, #T_d8f14_row6_col2, #T_d8f14_row6_col3, #T_d8f14_row6_col4 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_d8f14_row0_col7, #T_d8f14_row1_col7, #T_d8f14_row2_col7, #T_d8f14_row3_col7, #T_d8f14_row4_col7, #T_d8f14_row7_col0, #T_d8f14_row7_col1, #T_d8f14_row7_col2, #T_d8f14_row7_col3, #T_d8f14_row7_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d8f14_row0_col8, #T_d8f14_row1_col8, #T_d8f14_row2_col8, #T_d8f14_row3_col8, #T_d8f14_row4_col8, #T_d8f14_row8_col0, #T_d8f14_row8_col1, #T_d8f14_row8_col2, #T_d8f14_row8_col3, #T_d8f14_row8_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d8f14_row0_col9, #T_d8f14_row1_col9, #T_d8f14_row9_col0, #T_d8f14_row9_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_d8f14_row2_col9, #T_d8f14_row3_col9, #T_d8f14_row4_col9, #T_d8f14_row9_col2, #T_d8f14_row9_col3, #T_d8f14_row9_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_d8f14_row5_col6, #T_d8f14_row6_col5 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_d8f14_row5_col7, #T_d8f14_row7_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_d8f14_row5_col8, #T_d8f14_row8_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d8f14_row5_col9, #T_d8f14_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_d8f14_row6_col7, #T_d8f14_row7_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_d8f14_row6_col8, #T_d8f14_row8_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_d8f14_row6_col9, #T_d8f14_row9_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_d8f14_row7_col8, #T_d8f14_row8_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_d8f14_row7_col9, #T_d8f14_row9_col7 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_d8f14_row8_col9, #T_d8f14_row9_col8 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d8f14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8f14_level0_col0" class="col_heading level0 col0" >Customer_unique_id</th>
#       <th id="T_d8f14_level0_col1" class="col_heading level0 col1" >order_count</th>
#       <th id="T_d8f14_level0_col2" class="col_heading level0 col2" >Freight_value</th>
#       <th id="T_d8f14_level0_col3" class="col_heading level0 col3" >Price</th>
#       <th id="T_d8f14_level0_col4" class="col_heading level0 col4" >Payment_value</th>
#       <th id="T_d8f14_level0_col5" class="col_heading level0 col5" >구매당순이익</th>
#       <th id="T_d8f14_level0_col6" class="col_heading level0 col6" >구매당운송비</th>
#       <th id="T_d8f14_level0_col7" class="col_heading level0 col7" >고객당순이익</th>
#       <th id="T_d8f14_level0_col8" class="col_heading level0 col8" >고객당구매수</th>
#       <th id="T_d8f14_level0_col9" class="col_heading level0 col9" >고객당매출액</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8f14_level0_row0" class="row_heading level0 row0" >Customer_unique_id</th>
#       <td id="T_d8f14_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d8f14_row0_col1" class="data row0 col1" >0.999957</td>
#       <td id="T_d8f14_row0_col2" class="data row0 col2" >0.999994</td>
#       <td id="T_d8f14_row0_col3" class="data row0 col3" >0.999999</td>
#       <td id="T_d8f14_row0_col4" class="data row0 col4" >0.999999</td>
#       <td id="T_d8f14_row0_col5" class="data row0 col5" >0.976105</td>
#       <td id="T_d8f14_row0_col6" class="data row0 col6" >0.970899</td>
#       <td id="T_d8f14_row0_col7" class="data row0 col7" >-0.534094</td>
#       <td id="T_d8f14_row0_col8" class="data row0 col8" >-0.953953</td>
#       <td id="T_d8f14_row0_col9" class="data row0 col9" >-0.675886</td>
#     </tr>
#     <tr>
#       <th id="T_d8f14_level0_row1" class="row_heading level0 row1" >order_count</th>
#       <td id="T_d8f14_row1_col0" class="data row1 col0" >0.999957</td>
#       <td id="T_d8f14_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d8f14_row1_col2" class="data row1 col2" >0.999976</td>
#       <td id="T_d8f14_row1_col3" class="data row1 col3" >0.999958</td>
#       <td id="T_d8f14_row1_col4" class="data row1 col4" >0.999961</td>
#       <td id="T_d8f14_row1_col5" class="data row1 col5" >0.975140</td>
#       <td id="T_d8f14_row1_col6" class="data row1 col6" >0.970660</td>
#       <td id="T_d8f14_row1_col7" class="data row1 col7" >-0.535006</td>
#       <td id="T_d8f14_row1_col8" class="data row1 col8" >-0.951650</td>
#       <td id="T_d8f14_row1_col9" class="data row1 col9" >-0.675783</td>
#     </tr>
#     <tr>
#       <th id="T_d8f14_level0_row2" class="row_heading level0 row2" >Freight_value</th>
#       <td id="T_d8f14_row2_col0" class="data row2 col0" >0.999994</td>
#       <td id="T_d8f14_row2_col1" class="data row2 col1" >0.999976</td>
#       <td id="T_d8f14_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d8f14_row2_col3" class="data row2 col3" >0.999995</td>
#       <td id="T_d8f14_row2_col4" class="data row2 col4" >0.999996</td>
#       <td id="T_d8f14_row2_col5" class="data row2 col5" >0.975968</td>
#       <td id="T_d8f14_row2_col6" class="data row2 col6" >0.971284</td>
#       <td id="T_d8f14_row2_col7" class="data row2 col7" >-0.533671</td>
#       <td id="T_d8f14_row2_col8" class="data row2 col8" >-0.953252</td>
#       <td id="T_d8f14_row2_col9" class="data row2 col9" >-0.674982</td>
#     </tr>
#     <tr>
#       <th id="T_d8f14_level0_row3" class="row_heading level0 row3" >Price</th>
#       <td id="T_d8f14_row3_col0" class="data row3 col0" >0.999999</td>
#       <td id="T_d8f14_row3_col1" class="data row3 col1" >0.999958</td>
#       <td id="T_d8f14_row3_col2" class="data row3 col2" >0.999995</td>
#       <td id="T_d8f14_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d8f14_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_d8f14_row3_col5" class="data row3 col5" >0.976374</td>
#       <td id="T_d8f14_row3_col6" class="data row3 col6" >0.971119</td>
#       <td id="T_d8f14_row3_col7" class="data row3 col7" >-0.532855</td>
#       <td id="T_d8f14_row3_col8" class="data row3 col8" >-0.954143</td>
#       <td id="T_d8f14_row3_col9" class="data row3 col9" >-0.674837</td>
#     </tr>
#     <tr>
#       <th id="T_d8f14_level0_row4" class="row_heading level0 row4" >Payment_value</th>
#       <td id="T_d8f14_row4_col0" class="data row4 col0" >0.999999</td>
#       <td id="T_d8f14_row4_col1" class="data row4 col1" >0.999961</td>
#       <td id="T_d8f14_row4_col2" class="data row4 col2" >0.999996</td>
#       <td id="T_d8f14_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_d8f14_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_d8f14_row4_col5" class="data row4 col5" >0.976318</td>
#       <td id="T_d8f14_row4_col6" class="data row4 col6" >0.971143</td>
#       <td id="T_d8f14_row4_col7" class="data row4 col7" >-0.532969</td>
#       <td id="T_d8f14_row4_col8" class="data row4 col8" >-0.954018</td>
#       <td id="T_d8f14_row4_col9" class="data row4 col9" >-0.674858</td>
#     </tr>
#     <tr>
#       <th id="T_d8f14_level0_row5" class="row_heading level0 row5" >구매당순이익</th>
#       <td id="T_d8f14_row5_col0" class="dat

# %%
re_df3
# Out:
#   구매주기_구간  Customer_unique_id  order_count  Freight_value       Price  \
# 0   7일 이내                  37          222        1596.29     6838.84
# 1  14일 이내                  25          121        1148.54     5520.18
# 2  21일 이내                  30          197        1695.56     4863.40
# 3  28일 이내                  21          116         744.44     3055.26
# 4  29일 이상                8098         9754      183039.84  1120040.93
#
#    Payment_value  구매당순이익  구매당운송비  고객당순이익  고객당구매수  고객당매출액
# 0        8435.13   30.81    7.19   185.0    6.00   228.0
# 1        6668.72   45.62    9.49   221.0    4.84   267.0
# 2        6558.96   24.69    8.61   162.0    6.57   219.0
# 3        3799.70   26.34    6.42   145.0    5.52   181.0
# 4     1303080.77  114.83   18.77   138.0    1.20   161.0

# %%
# 구매주기_구간 인코딩
dummy_df = pd.get_dummies(re_df3['구매주기_구간'], prefix='구매주기_구간')

# %%
merged_df = pd.concat([re_df3, dummy_df], axis=1)

# %%
merged_df.columns
# Out:
# Index(['구매주기_구간', 'Customer_unique_id', 'order_count', 'Freight_value',
#        'Price', 'Payment_value', '구매당순이익', '구매당운송비', '고객당순이익', '고객당구매수',
#        '고객당매출액', '구매주기_구간_7일 이내', '구매주기_구간_14일 이내', '구매주기_구간_21일 이내',
#        '구매주기_구간_28일 이내', '구매주기_구간_29일 이상'],
#       dtype='object')

# %%
merged_drop_df = merged_df.drop(["구매주기_구간"],axis=1)

# %%
correlation_matrix = merged_drop_df.corr(numeric_only=True).style.background_gradient(cmap='coolwarm', axis=None)

# %%
correlation_matrix
# Out:
# <style type="text/css">
# #T_27f11_row0_col0, #T_27f11_row0_col1, #T_27f11_row0_col2, #T_27f11_row0_col3, #T_27f11_row0_col4, #T_27f11_row0_col14, #T_27f11_row1_col0, #T_27f11_row1_col1, #T_27f11_row1_col2, #T_27f11_row1_col3, #T_27f11_row1_col4, #T_27f11_row1_col14, #T_27f11_row2_col0, #T_27f11_row2_col1, #T_27f11_row2_col2, #T_27f11_row2_col3, #T_27f11_row2_col4, #T_27f11_row2_col14, #T_27f11_row3_col0, #T_27f11_row3_col1, #T_27f11_row3_col2, #T_27f11_row3_col3, #T_27f11_row3_col4, #T_27f11_row3_col14, #T_27f11_row4_col0, #T_27f11_row4_col1, #T_27f11_row4_col2, #T_27f11_row4_col3, #T_27f11_row4_col4, #T_27f11_row4_col14, #T_27f11_row5_col5, #T_27f11_row6_col6, #T_27f11_row7_col7, #T_27f11_row8_col8, #T_27f11_row9_col9, #T_27f11_row10_col10, #T_27f11_row11_col11, #T_27f11_row12_col12, #T_27f11_row13_col13, #T_27f11_row14_col0, #T_27f11_row14_col1, #T_27f11_row14_col2, #T_27f11_row14_col3, #T_27f11_row14_col4, #T_27f11_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_27f11_row0_col5, #T_27f11_row0_col6, #T_27f11_row1_col5, #T_27f11_row1_col6, #T_27f11_row2_col5, #T_27f11_row2_col6, #T_27f11_row3_col5, #T_27f11_row3_col6, #T_27f11_row4_col5, #T_27f11_row4_col6, #T_27f11_row5_col0, #T_27f11_row5_col1, #T_27f11_row5_col2, #T_27f11_row5_col3, #T_27f11_row5_col4, #T_27f11_row5_col14, #T_27f11_row6_col0, #T_27f11_row6_col1, #T_27f11_row6_col2, #T_27f11_row6_col3, #T_27f11_row6_col4, #T_27f11_row6_col14, #T_27f11_row14_col5, #T_27f11_row14_col6 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_27f11_row0_col7, #T_27f11_row1_col7, #T_27f11_row2_col7, #T_27f11_row3_col7, #T_27f11_row4_col7, #T_27f11_row7_col0, #T_27f11_row7_col1, #T_27f11_row7_col2, #T_27f11_row7_col3, #T_27f11_row7_col4, #T_27f11_row7_col14, #T_27f11_row14_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_27f11_row0_col8, #T_27f11_row1_col8, #T_27f11_row2_col8, #T_27f11_row3_col8, #T_27f11_row4_col8, #T_27f11_row8_col0, #T_27f11_row8_col1, #T_27f11_row8_col2, #T_27f11_row8_col3, #T_27f11_row8_col4, #T_27f11_row8_col14, #T_27f11_row14_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_27f11_row0_col9, #T_27f11_row1_col9, #T_27f11_row9_col0, #T_27f11_row9_col1, #T_27f11_row9_col14, #T_27f11_row14_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_27f11_row0_col10, #T_27f11_row0_col11, #T_27f11_row0_col12, #T_27f11_row0_col13, #T_27f11_row1_col11, #T_27f11_row1_col13, #T_27f11_row2_col11, #T_27f11_row2_col13, #T_27f11_row3_col11, #T_27f11_row3_col12, #T_27f11_row3_col13, #T_27f11_row4_col11, #T_27f11_row4_col12, #T_27f11_row4_col13, #T_27f11_row10_col0, #T_27f11_row10_col11, #T_27f11_row10_col12, #T_27f11_row10_col13, #T_27f11_row10_col14, #T_27f11_row11_col0, #T_27f11_row11_col1, #T_27f11_row11_col2, #T_27f11_row11_col3, #T_27f11_row11_col4, #T_27f11_row11_col10, #T_27f11_row11_col12, #T_27f11_row11_col13, #T_27f11_row11_col14, #T_27f11_row12_col0, #T_27f11_row12_col3, #T_27f11_row12_col4, #T_27f11_row12_col10, #T_27f11_row12_col11, #T_27f11_row12_col13, #T_27f11_row12_col14, #T_27f11_row13_col0, #T_27f11_row13_col1, #T_27f11_row13_col2, #T_27f11_row13_col3, #T_27f11_row13_col4, #T_27f11_row13_col10, #T_27f11_row13_col11, #T_27f11_row13_col12, #T_27f11_row13_col14, #T_27f11_row14_col10, #T_27f11_row14_col11, #T_27f11_row14_col12, #T_27f11_row14_col13 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_27f11_row1_col10, #T_27f11_row1_col12, #T_27f11_row2_col10, #T_27f11_row2_col12, #T_27f11_row3_col10, #T_27f11_row4_col10, #T_27f11_row10_col1, #T_27f11_row10_col2, #T_27f11_row10_col3, #T_27f11_row10_col4, #T_27f11_row12_col1, #T_27f11_row12_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_27f11_row2_col9, #T_27f11_row3_col9, #T_27f11_row4_col9, #T_27f11_row9_col2, #T_27f11_row9_col3, #T_27f11_row9_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_27f11_row5_col6, #T_27f11_row6_col5 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_27f11_row5_col7, #T_27f11_row5_col12, #T_27f11_row7_col5, #T_27f11_row12_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_27f11_row5_col8, #T_27f11_row8_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_27f11_row5_col9, #T_27f11_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_27f11_row5_col10, #T_27f11_row10_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_27f11_row5_col11, #T_27f11_row11_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_27f11_row5_col13, #T_27f11_row6_col10, #T_27f11_row10_col6, #T_27f11_row13_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_27f11_row6_col7, #T_27f11_row7_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_27f11_row6_col8, #T_27f11_row8_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_27f11_row6_col9, #T_27f11_row9_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_27f11_row6_col11, #T_27f11_row11_col6 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_27f11_row6_col12, #T_27f11_row12_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_27f11_row6_col13, #T_27f11_row7_col13, #T_27f11_row13_col6, #T_27f11_row13_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_27f11_row7_col8, #T_27f11_row8_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_27f11_row7_col9, #T_27f11_row9_col7 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_27f11_row7_col10, #T_27f11_row10_col7 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_27f11_row7_col11, #T_27f11_row11_col7 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_27f11_row7_col12, #T_27f11_row12_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_27f11_row8_col9, #T_27f11_row9_col8 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_27f11_row8_col10, #T_27f11_row10_col8 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_27f11_row8_col11, #T_27f11_row11_col8 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_27f11_row8_col12, #T_27f11_row12_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_27f11_row8_col13, #T_27f11_row13_col8 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_27f11_row9_col10, #T_27f11_row10_col9 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_27f11_row9_col11, #T_27f11_row11_col9 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_27f11_row9_col12, #T_27f11_row12_col9 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_27f11_row9_col13, #T_27f11_row13_col9 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# </style>
# <table id="T_27f11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27f11_level0_col0" class="col_heading level0 col0" >Customer_unique_id</th>
#       <th id="T_27f11_level0_col1" class="col_heading level0 col1" >order_count</th>
#       <th id="T_27f11_level0_col2" class="col_heading level0 col2" >Freight_value</th>
#       <th id="T_27f11_level0_col3" class="col_heading level0 col3" >Price</th>
#       <th id="T_27f11_level0_col4" class="col_heading level0 col4" >Payment_value</th>
#       <th id="T_27f11_level0_col5" class="col_heading level0 col5" >구매당순이익</th>
#       <th id="T_27f11_level0_col6" class="col_heading level0 col6" >구매당운송비</th>
#       <th id="T_27f11_level0_col7" class="col_heading level0 col7" >고객당순이익</th>
#       <th id="T_27f11_level0_col8" class="col_heading level0 col8" >고객당구매수</th>
#       <th id="T_27f11_level0_col9" class="col_heading level0 col9" >고객당매출액</th>
#       <th id="T_27f11_level0_col10" class="col_heading level0 col10" >구매주기_구간_7일 이내</th>
#       <th id="T_27f11_level0_col11" class="col_heading level0 col11" >구매주기_구간_14일 이내</th>
#       <th id="T_27f11_level0_col12" class="col_heading level0 col12" >구매주기_구간_21일 이내</th>
#       <th id="T_27f11_level0_col13" class="col_heading level0 col13" >구매주기_구간_28일 이내</th>
#       <th id="T_27f11_level0_col14" class="col_heading level0 col14" >구매주기_구간_29일 이상</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27f11_level0_row0" class="row_heading level0 row0" >Customer_unique_id</th>
#       <td id="T_27f11_row0_col0" class="data row0 col0" >1.000000</td>

# %%
merged_df
# Out:
#   구매주기_구간  Customer_unique_id  order_count  Freight_value       Price  \
# 0   7일 이내                  37          222        1596.29     6838.84
# 1  14일 이내                  25          121        1148.54     5520.18
# 2  21일 이내                  30          197        1695.56     4863.40
# 3  28일 이내                  21          116         744.44     3055.26
# 4  29일 이상                8098         9754      183039.84  1120040.93
#
#    Payment_value  구매당순이익  구매당운송비  고객당순이익  고객당구매수  고객당매출액  구매주기_구간_7일 이내  \
# 0        8435.13   30.81    7.19   185.0    6.00   228.0           True
# 1        6668.72   45.62    9.49   221.0    4.84   267.0          False
# 2        6558.96   24.69    8.61   162.0    6.57   219.0          False
# 3        3799.70   26.34    6.42   145.0    5.52   181.0          False
# 4     1303080.77  114.83   18.77   138.0    1.20   161.0          False
#
#    구매주기_구간_14일 이내  구매주기_구간_21일 이내  구매주기_구간_28일 이내  구매주기_구간_29일 이상
# 0           False           False           False           False
# 1            True           False           False           False
# 2           False            True           False           False
# 3           False           False            True           False
# 4           False           False           False            True

# %%
import pickle

with open("./dacon_term2.pkl", "wb") as file:
    pickle.dump(re_df3, file)
