# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
driver = webdriver.Chrome(service=Service(ChromeDriverManager(driver_version="123.0.6312.105").install()))
driver.get("https://www.koreabaseball.com/")
from selenium.webdriver.common.by import By
driver.find_element(By.CSS_SELECTOR, "#lnb > li:nth-child(3) > a").click()
#abc에 모든 선수들의 번호가 저장됨
# for i in range(len(abc)):
#팀이름 밑에 집계 리스트 844개 안에 딕셔너리로
import time
import re
pattern = re.compile("playerId=([0-9]+)")

select_page = "#cphContents_cphContents_cphContents_ucPager_btnNo{}"
select_team = "#cphContents_cphContents_cphContents_ddlTeam > option:nth-child({})"
playid = []
for x in range(2,12):
    for_1 = select_team.format(x)
    driver.find_element(By.CSS_SELECTOR, for_1).click()
    time.sleep(2)
    #playid.extend(pattern.findall(driver.page_source))
    for y in range(1,6):
        f2 = select_page.format(y)
        try:
            driver.find_element(By.CSS_SELECTOR, f2).click()
            time.sleep(1)
            playid.extend(pattern.findall(driver.page_source))
        except Exception as e:
            print ("page 없음 ")
        time.sleep(2)
# Out:
# page 없음

# %%
len(list(set(playid)))
from tqdm import tqdm

# %%
#abc에 모든 선수들의 번호가 저장됨
# for i in range(len(abc)):
#팀이름 밑에 집계 리스트 844개 안에 딕셔너리로
from bs4 import BeautifulSoup as BS 
import requests
select_user="https://www.koreabaseball.com/Record/Player/PitcherDetail/Basic.aspx?playerId={}"
user_info=[] # list선언 이지만 안에는 dict
user_dict={}
for i in tqdm(range(len(list(set(playid))))):
    r = requests.get(select_user.format(playid[i])) #headers부분 안적어도되는듯
    bs=BS(r.text)
    title = bs.find("div", class_="player_info").text.strip()
    list1=title.split("\n")
    #print(str(list1))
    user_dict={}
    user_dict["구단"]=list1[0]
    #dict(a)

    #print(user_dict)
    list2=list1[:14]
    # list3=list3.append(list2[0])
    list3=list2[4:14]
    for j in range(len(list3)):
        if j==4:
            #print(list2[j+4])
            just=list2[j+4]
            first=just.split(":")[0]
            second=just.split(":")[1]
            user_dict[first.split("/")[0]]=str(second.split("/")[0]).strip()
            user_dict[first.split("/")[1]]=second.split("/")[1]
        else:
            user_dict[list2[j+4].split(":")[0]]=list2[j+4].split(':')[1].strip()
    user_info.append(user_dict)      
        
    #print(str(list3))
    #print(len(user_dict))
    # for j in range(len(list3)):
    #     user_dict[str(list3).split(":")[0]]=str(list3).split(":")[1]
    # print(user_dict)
    #list3.insert(0,list2[0])
    #print(list3)
    #5가 신장/체중
    #print(list1)
    #user_info.append(list3)
    #1 5 67891011121314
    #break
print(user_info)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████|
'내야수(우투우타)', '신장': '175cm', '체중': '80kg', '경력': '영원초(영등포구리틀)-선린중-덕수고', '입단 계약금': '5000만원', '연봉': '3000만원', '지명순위': '18 한화 2차 7라운드 64순위', '입단년도': '18한화'}, {'구단': '한화 이글스', '선수명': '김민우', '등번호': 'No.53', '생년월일': '1995년 07월 25일', '포지션': '투수(우투우타)', '신장': '186cm', '체중': '123kg', '경력': '사파초-마산중-용마고', '입단 계약금': '20000만원', '연봉': '16700만원', '지명순위': '15 한화 2차 1라운드 1순위', '입단년도': '15한화'}, {'구단': '한화 이글스', '선수명': '김범수', '등번호': 'No.47', '생년월일': '1995년 10월 03일', '포지션': '투수(좌투좌타)', '신장': '181cm', '체중': '92kg', '경력': '온양온천초-온양중-북일고', '입단 계약금': '20000만원', '연봉': '19300만원', '지명순위': '15 한화 1차', '입단년도': '15한화'}, {'구단': '한화 이글스', '선수명': '김범준', '등번호': 'No.93', '생년월일': '2000년 09월 30일', '포지션': '투수(우투우타)', '신장': '175cm', '체중': '79kg', '경력': '서울도곡초-글로벌선진중-충암고', '입단 계약금': '3000만원', '연봉': '3000만원', '지명순위': '20 한화 2차 9라운드 88순위', '입단년도': ''}, {'구단': '한화 이글스', '선수명': '김서현', '등번호': 'No.54', '생년월일': '2004년 05월 31일', '포지션': '투수(우투우타)', '신장': '188cm', '체중': '86kg', '경력': '효제초-자양중-서울고', '입단 계약금': '50000만원', '연봉': '3300만원', '지명순위': '23 한화 1라운드 1순위', '입단년도': '23한화'}, {'구단': '한화 이글스', '선수명': '김선동', '등번호': 'No.03', '생년월일': '2000년 10월 30일', '포지션': '외야수(우투좌타)', '신장': '180cm', '체중': '77kg', '경력': '은어송초(대전동구리틀)-한밭중-대전고-원광대', '입단 계약금': '', '연봉': '3000만원', '지명순위': '24 한화 육성선수', '입단년도': ''}, {'구단': '한화 이글스', '선수명': '김승일', '등번호': 'No.04', '생년월일': '2001년 07월 07일', '포지션': '투수(우언우타)', '신장': '183cm', '체중': '85kg', '경력': '해강초(해운대리틀)-센텀중-경남고-한화', '입단 계약금': '3000만원', '연봉': '3000만원', '지명순위': '20 한화 2차 10라운드 98순위', '입단년도': ''}, {'구단': '한화 이글스', '선수명': '김인환', '등번호': 'No.37', '생년월일': '1994년 01월 28일', '포지션': '내야수(우투좌타)', '신장': '186cm', '체중': '100kg', '경력': '화순초-화순중-화순고-성균관대', '입단 계약금': '', '연봉': '6900만원', '지명순위': '16 한화 육성선수', '입단년도': '18한화'}, {'구단': '한화 이글스', '선수명': '김종수', '등번호': 'No.38', '생년월일': '1994년 06월 03일', '포지션': '투수(우투우타)', '신장': '180cm', '체중': '88kg', '경력': '성동초-덕수중-울산공고', '입단 계약금': '3000만원', '연봉': '6800만원', '지명순위': '13 한화 8라운 ...
