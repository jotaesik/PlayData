# %% [markdown]
# # 2024
# ## 데이터 수집

# %%
dict1 = {"a" : 1 , "b" : [1,2,3]}

# %%
import requests
url = "https://www.starbucks.co.kr/store/getStore.do?r=EXRPGE2OU7"
payload = {"in_biz_cds" : "0","in_scodes" : "0","ins_lat" : "37.4947","ins_lng" : "127.0493","search_text" : "","p_sido_cd" : "01","p_gugun_cd" : "","isError" : "true","in_distance" : "0","in_biz_cd" : "","iend" : "1000","searchType" : "C","set_date" : "","rndCod" : "Q878EXUG04","all_store" : "0","T03" : "0","T01" : "0","T27" : "0","T12" : "0","T09" : "0","T30" : "0","T05" : "0","T22" : "0","T21" : "0","T10" : "0","T36" : "0","T43" : "0","T48" : "0","Z9999" : "0","P02" : "0","P10" : "0","P50" : "0","P20" : "0","P60" : "0","P30" : "0","P70" : "0","P40" : "0","P80" : "0","whcroad_yn" : "0","P90" : "0","P01" : "0","new_bool" : "0",}
r = requests.post(url, data=payload)
data = r.json()

# %%
# keys, values, items 
len(data['list'])
# Out:
# 612

# %% [markdown]
# data['list'][0].keys()

# %%
empty_list =[]
for x in range(0,10):
    if x % 2 == 0:
        empty_list.append(x)

# %%
empty_list
# Out:
# [0, 2, 4, 6, 8]

# %%
empty_list2 = [x for x in range(0, 10) if x % 2 ==0]

# %%
empty_list2
# Out:
# [0, 2, 4, 6, 8]

# %%
seocho = []
for star in data['list']:
    if star['addr'].find("서초") > -1:
        seocho.append(star['s_name'])

# %%
seocho2 = [star['s_name'] for star in data['list'] if star['addr'].find("서초") > -1 ]

# %%
dict1 = {'a' : 1}

# %%
dict1['b'] = 10

# %%
data['list'][0].items()
# Out:
# dict_items([('seq', 0), ('sido_cd', None), ('sido_nm', None), ('gugun_cd', None), ('gugun_nm', None), ('code_order', None), ('view_yn', None), ('store_num', None), ('sido', None), ('gugun', None), ('address', None), ('new_img_nm', None), ('p_pro_seq', 0), ('p_view_yn', None), ('p_sido_cd', ''), ('p_gugun_cd', ''), ('p_store_nm', None), ('p_theme_cd', None), ('p_wireless_yn', None), ('p_smoking_yn', None), ('p_book_yn', None), ('p_music_yn', None), ('p_terrace_yn', None), ('p_table_yn', None), ('p_takeout_yn', None), ('p_parking_yn', None), ('p_dollar_assent', None), ('p_card_recharge', None), ('p_subway_yn', None), ('stb_store_file_renew', None), ('stb_store_theme_renew', None), ('stb_store_time_renew', None), ('stb_store_lsm', None), ('s_code', '1509'), ('s_name', '역삼아레나빌딩'), ('tel', '1522-3232'), ('fax', '02-568-3763'), ('sido_code', '01'), ('sido_name', '서울'), ('gugun_code', '0101'), ('gugun_name', '강남구'), ('addr', '서울특별시 강남구 역삼동 721-13 아레나빌딩'), ('park_info', None), ('new_state', None), ('theme_state', 'Z9999@T05@T08@T16@T17@T20@T21@T30@@T52@T57@P80@P90'), ('new_bool', 0), ('search_text', ''), ('ins_lat', ''), ('ins_lng', ''), ('in_distance', 0), ('out_distance', '.9'), ('all_search_cnt', -1), ('addr_search_cnt', -1), ('store_search_cnt', -1), ('rowCount', 30), ('store_nm', ''), ('store_cd', 0), ('s_biz_code', '3762'), ('new_icon', 'N'), ('set_user', ''), ('favorites', 0), ('map_desc', None), ('notice', None), ('defaultimage', '/upload/store/2020/09/[3762]_20200917031519_6juwr.JPG'), ('etcimage', None), ('in_biz_cd', None), ('in_store_cd', None), ('in_favorites', None), ('in_user_id', None), ('in_biz_cds', 0), ('in_biz_arr', None), ('in_biz_arrdata', None), ('in_scodes', 0), ('in_scode_arr', None), ('in_scode_arrdata', None), ('disp', None), ('set_date', None), ('hlytag', None), ('hlytag_msg', None), ('vSal', ''), ('istart', 1), ('iend', 60), ('open_dt', '20190613'), ('gold_card', 0), ('ip_lat', ''), ('ip_long', ''), ('espresso', ''), ('new_store', ''), ('premiere_food', ''), ('doro_address', '서울특별시 강남구 언주로 425 (역삼동)'), ('cold_blew', ''), ('my_siren_order_store_yn', 'N'), ('whcroad_yn', 'WHCROAD'), ('skuNo', ''), ('skuName', ''), ('skuImgUrl', ''), ('stock_count', 0), ('store_area_name', None), ('store_area_code', 'A01'), ('is_open', None), ('ev_open_yn', None), ('option', None), ('gift_stock_yn', None), ('lat', '37.501087'), ('lot', '127.043069'), ('t20', 0), ('t04', 0), ('t03', 0), ('t01', 0), ('t12', 0), ('t09', 0), ('t06', 0), ('t10', 0), ('p10', 0), ('p50', 0), ('p20', 0), ('p60', 0), ('p30', 0), ('p70', 0), ('p40', 0), ('p80', 0), ('t22', 0), ('t21', 0), ('p90', 0), ('p01', 0), ('t05', 0), ('t30', 0), ('t36', 0), ('t27', 0), ('t29', 0), ('t43', 0), ('t48', 0), ('z9999', 0), ('p02', 0)])

# %%
master = dict(zip(range(0,7), "월화수목금토일"))

# %%
master[0]
# Out:
# '월'

# %%
from datetime import date, datetime, timedelta

for t in range(0, 1001, 100):
    # f-string 3.6이상 
    print(f"{t}일째 - {date.today() + timedelta(days=t)} - {master[(date.today() + timedelta(days=t)).weekday()]}")
# Out:
# 0일째 - 2024-04-02 - 화
# 100일째 - 2024-07-11 - 목
# 200일째 - 2024-10-19 - 토
# 300일째 - 2025-01-27 - 월
# 400일째 - 2025-05-07 - 수
# 500일째 - 2025-08-15 - 금
# 600일째 - 2025-11-23 - 일
# 700일째 - 2026-03-03 - 화
# 800일째 - 2026-06-11 - 목
# 900일째 - 2026-09-19 - 토
# 1000일째 - 2026-12-28 - 월

# %%
datetime.strptime(data['list'][0]['open_dt'], "%Y%m%d").weekday()
# Out:
# 3

# %%
# 요일 키 추가 
for star in data['list']:
    star['요일'] = master[datetime.strptime(star['open_dt'], "%Y%m%d").weekday()]

# %%
#cnt_dict = {}
cnt_dict = {}
for x in data['list']:
    # print(x['요일'])
    if x['요일'] in cnt_dict:
        #cnt_dict[x['요일']] = cnt_dict[x['요일']] + 1 
        cnt_dict[x['요일']] +=  1 
    else:
        cnt_dict[x['요일']] = 1

# %%
cnt_dict
# Out:
# {'목': 167, '금': 143, '수': 121, '화': 126, '토': 6, '월': 47, '일': 2}

# %%
[x['s_name']  for x in data['list'] if x['s_name'][-2:] == "DT"]
# Out:
# ['강남세곡DT',
#  '방화DT',
#  '화곡DT',
#  '김포공항DT',
#  '신림DT',
#  '낙성대DT',
#  '구의DT',
#  '공릉DT',
#  '태릉입구역DT',
#  '도봉로DT',
#  '연희DT',
#  '북가좌DT',
#  '종암DT',
#  '송파나루역DT',
#  '송파방이DT',
#  '송파마천사거리DT',
#  '신정DT',
#  '신월IC DT',
#  '신월동DT',
#  '진관DT',
#  '강동구청DT',
#  '강동암사DT',
#  '구로오류DT']

# %%
cnt_dict2 = {}
for y in [x['addr'].split()[1] for x in data['list']]:
    if y in cnt_dict2:
        cnt_dict2[y] += 1 
    else:
        cnt_dict2[y] = 1

# %%
sorted(cnt_dict2.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('강남구', 91),
#  ('중구', 53),
#  ('서초구', 48),
#  ('영등포구', 41),
#  ('종로구', 40),
#  ('마포구', 36),
#  ('송파구', 36),
#  ('강서구', 27),
#  ('용산구', 24),
#  ('서대문구', 22),
#  ('광진구', 19),
#  ('양천구', 17),
#  ('강동구', 17),
#  ('성북구', 15),
#  ('노원구', 14),
#  ('은평구', 14),
#  ('구로구', 14),
#  ('성동구', 14),
#  ('금천구', 13),
#  ('동대문구', 13),
#  ('관악구', 12),
#  ('동작구', 11),
#  ('중랑구', 8),
#  ('도봉구', 7),
#  ('강북구', 6)]

# %% [markdown]
# # set

# %%
# & 교집합 
# | 합 
# - 차집합
{'a' , 'b' } - {'c'}
# Out:
# {'a', 'b'}

# %%
len(list(set(([x['addr'].split()[1] for x in data['list']]))))
# Out:
# 25

# %% [markdown]
# # tuple

# %%
tuple1 = ( 1,2,3)
list1 = [1,2,3]

# %%
for x in tuple1:
    print(x)
# Out:
# 1
# 2
# 3

# %%
list1[2] = 100

# %%
list1[2]
# Out:
# 100

# %%
tuple1[2] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 tuple1[2] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
def myfunction(x, y):
    return x + y
    print("x")

# %%
myfunction(2,3)
# Out:
# 5

# %%
def myfunc2(x, y=10):
    return x * y

# %%
myfunc2(10,12)
# Out:
# 120

# %%
(lambda x ,y : x * y)(4,5)
# Out:
# 20

# %%
def tmp(x,y):
    return x * y

# %%
int('1') + int('2')
# str
# Out:
# 3

# %%
list_data = ['1', '2', '3','4', '5', '6', '7', '8']
for x in list_data:
    print(int(x) ** 2)

# %%
def tmp(x):
    return int(x) ** 2

# %%
list(map(tmp, list_data))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
list(map(lambda x : int(x) ** 2, list_data))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
import requests

# %%
url = "https://www.genie.co.kr/chart/top200"

# %%
head = {'User-Agent':
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0'}

# %%
r = requests.get(url, headers=head)

# %%
from bs4 import BeautifulSoup

# %%
bs = BeautifulSoup(r.text)

# %%
type(bs)
# Out:
# bs4.BeautifulSoup

# %%
bs.find("div", class_="music-list-wrap")
# Out:
# <div class="music-list-wrap">
# <!-- TOOLBAR -->
# <div class="toolbar">
# <input class="all-check" id="" title="전체 선택" type="checkbox"/>
# <a class="btn btn-listen" href="#" onclick="fnPlayArrSong(1); return false;" title="재생">듣기</a>
# <a class="btn btn-add" href="#" onclick="fnPlayArrSong(3); return false;" title="추가"><span class="hide">재생목록에 </span>추가</a>
# <button class="btn btn-album" id="add_my_album_list" onclick="fnAddMyAlbumForm('#add_my_album_list', fnSelectArrSongID(),20, 20);return false;" title="담기" type="button"><span class="hide">마이앨범에 </span>담기</button>
# <a class="btn btn-down" href="#" onclick="fnDownSong(fnSelectArrSongID());return false;" title="다운">다운</a>
# <div class="btns">
# <a class="btn btn-listen" href="#" onclick="fnPlaySong(fnAllSongID() ,1); return false;" title="TOP200 듣기">TOP200 듣기</a>
# </div>
# <div class="check-length"><em>0</em>곡 선택</div>
# </div>
# <!--// TOOLBAR -->
# <!-- LIST -->
# <table class="list-wrap">
# <caption>곡 리스트</caption>
# <thead>
# <tr>
# <th class="hd-check" scope="col"><span class="hide">선택</span></th>
# <th class="hd-number" scope="col">순위</th>
# <th class="hd-album" scope="col"><span class="hide">앨범이미지</span></th>
# <th class="hd-link" scope="col"><span class="hide">곡정보 이동 링크</span></th>
# <th class="hd-info" scope="col">곡정보</th>
# <th class="hd-btns" scope="col">듣기</th>
# <th class="hd-btns" scope="col">추가</th>
# <th class="hd-btns" scope="col">담기</th>
# <th class="hd-btns" scope="col">다운</th>
# <th class="hd-btns" scope="col">뮤비</th>
# <th class="hd-more" scope="col">더보기</th>
# </tr>
# </thead>
# <tbody>
# <tr class="list" songid="105260468">
# <td class="check"><input class="select-check" title="나는 아픈 건 딱 질색이니까" type="checkbox"/></td>
# <td class="number">1
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84718499');return false;"><span class="mask"></span><img alt="2" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/718/499/84718499_1706517983529_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105260468');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105260468','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 나는 아픈 건 딱 질색이니까</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80632010');return false;">(여자)아이들</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105260468');" type="button">외</button>
# <ul class="list" id="RelationArtist_105260468"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84718499');return false;">2</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105260468;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105260468;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105260468" onclick="fnAddMyAlbumForm('#add_my_album_105260468' , '105260468' ,10, 10);return false;" songid="105260468" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105260468');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105260468">
# <a alt="나는 아픈 건 딱 질색이니까" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('105260468');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('105260468');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="105262751">
# <td class="check"><input class="select-check" title="첫 만남은 계획대로 되지 않아" type="checkbox"/></td>
# <td class="number">2
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84662081');return false;"><span class="mask"></span><img alt="TWS 1st Mini Album 'Sparkling Blue'" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/662/081/84662081_1705913418886_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105262751');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105262751','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 첫 만남은 계획대로 되지 않아</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('82313108');return false;">TWS (투어스)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105262751');" type="button">외</button>
# <ul class="list" id="RelationArtist_105262751"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84662081');return false;">TWS 1st Mini Album 'Sparkling Blue'</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105262751;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105262751;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105262751" onclick="fnAddMyAlbumForm('#add_my_album_105262751' , '105262751' ,10, 10);return false;" songid="105262751" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105262751');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105262751">
# <a alt="첫 만남은 계획대로 되지 않아" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('105262751','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('105262751');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('105262751');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="105464107">
# <td class="check"><input class="select-check" title="밤양갱" type="checkbox"/></td>
# <td class="number">3
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84783137');return false;"><span class="mask"></span><img alt="밤양갱" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/783/137/84783137_1707790321067_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105464107');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105464107','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 밤양갱</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80667991');return false;">비비 (BIBI)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105464107');" type="button">외</button>
# <ul class="list" id="RelationArtist_105464107"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84783137');return false;">밤양갱</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105464107;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105464107;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105464107" onclick="fnAddMyAlbumForm('#add_my_album_105464107' , '105464107' ,10, 10);return false;" songid="105464107" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105464107');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105464107">
# <a alt="밤양갱" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('105464107','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('105464107');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('105464107');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="105544232">
# <td class="check"><input class="select-check" title="EASY" type="checkbox"/></td>
# <td class="number">4
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84742099');return false;"><span class="mask"></span><img alt="EASY" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/742/099/84742099_1708319116249_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105544232');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105544232','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 EASY</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('81397289');return false;">LE SSERAFIM (르세라핌)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105544232');" type="button">외</button>
# <ul class="list" id="RelationArtist_105544232"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84742099');return false;">EASY</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105544232;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105544232;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105544232" onclick="fnAddMyAlbumForm('#add_my_album_105544232' , '105544232' ,10, 10);return false;" songid="105544232" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105544232');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105544232">
# <a alt="EASY" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('105544232','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('105544232');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('105544232');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="105293063">
# <td class="check"><input class="select-check" title="Love wins all" type="checkbox"/></td>
# <td class="number">5
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84729887');return false;"><span class="mask"></span><img alt="The Winning" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/729/887/84729887_1708417120198_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105293063');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105293063','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Love wins all</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('67872918');return false;">아이유 (IU)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105293063');" type="button">외</button>
# <ul class="list" id="RelationArtist_105293063"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84729887');return false;">The Winning</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105293063;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105293063;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105293063" onclick="fnAddMyAlbumForm('#add_my_album_105293063' , '105293063' ,10, 10);return false;" songid="105293063" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105293063');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105293063">
# <a alt="Love wins all" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('105293063','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('105293063');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('105293063');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="105872512">
# <td class="check"><input class="select-check" title="Magnetic" type="checkbox"/></td>
# <td class="number">6
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-down">1<span class="hide">하강</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84914987');return false;"><span class="mask"></span><img alt="SUPER REAL ME" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/914/987/84914987_1711342168138_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105872512');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105872512','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Magnetic</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('82387391');return false;">아일릿 (ILLIT)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105872512');" type="button">외</button>
# <ul class="list" id="RelationArtist_105872512"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84914987');return false;">SUPER REAL ME</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105872512;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105872512;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105872512" onclick="fnAddMyAlbumForm('#add_my_album_105872512' , '105872512' ,10, 10);return false;" songid="105872512" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105872512');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105872512">
# <a alt="Magnetic" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('105872512','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('105872512');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('105872512');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="86931930">
# <td class="check"><input class="select-check" title="예뻤어" type="checkbox"/></td>
# <td class="number">7
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('80919666');return false;"><span class="mask"></span><img alt="Every DAY6 February" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/080/919/666/80919666_1486113823984_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('86931930');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('86931930','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 예뻤어</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80444970');return false;">DAY6 (데이식스)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('86931930');" type="button">외</button>
# <ul class="list" id="RelationArtist_86931930"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('80919666');return false;">Every DAY6 February</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('86931930;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('86931930;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_86931930" onclick="fnAddMyAlbumForm('#add_my_album_86931930' , '86931930' ,10, 10);return false;" songid="86931930" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('86931930');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_86931930">
# <a alt="예뻤어" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('86931930','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('86931930');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('86931930');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="104553679">
# <td class="check"><input class="select-check" title="비의 랩소디" type="checkbox"/></td>
# <td class="number">8
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84545218');return false;"><span class="mask"></span><img alt="비의 랩소디" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/545/218/84545218_1701255631132_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('104553679');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('104553679','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 비의 랩소디</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80639927');return false;">임재현</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('104553679');" type="button">외</button>
# <ul class="list" id="RelationArtist_104553679"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84545218');return false;">비의 랩소디</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('104553679;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('104553679;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_104553679" onclick="fnAddMyAlbumForm('#add_my_album_104553679' , '104553679' ,10, 10);return false;" songid="104553679" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('104553679');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_104553679">
# <a alt="비의 랩소디" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('104553679');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('104553679');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="104534602">
# <td class="check"><input class="select-check" title="To. X" type="checkbox"/></td>
# <td class="number">9
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">2<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84539814');return false;"><span class="mask"></span><img alt="To. X - The 5th Mini Album" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/539/814/84539814_1701067108915_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('104534602');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('104534602','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 To. X</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('56069675');return false;">태연 (TAEYEON)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('104534602');" type="button">외</button>
# <ul class="list" id="RelationArtist_104534602"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84539814');return false;">To. X - The 5th Mini Album</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('104534602;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('104534602;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_104534602" onclick="fnAddMyAlbumForm('#add_my_album_104534602' , '104534602' ,10, 10);return false;" songid="104534602" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('104534602');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_104534602">
# <a alt="To. X" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('104534602','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('104534602');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('104534602');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="105563654">
# <td class="check"><input class="select-check" title="천상연" type="checkbox"/></td>
# <td class="number">10
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-down">3<span class="hide">하강</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84815509');return false;"><span class="mask"></span><img alt="천상연 (웹툰 '선녀외전' X 이창섭 (LEE CHANGSUB))" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/815/509/84815509_1708311688384_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105563654');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105563654','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 천상연</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80441192');return false;">이창섭</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105563654');" type="button">외</button>
# <ul class="list" id="RelationArtist_105563654"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84815509');return false;">천상연 (웹툰 '선녀외전' X 이창섭 (LEE CHANGSUB))</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105563654;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105563654;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105563654" onclick="fnAddMyAlbumForm('#add_my_album_105563654' , '105563654' ,10, 10);return false;" songid="105563654" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105563654');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105563654">
# <a alt="천상연" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('105563654');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('105563654');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="104821618">
# <td class="check"><input class="select-check" title="에피소드" type="checkbox"/></td>
# <td class="number">11
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84600370');return false;"><span class="mask"></span><img alt="에피소드" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/600/370/84600370_1702445165120_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('104821618');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('104821618','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 에피소드</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80632742');return false;">이무진</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('104821618');" type="button">외</button>
# <ul class="list" id="RelationArtist_104821618"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84600370');return false;">에피소드</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('104821618;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('104821618;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_104821618" onclick="fnAddMyAlbumForm('#add_my_album_104821618' , '104821618' ,10, 10);return false;" songid="104821618" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('104821618');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_104821618">
# <a alt="에피소드" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('104821618','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('104821618');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('104821618');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="89220627">
# <td class="check"><input class="select-check" title="한 페이지가 될 수 있게" type="checkbox"/></td>
# <td class="number">12
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-down">2<span class="hide">하강</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('81244101');return false;"><span class="mask"></span><img alt="The Book of Us : Gravity" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/081/244/101/81244101_1563174738943_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('89220627');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('89220627','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 한 페이지가 될 수 있게</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80444970');return false;">DAY6 (데이식스)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('89220627');" type="button">외</button>
# <ul class="list" id="RelationArtist_89220627"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('81244101');return false;">The Book of Us : Gravity</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('89220627;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('89220627;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_89220627" onclick="fnAddMyAlbumForm('#add_my_album_89220627' , '89220627' ,10, 10);return false;" songid="89220627" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('89220627');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_89220627">
# <a alt="한 페이지가 될 수 있게" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('89220627','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('89220627');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('89220627');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="105544011">
# <td class="check"><input class="select-check" title="홀씨" type="checkbox"/></td>
# <td class="number">13
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84729887');return false;"><span class="mask"></span><img alt="The Winning" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/729/887/84729887_1708417120198_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105544011');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105544011','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 홀씨</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('67872918');return false;">아이유 (IU)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105544011');" type="button">외</button>
# <ul class="list" id="RelationArtist_105544011"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84729887');return false;">The Winning</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105544011;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105544011;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105544011" onclick="fnAddMyAlbumForm('#add_my_album_105544011' , '105544011' ,10, 10);return false;" songid="105544011" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105544011');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105544011">
# <a alt="홀씨" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('105544011','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('105544011');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('105544011');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="101407645">
# <td class="check"><input class="select-check" title="헤어지자 말해요" type="checkbox"/></td>
# <td class="number">14
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83748133');return false;"><span class="mask"></span><img alt="1집 Alone" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/748/133/83748133_1681960235531_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('101407645');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('101407645','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 헤어지자 말해요</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80233010');return false;">박재정</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('101407645');" type="button">외</button>
# <ul class="list" id="RelationArtist_101407645"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83748133');return false;">1집 Alone</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('101407645;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('101407645;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_101407645" onclick="fnAddMyAlbumForm('#add_my_album_101407645' , '101407645' ,10, 10);return false;" songid="101407645" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('101407645');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_101407645">
# <a alt="헤어지자 말해요" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('101407645','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('101407645');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('101407645');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="96042335">
# <td class="check"><input class="select-check" title="사랑인가 봐" type="checkbox"/></td>
# <td class="number">15
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">12<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82540759');return false;"><span class="mask"></span><img alt="사랑인가 봐 (사내맞선 OST 스페셜 트랙)" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/540/759/82540759_1645152997958_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96042335');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('96042335','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 사랑인가 봐</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80343878');return false;">멜로망스 (MeloMance)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('96042335');" type="button">외</button>
# <ul class="list" id="RelationArtist_96042335"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82540759');return false;">사랑인가 봐 (사내맞선 OST 스페셜 트랙)</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96042335;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('96042335;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_96042335" onclick="fnAddMyAlbumForm('#add_my_album_96042335' , '96042335' ,10, 10);return false;" songid="96042335" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('96042335');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_96042335">
# <a alt="사랑인가 봐" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('96042335','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('96042335');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('96042335');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="105544234">
# <td class="check"><input class="select-check" title="Smart" type="checkbox"/></td>
# <td class="number">16
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-down">1<span class="hide">하강</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84742099');return false;"><span class="mask"></span><img alt="EASY" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/742/099/84742099_1708319116249_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('105544234');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('105544234','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Smart</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('81397289');return false;">LE SSERAFIM (르세라핌)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('105544234');" type="button">외</button>
# <ul class="list" id="RelationArtist_105544234"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84742099');return false;">EASY</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('105544234;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('105544234;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_105544234" onclick="fnAddMyAlbumForm('#add_my_album_105544234' , '105544234' ,10, 10);return false;" songid="105544234" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('105544234');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_105544234">
# <a alt="Smart" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('105544234','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# ...
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('100080644');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('100080644','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 그대가 내 안에 박혔다 (그내박)</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80629888');return false;">순순희 (기태)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('100080644');" type="button">외</button>
# <ul class="list" id="RelationArtist_100080644"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83455650');return false;">그대가 내 안에 박혔다 (그내박)</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('100080644;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('100080644;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_100080644" onclick="fnAddMyAlbumForm('#add_my_album_100080644' , '100080644' ,10, 10);return false;" songid="100080644" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('100080644');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_100080644">
# <a alt="그대가 내 안에 박혔다 (그내박)" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('100080644','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('100080644');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('100080644');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="102724316">
# <td class="check"><input class="select-check" title="ETA" type="checkbox"/></td>
# <td class="number">47
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84019740');return false;"><span class="mask"></span><img alt="NewJeans 2nd EP 'Get Up'" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/019/740/84019740_1688692234715_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('102724316');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('102724316','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 ETA</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('81490206');return false;">NewJeans</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('102724316');" type="button">외</button>
# <ul class="list" id="RelationArtist_102724316"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84019740');return false;">NewJeans 2nd EP 'Get Up'</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('102724316;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('102724316;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_102724316" onclick="fnAddMyAlbumForm('#add_my_album_102724316' , '102724316' ,10, 10);return false;" songid="102724316" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('102724316');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_102724316">
# <a alt="ETA" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('102724316','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('102724316');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('102724316');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="96696809">
# <td class="check"><input class="select-check" title="다시 만날 수 있을까" type="checkbox"/></td>
# <td class="number">48
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">2<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82638032');return false;"><span class="mask"></span><img alt="IM HERO" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/638/032/82638032_1651479062721_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96696809');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('96696809','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 다시 만날 수 있을까</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80539618');return false;">임영웅</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('96696809');" type="button">외</button>
# <ul class="list" id="RelationArtist_96696809"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82638032');return false;">IM HERO</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96696809;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('96696809;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_96696809" onclick="fnAddMyAlbumForm('#add_my_album_96696809' , '96696809' ,10, 10);return false;" songid="96696809" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('96696809');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_96696809">
# <a alt="다시 만날 수 있을까" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('96696809','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('96696809');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('96696809');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="102563175">
# <td class="check"><input class="select-check" title="Super Shy" type="checkbox"/></td>
# <td class="number">49
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-down">5<span class="hide">하강</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('84019740');return false;"><span class="mask"></span><img alt="NewJeans 2nd EP 'Get Up'" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/084/019/740/84019740_1688692234715_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('102563175');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('102563175','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Super Shy</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('81490206');return false;">NewJeans</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('102563175');" type="button">외</button>
# <ul class="list" id="RelationArtist_102563175"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('84019740');return false;">NewJeans 2nd EP 'Get Up'</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('102563175;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('102563175;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_102563175" onclick="fnAddMyAlbumForm('#add_my_album_102563175' , '102563175' ,10, 10);return false;" songid="102563175" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('102563175');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_102563175">
# <a alt="Super Shy" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('102563175','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('102563175');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('102563175');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr class="list" songid="81302362">
# <td class="check"><input class="select-check" title="벚꽃 엔딩" type="checkbox"/></td>
# <td class="number">50
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-up">44<span class="hide">상승</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('80287115');return false;"><span class="mask"></span><img alt="버스커 버스커 1집" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/080/287/115/80287115_1332318513743_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('81302362');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('81302362','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 벚꽃 엔딩</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('80144528');return false;">버스커 버스커 (Busker Busker)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('81302362');" type="button">외</button>
# <ul class="list" id="RelationArtist_81302362"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('80287115');return false;">버스커 버스커 1집</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('81302362;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('81302362;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_81302362" onclick="fnAddMyAlbumForm('#add_my_album_81302362' , '81302362' ,10, 10);return false;" songid="81302362" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('81302362');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_81302362">
# <a alt="벚꽃 엔딩" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('81302362','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('81302362');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('81302362');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>
# </tbody>
# </table>
# <!--// LIST -->
# <!-- TOOLBAR -->
# <div class="toolbar">
# <input class="all-check" id="" title="전체 선택" type="checkbox"/>
# <a class="btn btn-listen" href="#" onclick="fnPlayArrSong(1); return false;" title="재생">듣기</a>
# <a class="btn btn-add" href="#" onclick="fnPlayArrSong(3); return false;" title="추가"><span class="hide">재생목록에 </span>추가</a>
# <button class="btn btn-album" id="add_my_album_list2" onclick="fnAddMyAlbumForm('#add_my_album_list2', fnSelectArrSongID(),20, 20);return false;" title="담기" type="button"><span class="hide">마이앨범에 </span>담기</button>
# <a class="btn btn-down" href="#" onclick="fnDownSong(fnSelectArrSongID());return false;" title="다운">다운</a>
# <div class="btns">
# <a class="btn btn-listen" href="#" onclick="fnPlayTop100Song(1); return false;" title="TOP200 듣기">TOP200 듣기</a>
# </div>
# <div class="check-length"><em>0</em>곡 선택</div>
# </div>
# <!--// TOOLBAR -->
# <script type="text/javascript">
#                 //<![CDATA[
#                 var musicList = new MUSIC_LIST();
#                 musicList.hook = $('.newest-list .music-list-wrap');
#                 musicList.option = {
#                     scroll:true,
#                     multiple:true
#                 };
#                 musicList._load();
#
#                 var artist_etc_layer = new FG_toggleLayer($('.artist_etc_layer'), {
#                     clickHide : true,
#                     mode : 'artistLayer'
#                 }, function(){
#                     //call back
#                 });
#                 //뮤직 비디오 disabled 비활성화 처리
#                 $('.lyr-mv .disabled').css({ 'pointer-events':'none'});
#
#                 //곡 리스트 순회해서 좋아요 여부 체크 (추후 적용)
#                 //fnSetLikeList(iMemUno,'SONG_LIKE','<= sSongIDs >', '.songlist-box .music-list-wrap');
#                 //]]>
#             </script>
# </div>

# %%
bs.findAll("td",class_='info')[0].find("a", class_="title ellipsis").text.strip()
# Out:
# '나는 아픈 건 딱 질색이니까'

# %%
bs.findAll("td",class_='info')[0].find("a", class_="artist ellipsis").text
# Out:
# '(여자)아이들'

# %%
for idx, x in enumerate(bs.findAll("td",class_='info')):
    title = x.find("a", class_="title ellipsis").text.strip()
    artist = x.find("a", class_="artist ellipsis").text
    print(f"{idx+1}위 -> {title} - {artist} ")
# Out:
# 1위 -> 나는 아픈 건 딱 질색이니까 - (여자)아이들
# 2위 -> 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# 3위 -> 밤양갱 - 비비 (BIBI)
# 4위 -> EASY - LE SSERAFIM (르세라핌)
# 5위 -> Love wins all - 아이유 (IU)
# 6위 -> Magnetic - 아일릿 (ILLIT)
# 7위 -> 예뻤어 - DAY6 (데이식스)
# 8위 -> 비의 랩소디 - 임재현
# 9위 -> To. X - 태연 (TAEYEON)
# 10위 -> 천상연 - 이창섭
# 11위 -> 에피소드 - 이무진
# 12위 -> 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 13위 -> 홀씨 - 아이유 (IU)
# 14위 -> 헤어지자 말해요 - 박재정
# 15위 -> 사랑인가 봐 - 멜로망스 (MeloMance)
# 16위 -> Smart - LE SSERAFIM (르세라핌)
# 17위 -> 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션 (Nerd Connection)
# 18위 -> Perfect Night - LE SSERAFIM (르세라핌)
# 19위 -> I AM - IVE (아이브)
# 20위 -> 사건의 지평선 - 윤하 (YOUNHA)
# 21위 -> Love 119 - RIIZE
# 22위 -> Drama - aespa
# 23위 -> 사랑은 늘 도망가 - 임영웅
# 24위 -> Love Lee - AKMU (악뮤)
# 25위 -> 인사 - 범진
# 26위 -> 후라이의 꿈 - AKMU (악뮤)
# 27위 -> 심 (心) - DK (디셈버)
# 28위 -> Wife - (여자)아이들
# 29위 -> 우리들의 블루스 - 임영웅
# 30위 -> 퀸카 (Queencard) - (여자)아이들
# 31위 -> Hype Boy - NewJeans
# 32위 -> 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 - 장범준
# 33위 -> 사막에서 꽃을 피우듯 - 우디 (Woody)
# 34위 -> Shopper - 아이유 (IU)
# 35위 -> 이제 나만 믿어요 - 임영웅
# 36위 -> Super Lady - (여자)아이들
# 37위 -> Welcome to the Show - DAY6 (데이식스)
# 38위 -> 모래 알갱이 - 임영웅
# 39위 -> Seven (Feat. Latto) (Clean Ver.) - 정국
# 40위 -> I Don't Think That I Like Her - Charlie Puth
# 41위 -> You & Me - 제니 (JENNIE)
# 42위 -> MANIAC - VIVIZ (비비지)
# 43위 -> 너의 모든 순간 - 성시경
# 44위 -> Ditto - NewJeans
# 45위 -> Baddie - IVE (아이브)
# 46위 -> 그대가 내 안에 박혔다 (그내박) - 순순희 (기태)
# 47위 -> ETA - NewJeans
# 48위 -> 다시 만날 수 있을까 - 임영웅
# 49위 -> Super Shy - NewJeans
# 50위 -> 벚꽃 엔딩 - 버스커 버스커 (Busker Busker)

# %%
lyric = "https://www.genie.co.kr/detail/songInfo?xgnm={}"

# %%
import re 
p = re.compile("[0-9]+")

# %%
x.find("a", class_="title ellipsis")['onclick'].split("'")[1]
# Out:
# '81302362'

# %%
for idx, x in enumerate(bs.findAll("td",class_='info')):
    title = x.find("a", class_="title ellipsis").text.strip()
    artist = x.find("a", class_="artist ellipsis").text
    id_ = x.find("a", class_="title ellipsis")['onclick'].split("'")[1]
    print(f"{idx+1}위 -> {title} - {artist} ")
    print(lyric.format(id_))
# Out:
# 1위 -> 나는 아픈 건 딱 질색이니까 - (여자)아이들
# https://www.genie.co.kr/detail/songInfo?xgnm=105260468
# 2위 -> 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# https://www.genie.co.kr/detail/songInfo?xgnm=105262751
# 3위 -> 밤양갱 - 비비 (BIBI)
# https://www.genie.co.kr/detail/songInfo?xgnm=105464107
# 4위 -> EASY - LE SSERAFIM (르세라핌)
# https://www.genie.co.kr/detail/songInfo?xgnm=105544232
# 5위 -> Love wins all - 아이유 (IU)
# https://www.genie.co.kr/detail/songInfo?xgnm=105293063
# 6위 -> Magnetic - 아일릿 (ILLIT)
# https://www.genie.co.kr/detail/songInfo?xgnm=105872512
# 7위 -> 예뻤어 - DAY6 (데이식스)
# https://www.genie.co.kr/detail/songInfo?xgnm=86931930
# 8위 -> 비의 랩소디 - 임재현
# https://www.genie.co.kr/detail/songInfo?xgnm=104553679
# 9위 -> To. X - 태연 (TAEYEON)
# https://www.genie.co.kr/detail/songInfo?xgnm=104534602
# 10위 -> 천상연 - 이창섭
# https://www.genie.co.kr/detail/songInfo?xgnm=105563654
# 11위 -> 에피소드 - 이무진
# https://www.genie.co.kr/detail/songInfo?xgnm=104821618
# 12위 -> 한 페이지가 될 수 있게 - DAY6 (데이식스)
# https://www.genie.co.kr/detail/songInfo?xgnm=89220627
# 13위 -> 홀씨 - 아이유 (IU)
# https://www.genie.co.kr/detail/songInfo?xgnm=105544011
# 14위 -> 헤어지자 말해요 - 박재정
# https://www.genie.co.kr/detail/songInfo?xgnm=101407645
# 15위 -> 사랑인가 봐 - 멜로망스 (MeloMance)
# https://www.genie.co.kr/detail/songInfo?xgnm=96042335
# 16위 -> Smart - LE SSERAFIM (르세라핌)
# https://www.genie.co.kr/detail/songInfo?xgnm=105544234
# 17위 -> 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션 (Nerd Connection)
# https://www.genie.co.kr/detail/songInfo?xgnm=103024121
# 18위 -> Perfect Night - LE SSERAFIM (르세라핌)
# https://www.genie.co.kr/detail/songInfo?xgnm=104098457
# 19위 -> I AM - IVE (아이브)
# https://www.genie.co.kr/detail/songInfo?xgnm=101268096
# 20위 -> 사건의 지평선 - 윤하 (YOUNHA)
# https://www.genie.co.kr/detail/songInfo?xgnm=96424586
# 21위 -> Love 119 - RIIZE
# https://www.genie.co.kr/detail/songInfo?xgnm=105074315
# 22위 -> Drama - aespa
# https://www.genie.co.kr/detail/songInfo?xgnm=104277953
# 23위 -> 사랑은 늘 도망가 - 임영웅
# https://www.genie.co.kr/detail/songInfo?xgnm=94535712
# 24위 -> Love Lee - AKMU (악뮤)
# https://www.genie.co.kr/detail/songInfo?xgnm=103151984
# 25위 -> 인사 - 범진
# https://www.genie.co.kr/detail/songInfo?xgnm=95443285
# 26위 -> 후라이의 꿈 - AKMU (악뮤)
# https://www.genie.co.kr/detail/songInfo?xgnm=103151985
# 27위 -> 심 (心) - DK (디셈버)
# https://www.genie.co.kr/detail/songInfo?xgnm=100522029
# 28위 -> Wife - (여자)아이들
# https://www.genie.co.kr/detail/songInfo?xgnm=105260470
# 29위 -> 우리들의 블루스 - 임영웅
# https://www.genie.co.kr/detail/songInfo?xgnm=96549502
# 30위 -> 퀸카 (Queencard) - (여자)아이들
# https://www.genie.co.kr/detail/songInfo?xgnm=101686193
# 31위 -> Hype Boy - NewJeans
# https://www.genie.co.kr/detail/songInfo?xgnm=97582507
# 32위 -> 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 - 장범준
# https://www.genie.co.kr/detail/songInfo?xgnm=89320910
# 33위 -> 사막에서 꽃을 피우듯 - 우디 (Woody)
# https://www.genie.co.kr/detail/songInfo?xgnm=102605425
# 34위 -> Shopper - 아이유 (IU)
# https://www.genie.co.kr/detail/songInfo?xgnm=105544013
# 35위 -> 이제 나만 믿어요 - 임영웅
# https://www.genie.co.kr/detail/songInfo?xgnm=90077755
# 36위 -> Super Lady - (여자)아이들
# https://www.genie.co.kr/detail/songInfo?xgnm=105260463
# 37위 -> Welcome to the Show - DAY6 (데이식스)
# https://www.genie.co.kr/detail/songInfo?xgnm=105757621
# 38위 -> 모래 알갱이 - 임영웅
# https://www.genie.co.kr/detail/songInfo?xgnm=102067588
# 39위 -> Seven (Feat. Latto) (Clean Ver.) - 정국
# https://www.genie.co.kr/detail/songInfo?xgnm=102664199
# 40위 -> I Don't Think That I Like Her - Charlie Puth
# https://www.genie.co.kr/detail/songInfo?xgnm=98304971
# 41위 -> You & Me - 제니 (JENNIE)
# https://www.genie.co.kr/detail/songInfo?xgnm=103797393
# 42위 -> MANIAC - VIVIZ (비비지)
# https://www.genie.co.kr/detail/songInfo?xgnm=104169271
# 43위 -> 너의 모든 순간 - 성시경
# https://www.genie.co.kr/detail/songInfo?xgnm=82280761
# 44위 -> Ditto - NewJeans
# https://www.genie.co.kr/detail/songInfo?xgnm=99570005
# 45위 -> Baddie - IVE (아이브)
# https://www.genie.co.kr/detail/songInfo?xgnm=103903575
# 46위 -> 그대가 내 안에 박혔다 (그내박) - 순순희 (기태)
# https://www.genie.co.kr/detail/songInfo?xgnm=100080644
# 47위 -> ETA - NewJeans
# https://www.genie.co.kr/detail/songInfo?xgnm=102724316
# 48위 -> 다시 만날 수 있을까 - 임영웅
# https://www.genie.co.kr/detail/songInfo?xgnm=96696809
# 49위 -> Super Shy - NewJeans
# https://www.genie.co.kr/detail/songInfo?xgnm=102563175
# 50위 -> 벚꽃 엔딩 - 버스커 버스커 (Busker Busker)
# https://www.genie.co.kr/detail/songInfo?xgnm=81302362

# %%
r2 = requests.get("https://www.genie.co.kr/detail/songInfo?xgnm=105544013", headers=head)

# %%
bs2 = BeautifulSoup(r2.text)

# %%
print(bs2.find("pre", id="pLyrics").text.strip())
# Out:
# Shopper - 03:36
# 							아직도 난
# 더 가지고 싶어
# (Yeah I want more
# I’ll get it more, more)
#
# 설레는 게
# 이렇게나 많은 걸
# (Oh I want all
# I must have all, all)
#
# 저녁 일곱시
# 노을의 팔레트
# (I need it, course
# I’ll take it, course, course)
#
# 가슴 터질 듯
# 내 이름을 외치는 목소리
# (Oh it’s so worth
# It’s more than what, what)
#
# 빼곡히 적은 wish list
# 빠짐없이 가질 때까지
# (Take what you want
# No matter who calls you a freak)
#
# 설명할 필요 없어
# 나 그때와는 다른 걸 원해, 원해
#
# Let’s go haul
# 더 미어터질 만큼 다 채워
# Look around
# 시간은 짧아 더 빨리 가져
# (Shop all day, ay
# Greed is free, ay)
#
# Go Make your own
# 가지러 태어난 것처럼
# 이 샵은 문 닫지 않아 늘, 영원히
#
# 마지막 소절 숨의 첫 모금
# (It's time to show
# Go, make it sure, sure)
#
# 승리를 앞둔
# 마음이 달릴 때 내는 소리
# (It's time to go
# I'll make my goal, goal)
#
# 내게는 없어 plan B
# 모조리 내 것이 될 때까지
# (Take what you want
# No matter who puts down your greed)
#
# 적당히로는 안돼
# 난 훨씬 더 대담한 걸 원해, 원해
#
# Let’s go haul
# 더 미어터질 만큼 다 채워
# Look around
# 시간은 짧아 더 빨리 가져
# 이 샵은 문 닫지 않아, 봐
#
# 필요 없는 건 없어
# for my Victory, even your jealousy
# 나 이제껏 모르던 세상을 욕심 내볼래
#
# Let’s go haul
# 더 미어터질 만큼 다 채워
# Look around
# 시간은 짧아 더 빨리 가져
#
# Shop all day, ay
# Greed is free, ay
#
# Go Make your own
# 가지러 태어난 것처럼
# 이 샵은 문 닫지 않아 늘, 영원히

# %%
import os 
os.getcwd()
# Out:
# '/home/gen2/workspace'

# %%
# 상대경로 -> ./ -> 현재 폴더 
# ../ -> 현재 경로에서 상위 폴더 
# 절대경로 
f = open('./a.txt', "w", encoding='utf-8')
f.write(bs2.find("pre", id="pLyrics").text.strip())
f.close()

# %%
target = "./lyric"
if not os.path.isdir(target):
    os.mkdir(target)
